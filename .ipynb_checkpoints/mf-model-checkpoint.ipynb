# %%
import numpy as np
import pandas as pd
from sklearn.metrics import ndcg_score, root_mean_squared_error
from sklearn.model_selection import ParameterGrid
from sklearn.decomposition import NMF
from sklearn.model_selection import KFold, train_test_split
import seaborn as sns
import itertools
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
from matplotlib.cm import ScalarMappable
import matplotlib.colors as mcolors
from sklearn.decomposition import TruncatedSVD
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score, f1_score

# %%
def set_dim_fig(sizes=(10,12,12)):
    SMALL_SIZE = sizes[0]
    MEDIUM_SIZE = sizes[1]
    BIGGER_SIZE = sizes[2]
    
    plt.rc('font', size=MEDIUM_SIZE)         # controls default text sizes
    plt.rc('axes', titlesize=MEDIUM_SIZE)    # fontsize of the axes title
    plt.rc('axes', labelsize=SMALL_SIZE)     # fontsize of the x and y labels
    plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
    plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
    plt.rc('figure', titlesize=MEDIUM_SIZE)  # fontsize of the figure title

# %%
set_dim_fig()

# %% [markdown]
# # Functions

# %% [markdown]
# ## Exploratory

# %%
def calculate_density(df, col_user='user_id', col_video='video_id', print_density=True):
    # Number of unique users and videos
    n_users = df[col_user].nunique()
    n_videos = df[col_video].nunique()
    
    # Number of observed interactions
    n_observed = len(df)
    
    # Compute density and sparsity
    density = n_observed / (n_users * n_videos)
    sparsity = 1 - density

    if print_density:
        print(f"Users: {n_users}, Videos: {n_videos}")
        print(f"Observed interactions: {n_observed}")
        print(f"Density: {density:.4f}")
        print(f"Sparsity: {sparsity:.4f}")

    return density

# %% [markdown]
# ## Matrix Factorization

# %%
def split_train_test_smart(df, test_size=0.2, seed=42):
    # Step 1: Filter out users/items with only one rating
    user_counts = df['user_id'].value_counts()
    item_counts = df['video_id'].value_counts()
    df = df[df['user_id'].isin(user_counts[user_counts > 1].index)]
    df = df[df['video_id'].isin(item_counts[item_counts > 1].index)]
    
    # Step 2: Split per user
    train_list, test_list = [], []
    for user, user_data in df.groupby('user_id'):
        if len(user_data) >= 2:
            train_u, test_u = train_test_split(user_data, test_size=test_size, random_state=seed)
        else:
            train_u, test_u = user_data, pd.DataFrame()
        train_list.append(train_u)
        test_list.append(test_u)
    
    train_df = pd.concat(train_list)
    test_df = pd.concat(test_list)

    print(df.shape, train_df.shape, test_df.shape)
    
    # Step 3: Identify cold users/items in test
    cold_users = test_df.loc[~test_df['user_id'].isin(train_df['user_id']), 'user_id'].unique()
    cold_items = test_df.loc[~test_df['video_id'].isin(train_df['video_id']), 'video_id'].unique()

    if len(cold_users) > 0:
        print("cold users", cold_users)
    if len(cold_items) > 0:
        print("cold items", cold_items)
    
    # Step 4: Move only ONE rating per cold user/item from test to train
    to_move = []

    # For each cold user: move one random rating
    for u in cold_users:
        user_ratings = test_df[test_df['user_id'] == u]
        if not user_ratings.empty:
            to_move.append(user_ratings.sample(1, random_state=seed))

    # For each cold item: move one random rating
    for i in cold_items:
        item_ratings = test_df[test_df['video_id'] == i]
        if not item_ratings.empty:
            to_move.append(item_ratings.sample(1, random_state=seed))

    if len(to_move) > 0:
        move_back_df = pd.concat(to_move).drop_duplicates()
        train_df = pd.concat([train_df, move_back_df])
        test_df = test_df.drop(move_back_df.index)

    # Final check
    # --- Check for remaining cold users/items ---
    if not test_df['user_id'].isin(train_df['user_id']).all():
        print("⚠️ Warning: Some test users are not in training")
    if not test_df['video_id'].isin(train_df['video_id']).all():
        print("⚠️ Warning: Some test items are not in training")
    

    print(len(train_df), len(test_df), 0.2*len(df))
    return train_df, test_df


def transform_df_to_matrix(df, users, items):
    df_mf = pd.pivot_table(df, values='rating', index='user_id', columns='video_id')
    df_mf = df_mf.reindex(index=users, columns=items)
    df_mf = df_mf.fillna(0)
    return df_mf.to_numpy() # <-- return NumPy array #for sparse matrix: csr_matrix(df_mf.values)  

def compute_ndcg_per_user(R_true, R_pred, k=None, print_info=True):
    ndcgs = []

    # Number of relevant (non-zero) items per user
    test_items_per_user = np.sum(R_true > 0, axis=1)

    # Determine k if not provided
    if k is None:
        valid_users = test_items_per_user[test_items_per_user > 1]
        if len(valid_users) == 0:
            print("⚠️ No users with more than 1 test item!")
            return 0, 0.0
        k = np.min(valid_users)
        if print_info:
            print(f"NDCG score k = {k}")

    for u in range(R_true.shape[0]):
        mask_u = R_true[u] > 0  # only items the user interacted with

        n_items = np.sum(mask_u)
        if n_items < k:
            continue  # skip users with less than k relevant items

        ndcgs.append(ndcg_score([R_true[u, mask_u]], [R_pred[u, mask_u]], k=k))

    if print_info:
        print("Number of users used for NDCG:", len(ndcgs))

    return k, len(ndcgs), float(np.mean(ndcgs)) if len(ndcgs) > 0 else 0.0

    
def grid_search_mf_bias(df, param_grid, seed=42, print_info=True, norm=True):
    """
    Grid search over MF models (SVD/NMF) with bias correction, using smart train-test split.
    df: DataFrame with columns ['user_id', 'video_id', 'rating']
    param_grid: dict with keys: model_type, n_components, max_iter, init
    """
    # ---- SMART TRAIN TEST SPLIT ----
    train_df, test_df = split_train_test_smart(df)

    best_score = float('inf')
    best_params = None
    best_results = None
    best_exp_var = None
    best_rec_error = None
    best_rec_error_norm = None
    
    explained_variance = None
    reconstruction_error = None
    reconstruction_error_norm = None

    users = sorted(df['user_id'].unique())
    items = sorted(df['video_id'].unique())
    user_idx_map = {u: i for i, u in enumerate(users)}
    item_idx_map = {v: j for j, v in enumerate(items)}

    # Convert train interactions to matrix
    R_train = np.zeros((len(users), len(items)))
    for _, row in train_df.iterrows():
        R_train[user_idx_map[row['user_id']], item_idx_map[row['video_id']]] = row['rating']
    mask_train = R_train > 0

    # Convert test interactions to matrix
    R_test = np.zeros((len(users), len(items)))
    for _, row in test_df.iterrows():
        R_test[user_idx_map[row['user_id']], item_idx_map[row['video_id']]] = row['rating']
    mask_test = R_test > 0

    # ---- BASELINE BIASES (only on train!) ----
    if norm:
        global_mean = R_train[mask_train].mean()
        user_bias = np.zeros(R_train.shape[0])
        item_bias = np.zeros(R_train.shape[1])
    
        for i in range(R_train.shape[0]):
            user_ratings = R_train[i, :]
            mask_i = user_ratings > 0
            if np.sum(mask_i) > 0:
                user_bias[i] = user_ratings[mask_i].mean() - global_mean
    
        for j in range(R_train.shape[1]):
            item_ratings = R_train[:, j]
            mask_j = item_ratings > 0
            if np.sum(mask_j) > 0:
                item_bias[j] = item_ratings[mask_j].mean() - global_mean
    
        # ---- CENTER TRAIN MATRIX ----
        R_centered = np.zeros_like(R_train)
        for i in range(R_train.shape[0]):
            for j in range(R_train.shape[1]):
                if mask_train[i, j]:
                    R_centered[i, j] = R_train[i, j] - (global_mean + user_bias[i] + item_bias[j])

    else:
        R_centered = R_train
        
    # ---- GRID SEARCH ----
    for params in ParameterGrid(param_grid):
        model_type = params.get('model_type', 'nmf')
        n_components = params.get('n_components', 2)
        max_iter = params.get('max_iter', 2000)
        init = params.get('init', 'random')
        n_iter = params.get('n_iter', 5)

        if print_info:
            print(f"Testing parameters: {params}")
            print(model_type, n_components, max_iter, init, n_iter)

        np.random.seed(seed)

        if model_type == 'nmf':
            model = NMF(n_components=n_components, init=init, random_state=seed, max_iter=max_iter)
            R_input = np.maximum(R_centered, 0)
            A = model.fit_transform(R_input)
            B = model.components_
            reconstruction_error = model.reconstruction_err_
            reconstruction_error_norm = reconstruction_error / np.linalg.norm(R_input, 'fro')
            if print_info:
                print("Normalized reconstruction error:", reconstruction_error_norm)

        elif model_type == 'svd':
            model = TruncatedSVD(n_components=n_components, random_state=seed, n_iter=n_iter)
            A = model.fit_transform(R_centered)
            B = model.components_
            # TruncatedSVD provides explained_variance_
            explained_variance = model.explained_variance_ratio_.sum()  # total variance explained by components
            if print_info:
                print("Explained variance:", explained_variance)
        else:
            raise ValueError("model_type must be 'nmf' or 'svd'")

        R_estimated_centered = np.dot(A, B)

        # Add baseline bias back
        R_estimated = np.zeros_like(R_train)
        for i in range(R_train.shape[0]):
            for j in range(R_train.shape[1]):
                if norm:
                    R_estimated[i, j] = R_estimated_centered[i, j] + global_mean + user_bias[i] + item_bias[j]
                else:
                    R_estimated[i, j] = R_estimated_centered[i, j]

        # ---- EVALUATE ON TEST ONLY ----
        y_true = R_test[mask_test]
        y_pred = R_estimated[mask_test]

        rmse = root_mean_squared_error(y_true, y_pred)
        rmse_normalized = rmse / np.std(y_true)

        k_ndcg, len_ndcg, ndcg = compute_ndcg_per_user(R_test, R_estimated, k=3, print_info=print_info)

        if print_info:
            print(f"RMSE: {rmse:.4f}, Normalized: {rmse_normalized:.4f}, NDCG@{k_ndcg}: {ndcg:.4f}")

        # Track best
        if rmse < best_score:
            best_score = rmse
            best_params = params
            best_results = (R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_normalized, best_params)
            best_exp_var = explained_variance
            best_rec_error = reconstruction_error
            best_rec_error_norm = reconstruction_error_norm

    
    print(f"\n✅ Best params: {best_params}")
    print(f"✅ Best RMSE on TEST: {best_score:.4f}, NDCG@{k_ndcg}: {best_results[2]:.4f} (len:{len_ndcg}), normalized RMSE: {best_results[4]:.4f}")
    print(f"\n📈 Explained Variance (for best SVD only): {best_exp_var}")
    print(f"\n📈 Reconstruction Error (for best NMF only): {best_rec_error}")
    print(f"\n📈 Reconstruction Error Normalized(for best NMF only): {best_rec_error_norm}")
    
    return best_results

# %%
def grid_search_mf_bias_loou_ndcg(df, param_grid, seed=42, print_info=True, norm=True,  k_ndcg=10):
   
    np.random.seed(seed)

    print(df.shape)
    # --- Filter out users with only 1 rating ---
    user_counts = df['user_id'].value_counts()
    users_to_keep = set(user_counts[user_counts > 1].index)
    filtered_df = df[df['user_id'].isin(users_to_keep)].copy()
    print(filtered_df.shape)
    
    if filtered_df.empty:
        raise ValueError("After filtering users with <= 1 rating, no data remains.")

    # Define global item universe from filtered data to keep consistent item indexing across folds
    items = sorted(filtered_df['video_id'].unique())
    item_idx_map = {v: j for j, v in enumerate(items)}
    n_items = len(items)

    users_all = sorted(filtered_df['user_id'].unique())  # users to be left out one-by-one

    model_type = param_grid['model_type']
    n_components = param_grid['n_components']
    max_iter = param_grid['max_iter']
    init = param_grid['init']
    n_iter = param_grid['n_iter'] # for TruncatedSVD

    if print_info:
        print(f"\n=== Testing params: {param_grid} ===")

    # containers to aggregate held-out values across folds for RMSE and per-user ndcg
    all_y_true = []
    all_y_pred = []
    ndcg_per_user = []

    # Leave-One-User-Out CV
    for left_user in users_all:
        # training = all users except left_user
        train_df = filtered_df[filtered_df['user_id'] != left_user]
        test_df = filtered_df[filtered_df['user_id'] == left_user]

        # user ordering: training users, then left_user as last row (so we can predict)
        train_users = sorted(train_df['user_id'].unique())
        users_for_matrix = train_users + [left_user]
        user_idx_map = {u: i for i, u in enumerate(users_for_matrix)}
        n_users_matrix = len(users_for_matrix)

        # Build R_train matrix (rows = users_for_matrix, last row = left_user zeros)
        R_train = np.zeros((n_users_matrix, n_items), dtype=float)
        for _, r in train_df.iterrows():
            u = r['user_id']; v = r['video_id']; rating = r['rating']
            # skip items not in global item list (shouldn't happen)
            if v in item_idx_map:
                R_train[user_idx_map[u], item_idx_map[v]] = rating
        mask_train = R_train > 0

        # Build R_test matrix (only last row may have ratings)
        R_test = np.zeros_like(R_train)
        for _, r in test_df.iterrows():
            v = r['video_id']; rating = r['rating']
            if v in item_idx_map:
                R_test[user_idx_map[left_user], item_idx_map[v]] = rating
        mask_test = R_test > 0

        # If no training ratings (unlikely after filtering), skip this fold
        if mask_train.sum() == 0:
            if print_info:
                print(f"  Skipping fold for left_user={left_user}: no training ratings")
            continue

        # Baseline biases computed on training data only (exclude left_user)
        if norm:
            train_vals = R_train[mask_train]
            global_mean = float(train_vals.mean())
            # user_bias for training users; left_user bias kept 0 (not used for centering)
            user_bias = np.zeros(n_users_matrix, dtype=float)
            for i, u in enumerate(users_for_matrix):
                if u == left_user:
                    user_bias[i] = 0.0
                else:
                    mask_i = mask_train[i, :]
                    if mask_i.sum() > 0:
                        user_bias[i] = R_train[i, mask_i].mean() - global_mean
                    else:
                        user_bias[i] = 0.0
            # item bias from training rows only
            item_bias = np.zeros(n_items, dtype=float)
            for j in range(n_items):
                col_mask = mask_train[:, j]
                if col_mask.sum() > 0:
                    item_bias[j] = R_train[col_mask, j].mean() - global_mean
                else:
                    item_bias[j] = 0.0

            # Center training matrix entries
            R_centered = np.zeros_like(R_train)
            rows, cols = np.where(mask_train)
            for (i, j) in zip(rows, cols):
                R_centered[i, j] = R_train[i, j] - (global_mean + user_bias[i] + item_bias[j])
        else:
            R_centered = R_train.copy()
            global_mean = 0.0
            user_bias = np.zeros(n_users_matrix, dtype=float)
            item_bias = np.zeros(n_items, dtype=float)

        # Fit the chosen model on R_centered (note: left_user row is zeros -> unseen)
        try:
            if model_type == 'nmf':
                # NMF requires non-negative input
                R_input = np.maximum(R_centered, 0.0)
                model = NMF(n_components=n_components, init=init, random_state=seed, max_iter=max_iter)
                A = model.fit_transform(R_input)
                B = model.components_
            elif model_type == 'svd':
                model = TruncatedSVD(n_components=n_components, random_state=seed, n_iter=n_iter)
                A = model.fit_transform(R_centered)
                B = model.components_
            else:
                raise ValueError("model_type must be 'nmf' or 'svd'")
        except Exception as e:
            if print_info:
                print(f"  Model fitting failed on fold left_user={left_user}: {e}")
            # skip fold if fitting fails
            continue

        # Reconstruct centered predictions and add biases back
        R_est_centered = np.dot(A, B)
        R_est = R_est_centered + (global_mean + user_bias[:, None] + item_bias[None, :])

        # Evaluate on left-out user
        user_row = user_idx_map[left_user]
        test_mask_user = mask_test[user_row, :]
        test_indices = np.where(test_mask_user)[0]
        if test_indices.size == 0:
            # No test items for this left-out user (shouldn't happen after filtering), skip
            continue

        # Collect true/pred for RMSE (only on held-out items)
        y_true_user = R_test[user_row, test_indices]
        y_pred_user = R_est[user_row, test_indices]
        all_y_true.extend(y_true_user.tolist())
        all_y_pred.extend(y_pred_user.tolist())

        # For NDCG: prepare full-length arrays (length n_items), with graded relevance = ratings
        y_true_full = np.zeros(n_items, dtype=float)
        y_true_full[test_indices] = R_test[user_row, test_indices]  # ratings as graded relevance
        y_score_full = R_est[user_row, :].astype(float)

        # ndcg_score expects 2D arrays: shape (1, n_items)
        try:
            user_ndcg = ndcg_score([y_true_full], [y_score_full], k=k_ndcg)
        except Exception as e:
            # fallback: if sklearn raises, set ndcg to 0 for this user and continue
            if print_info:
                print(f"  ndcg_score failed for user {left_user}: {e}")
            user_ndcg = 0.0

        ndcg_per_user.append(float(user_ndcg))

        if print_info:
            print(f"  Left-out user {left_user}: NDCG@{k_ndcg}={user_ndcg:.4f}, n_test_items={len(test_indices)}")

    # End LOUO for this parameter setting
    if len(ndcg_per_user) == 0:
        avg_ndcg = 0.0
    else:
        avg_ndcg = float(np.mean(ndcg_per_user))

    all_y_true_arr = np.asarray(all_y_true)
    all_y_pred_arr = np.asarray(all_y_pred)
    rmse = root_mean_squared_error(all_y_true_arr, all_y_pred_arr)
    rmse_normalized = float(rmse / np.std(all_y_true_arr)) if all_y_true_arr.size > 0 and np.std(all_y_true_arr) > 0 else np.nan

    if print_info:
        print(f"Params {param_grid} -> Avg NDCG@{k_ndcg}: {avg_ndcg:.4f}, RMSE: {rmse:.4f}, RMSE_norm: {rmse_normalized}")

    best_metrics = dict()
    best_metrics["avg_ndcg_loo"] = avg_ndcg
    best_metrics["k_ndcg_loo"] = k_ndcg
    best_metrics["rmse_loo"] = rmse
    best_metrics["rmse_normalized_loo"] = rmse_normalized
    best_metrics["num_users_loo"] = len(ndcg_per_user)
    

    return best_metrics

# %%
def generate_latex_table(data, data_with_video_duration, quantiles=[0.2, 0.25, 0.5, 0.75, 0.8]):

    rows = []

    def rating_counts_with_percentage(series):
        n_total = len(series)
        counts = [(series.values == r).sum() for r in range(1,6)]
        counts_pct = [f"{c} ({c/n_total*100:.1f}%)" for c in counts]
        return counts_pct

    # All videos
    n_all = len(data)
    density_all = calculate_density(data, print_density=False)
    n_rating_all = rating_counts_with_percentage(data)
    rows.append(["All", n_all, f"{density_all:.3f}"] + n_rating_all)
    print("Density all", density_all)
    
    if data_with_video_duration is not None:
        for q in quantiles:
            t = int(data_with_video_duration[["video_duration"]].quantile(q).iloc[0])
            
            video_ids_up_ts, video_ids_more_ts = select_short_videos(data_with_video_duration, time=t, col="video_duration")
            
            # Short videos
            data_short = data[data["video_id"].isin(video_ids_up_ts)]
            n_short = len(data_short)
            density_short = calculate_density(data_short, print_density=False)
            n_rating_short = rating_counts_with_percentage(data_short)
            rows.append([f"Short Q{q} ({t}s)", n_short, f"{density_short:.3f}"] + n_rating_short)
            
            # Long videos
            data_long = data[data["video_id"].isin(video_ids_more_ts)]
            n_long = len(data_long)
            density_long = calculate_density(data_long, print_density=False)
            n_rating_long = rating_counts_with_percentage(data_long)
            rows.append([f"Long Q{q} ({t}s)", n_long, f"{density_long:.3f}"] + n_rating_long)

    # Convert to DataFrame
    df_table = pd.DataFrame(rows, columns=["Dataset", "Size", "Density", "1", "2", "3", "4", "5"])
    
    # Generate LaTeX code
    latex_code = df_table.to_latex(index=False, caption="Dataset Statistics", label="tab:dataset_stats", 
                                   column_format="lrrrrrrr")
    return latex_code

# %% [markdown]
# ## Plots

# %%
def plot_heatmap_residuals(R, R_hat, ax_arr=None):
    if ax_arr is None:
        fig, ax_arr = plt.subplots(1, 3, figsize=(12, 3))
    
    sns.heatmap(R, ax=ax_arr[0], cmap='Greens', vmin=-.05, vmax=1.05)
    ax_arr[0].set_title('Original Matrix')

    sns.heatmap(R_hat, ax=ax_arr[1], cmap='Purples', vmin=-0.5, vmax=1.05)
    ax_arr[1].set_title('Predicted Matrix')

    sns.heatmap(R - R_hat, ax=ax_arr[2], cmap='coolwarm', center=0, vmin=-1, vmax=1)
    ax_arr[2].set_title('Residuals')

    if ax_arr is None:
        plt.tight_layout()
        plt.show()


def plot_scatter_entries(R, R_hat, log=False, ax=None):
    if ax is None:
        fig, ax = plt.subplots(figsize=(5, 3))

    ax.scatter(R.flatten(), R_hat.flatten(), alpha=0.5)
    ax.plot([R.min(), R.max()], [R.min(), R.max()], 'r--')
    
    if log:
        ax.set_xscale('log')
        ax.set_yscale('log')
        ax.set_xlabel('Original (log scale)')
        ax.set_ylabel('Predicted (log scale)')
    else:
        ax.set_xlabel('Original')
        ax.set_ylabel('Predicted')
    
    ax.set_title('Original vs Predicted Matrix Entries')

    if ax is None:
        plt.show()


def plot_hist_residuals(R, R_hat, ax=None):
    if ax is None:
        fig, ax = plt.subplots(figsize=(5, 3))
    
    residuals = R - R_hat
    sns.histplot(residuals.flatten(), bins=50, kde=True, color="black", ax=ax)
    ax.set_xlabel('Residual')
    ax.set_title('Distribution of Prediction Errors')

    if ax is None:
        plt.show()


def plot_residuals_vs_original(R, R_hat, ax=None):
    if ax is None:
        fig, ax = plt.subplots(figsize=(5, 3))
    
    R_flat = R.flatten()
    residuals = R_flat - R_hat.flatten()
    
    ax.scatter(R_flat, residuals, alpha=0.5)
    ax.axhline(0, color='r', linestyle='--')
    #ax.set_xscale('log')
    ax.set_xlabel('Original Value')
    ax.set_ylabel('Residual (Original - Predicted)')
    ax.set_title('Residuals vs Original Values')

    if ax is None:
        plt.show()

# %%
def plot_full_grid(R_short, Rhat_short, R_long, Rhat_long, quantile, duration):

    # --- Create 4-row grid: 2 heatmap rows, 1 short colorbar row, 1 diagnostics row ---
    fig, axes = plt.subplots(
        4, 3, figsize=(12, 10),
        gridspec_kw={'height_ratios': [1, 1, 0.15, 0.8], 'hspace': 0.5, 'wspace': 0.5}
    )
    plt.suptitle(f"Matrix Factorization Results — Quantile {quantile}, Duration {duration}s",
                 fontsize=14, fontweight='bold')

    # --- Color normalization ---
    cmap_original = 'Greens'
    cmap_predicted = 'Purples'
    cmap_residuals = 'coolwarm'
    vmin_orig, vmax_orig = -.05, 5.05
    vmin_pred, vmax_pred = -.05, 5.05
    vmin_res, vmax_res = -1, 1

    # === 1. SHORT VIDEOS HEATMAPS ===
    sns.heatmap(R_short, ax=axes[0, 0], cmap=cmap_original, vmin=vmin_orig, vmax=vmax_orig, cbar=False)
    axes[0, 0].set_title('Original (Short)')
    sns.heatmap(Rhat_short, ax=axes[0, 1], cmap=cmap_predicted, vmin=vmin_pred, vmax=vmax_pred, cbar=False)
    axes[0, 1].set_title('Predicted (Short)')
    sns.heatmap(R_short - Rhat_short, ax=axes[0, 2], cmap=cmap_residuals, center=0,
                vmin=vmin_res, vmax=vmax_res, cbar=False)
    axes[0, 2].set_title('Residuals (Short)')

    # === 2. LONG VIDEOS HEATMAPS ===
    sns.heatmap(R_long, ax=axes[1, 0], cmap=cmap_original, vmin=vmin_orig, vmax=vmax_orig, cbar=False)
    axes[1, 0].set_title('Original (Long)')
    sns.heatmap(Rhat_long, ax=axes[1, 1], cmap=cmap_predicted, vmin=vmin_pred, vmax=vmax_pred, cbar=False)
    axes[1, 1].set_title('Predicted (Long)')
    sns.heatmap(R_long - Rhat_long, ax=axes[1, 2], cmap=cmap_residuals, center=0,
                vmin=vmin_res, vmax=vmax_res, cbar=False)
    axes[1, 2].set_title('Residuals (Long)')

    # === 3. COLORBARS IN THIRD ROW (short height, keep ticks and numbers, no label) ===
    sm_orig = ScalarMappable(cmap=cmap_original, norm=mcolors.Normalize(vmin=vmin_orig, vmax=vmax_orig))
    sm_pred = ScalarMappable(cmap=cmap_predicted, norm=mcolors.Normalize(vmin=vmin_pred, vmax=vmax_pred))
    sm_res = ScalarMappable(cmap=cmap_residuals, norm=mcolors.Normalize(vmin=vmin_res, vmax=vmax_res))

    for i, sm in enumerate([sm_orig, sm_pred, sm_res]):
        cbar_ax = axes[2, i]
        plt.colorbar(sm, cax=cbar_ax, orientation='horizontal')
        cbar_ax.tick_params(axis='x')  # optional: adjust tick size
        # Do NOT set xlabel → removes label, keeps ticks and numbers

    # === 4. DIAGNOSTIC PLOTS ===
    x_short = R_short.flatten()
    y_short = Rhat_short.flatten()
    x_long = R_long.flatten() + 0.05
    y_long = Rhat_long.flatten()
    res_short = (R_short - Rhat_short).flatten()
    res_long = (R_long - Rhat_long).flatten()

    # (a) Original vs Predicted
    axes[3, 0].scatter(x_short, y_short, alpha=0.25, label="Short", color='green', s=10)
    axes[3, 0].scatter(x_long, y_long, alpha=0.25, label="Long", color='purple', s=10)
    axes[3, 0].plot([0, 5], [0, 5], 'r--')
    axes[3, 0].set_xlabel('Original')
    axes[3, 0].set_ylabel('Predicted')
    axes[3, 0].set_title('Original vs Predicted')
    axes[3, 0].legend()

    # (b) Histogram of residuals
    sns.histplot(res_short, bins=50, kde=True, ax=axes[3, 1], color='green', label='Short', alpha=0.4)
    sns.histplot(res_long, bins=50, kde=True, ax=axes[3, 1], color='purple', label='Long', alpha=0.4)
    axes[3, 1].set_title('Residual Distribution')
    axes[3, 1].set_xlabel('Residual (Original - Predicted)')
    axes[3, 1].legend()

    # (c) Residuals vs Original
    axes[3, 2].scatter(x_short, res_short, alpha=0.25, color='green', label='Short', s=10)
    axes[3, 2].scatter(x_long, res_long, alpha=0.25, color='purple', label='Long', s=10)
    axes[3, 2].axhline(0, color='r', linestyle='--')
    axes[3, 2].set_xticks([0, 5])
    axes[3, 2].set_xlabel('Original Value')
    axes[3, 2].set_ylabel('Residual')
    axes[3, 2].set_title('Residuals vs Original')
    axes[3, 2].legend()

    plt.show()

# %%
def plots_mf_and_results(data, param_grid, data_with_video_duration):
    results = []
    
    # All videos
    R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_normalized = grid_search_mf_bias(data, param_grid, print_info=False)
    
    plot_scatter_entries(R_test, R_estimated)
    plot_heatmap_residuals(R_test, R_estimated)
    plot_hist_residuals(R_test, R_estimated)
    plot_residuals_vs_original(R_test, R_estimated)
    
    results.append({
        "quantile": 1.0,
        "duration": np.nan,
        "type": "all",
        "ndcg": ndcg,
        "k_ndcg": k_ndcg,
        "rmse": rmse,
        "rmse_norm": rmse_normalized
    })

    quantiles = [0.2, 0.25, 0.5, 0.75, 0.8]
    
    for q in quantiles:
        t = int(data_with_video_duration[["video_duration"]].quantile(q).iloc[0])
        video_ids_up_ts, video_ids_more_ts = select_short_videos(data_with_video_duration, time=t, col="video_duration")

        # Short videos
        data_up_ts = data[data["video_id"].isin(video_ids_up_ts)]
        R_short, Rhat_short, ndcg_s, k_ndcg_s, rmse_s, rmse_norm_s = grid_search_mf_bias(data_up_ts, param_grid, print_info=False)
        results.append({"quantile": q, "duration": t, "type": "short", "ndcg": ndcg_s, "k_ndcg": k_ndcg_s, "rmse": rmse_s, "rmse_norm": rmse_norm_s})
        
        # Long videos
        data_more_ts = data[data["video_id"].isin(video_ids_more_ts)]
        R_long, Rhat_long, ndcg_l, k_ndcg_l, rmse_l, rmse_norm_l = grid_search_mf_bias(data_more_ts, param_grid, print_info=False)
        results.append({"quantile": q, "duration": t, "type": "long", "ndcg": ndcg_l, "k_ndcg": k_ndcg_l, "rmse": rmse_l, "rmse_norm": rmse_norm_l})
        
    
        # Plot both sets together in a single figure
        plot_full_grid(R_short, Rhat_short, R_long, Rhat_long, quantile=q, duration=t)

    return pd.DataFrame(results)

# %%
def plot_metric_bars(metric_name, short_vals, long_vals, all_vals, x, labels, quantiles, bar_width=0.35, ylim=None, note=None):
    plt.figure(figsize=(8, 5))
    
    # Bars
    plt.bar(x[:len(quantiles)] - bar_width/2, short_vals[metric_name], width=bar_width, label='Short Videos', color="#fdae6b")
    plt.bar(x[:len(quantiles)] + bar_width/2, long_vals[metric_name], width=bar_width, label='Long Videos', color="#f16913")
        
    # All videos bar and reference line
    plt.bar(x[-1], all_vals[metric_name], width=bar_width, color='#a63603', label='All Videos')
    plt.axhline(all_vals[metric_name], color='gray', linestyle='--', linewidth=1.2)
    
    # Axes and layout
    plt.xticks(x, labels)
    plt.xlabel("Quantile (Video Duration)")
    plt.ylabel(metric_name.replace("_", " ").upper())
    if ylim:
        plt.ylim(*ylim)
    plt.legend()
    plt.tight_layout()

    plt.savefig(f"figs/mf/{note}-{metric_name}.pdf", bbox_inches='tight', dpi=300)
    plt.show()
    
def plot_mf_summary(df_results, note=None):
    quantiles = [0.2, 0.25, 0.5, 0.75, 0.8]
    
    # Custom x-axis labels: "quantile (duration)" + "All"
    labels = [f"{q} ({int(df_results[df_results['Quantile']==q]['Duration'].iloc[0])}s)" for q in quantiles] + ["All"]
    x = np.arange(len(labels))
    bar_width = 0.35
    
    # Extract values
    long_vals = df_results[df_results["Type"]=="long"][["Quantile","ndcg","rmse","rmse_norm","F1 score", "avg_ndcg_loo", "rmse_loo", "rmse_normalized_loo"]].sort_values("Quantile")
    short_vals = df_results[df_results["Type"]=="short"][["Quantile","ndcg","rmse","rmse_norm","F1 score", "avg_ndcg_loo", "rmse_loo", "rmse_normalized_loo"]].sort_values("Quantile")
    
    all_vals = df_results[df_results["Type"]=="all"][["ndcg","rmse","rmse_norm", "F1 score", "avg_ndcg_loo", "rmse_loo", "rmse_normalized_loo"]].iloc[0]

    plot_metric_bars("ndcg", short_vals, long_vals, all_vals, x, labels, quantiles, ylim=(0, df_results["ndcg"].max().round(1) + 0.3), note=note) #or 1.3 or 1.2
    plot_metric_bars("rmse_norm", short_vals, long_vals, all_vals, x, labels, quantiles, ylim=(0, df_results["rmse_norm"].max().round(1) + 0.2), note=note) #or 3 or 1.4
    plot_metric_bars("rmse", short_vals, long_vals, all_vals, x, labels, quantiles, ylim=(0, df_results["rmse"].max().round(1) + 0.1), note=note) #or 3.5 or 0.7
    plot_metric_bars("F1 score", short_vals, long_vals, all_vals, x, labels, quantiles, ylim=(0, df_results["F1 score"].max().round(1) + 0.1), note=note)
    plot_metric_bars("avg_ndcg_loo", short_vals, long_vals, all_vals, x, labels, quantiles, ylim=(0, df_results["avg_ndcg_loo"].max().round(1) + 0.1), note=note)
    plot_metric_bars("rmse_loo", short_vals, long_vals, all_vals, x, labels, quantiles, ylim=(0, df_results["rmse_loo"].max().round(1) + 0.1), note=note)
    plot_metric_bars("rmse_normalized_loo", short_vals, long_vals, all_vals, x, labels, quantiles, ylim=(0, df_results["rmse_normalized_loo"].max().round(1) + 0.1), note=note)

# %%
def summary_plot_ratings(df):

    df_wide = df.pivot_table(index="user_id", columns="video_id", values="rating")

    # Count ratings per user
    user_counts = df_wide.notna().sum(axis=1)
    most_active_user = user_counts.idxmax()
    ratings_by_most_active = user_counts.max()
    
    # Count ratings per video
    video_counts = df_wide.notna().sum(axis=0)
    most_rated_video = video_counts.idxmax()
    ratings_on_most_rated = video_counts.max()
    
    print(f"Most active user: {most_active_user} ({ratings_by_most_active} ratings)")
    print(f"Most rated video: {most_rated_video} ({ratings_on_most_rated} ratings)")
    
    # Optional: convert to numpy arrays if needed
    n_ratings_per_user = user_counts.values
    n_ratings_per_movie = video_counts.values
    
    # Now you can plot
    plt.figure(figsize=(16,4))
    
    plt.subplot(1,2,1)
    sns.kdeplot(n_ratings_per_user, fill=True)
    plt.xlim(0)
    plt.title("Number of Ratings Per User", fontsize=14)
    plt.xlabel("number of ratings per user")
    plt.ylabel("density")
    
    plt.subplot(1,2,2)
    sns.kdeplot(n_ratings_per_movie, fill=True)
    plt.xlim(0)
    plt.title("Number of Ratings Per Item", fontsize=14)
    plt.xlabel("number of ratings per item")
    plt.ylabel("density")
    
    plt.show()

# %%
def plot_confusion_matrix_ratings(R_test, R_estimated, title="Confusion Matrix (0–5 Ratings)"):
    """
    Converts predicted ratings to categories (0–5) and plots confusion matrix.
    Computes accuracy, precision, recall, and F1 score.
    
    R_test: ground truth user-item matrix (test split)
    R_estimated: predicted ratings matrix
    """
    # Mask only observed entries in test set
    mask = R_test > 0
    y_true = R_test[mask].flatten()
    y_pred = R_estimated[mask].flatten()

    # Clip predictions to range 0–5
    y_pred = np.clip(y_pred, 0, 5)

    # Round to closest integer rating
    y_true_cat = np.round(y_true).astype(int)
    y_pred_cat = np.round(y_pred).astype(int)

    # Compute confusion matrix
    labels = [0, 1, 2, 3, 4, 5]
    cm = confusion_matrix(y_true_cat, y_pred_cat, labels=labels)
    # Normalize to get percentages
    cm_percent = cm.astype('float') / cm.sum() * 100

    # Compute classification metrics
    accuracy = accuracy_score(y_true_cat, y_pred_cat)
    precision = precision_score(y_true_cat, y_pred_cat, average='macro', zero_division=0)
    recall = recall_score(y_true_cat, y_pred_cat, average='macro', zero_division=0)
    f1 = f1_score(y_true_cat, y_pred_cat, average='macro', zero_division=0)

    print(f"Test size: {len(y_true)}")
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision (macro): {precision:.4f}")
    print(f"Recall (macro): {recall:.4f}")
    print(f"F1 Score (macro): {f1:.4f}")

    # Plot confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    fig, ax = plt.subplots(figsize=(6, 5))
    disp.plot(cmap='Blues', xticks_rotation=45, ax=ax)
    
    # Add percentages to each cell
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            text = f"\n\n({cm_percent[i, j]:.1f}%)"
            ax.text(j, i, text,
                    ha="center", va="center",
                    color="black", fontsize=9)
    
    plt.title(title)
    plt.xlabel("Predicted Rating")
    plt.ylabel("True Rating")
    plt.grid(False)
    plt.show()

    return cm, accuracy, precision, recall, f1

# %% [markdown]
# # Dataset

# %% [markdown]
# ## TikTok Experiment setup

# %%
df_tiktok_exp = pd.read_csv("data/mf_perc_experiment.csv", index_col=0)
df_tiktok_exp.head(5)
# Out:
#    video_id  user_id  video_duration  percentage_watched
# 0         0      169            24.0               100.0
# 1         1      169             9.0                33.0
# 2         2      169           470.0                 3.0
# 3         3      169           331.0                34.0
# 4         4      169            16.0                81.0

# %%
df_mf_tiktok_exp = df_tiktok_exp.loc[:,["video_id", "user_id", "percentage_watched"]]

# %% [markdown]
# ### Rating 1-5

# %%
df_mf_tiktok_exp = df_mf_tiktok_exp.rename(columns={"percentage_watched": "rating"})
df_mf_tiktok_exp["rating"] = df_mf_tiktok_exp["rating"].clip(0, 100)
df_mf_tiktok_exp["rating"] = round((df_mf_tiktok_exp["rating"]/100) * 4 + 1, 0) #rating 1-5

# %%
df_mf_tiktok_exp[["rating"]].hist(figsize=(5,2))
plt.title("Distribution of video percentage watched \"rating\"")
# Out:
# Text(0.5, 1.0, 'Distribution of video percentage watched "rating"')

# %%
_ = calculate_density(df_mf_tiktok_exp)
# Out:
# Users: 80, Videos: 105
# Observed interactions: 5135
# Density: 0.6113
# Sparsity: 0.3887

# %%
summary_plot_ratings(df_mf_tiktok_exp)
# Out:
# Most active user: 95 (105 ratings)
# Most rated video: 0 (80 ratings)

# %% [markdown]
# ### Split short vs. long videos

# %%
def select_short_videos (df, time=100, col="video_duration"):
    video_ids_up_ts = df[df[col] <= time]["video_id"].tolist()
    video_ids_more_ts = df[df[col] > time]["video_id"].tolist()

    return video_ids_up_ts, video_ids_more_ts

# %%
df_tiktok_exp[["video_duration"]].describe()
# Out:
#        video_duration
# count     5135.000000
# mean        74.080039
# std         99.895937
# min          5.000000
# 25%         13.000000
# 50%         39.000000
# 75%         70.000000
# max        489.000000

# %%
df_tiktok_exp[["video_duration"]].hist(figsize=(5,2))
plt.title("Distribution of video duration")
# Out:
# Text(0.5, 1.0, 'Distribution of video duration')

# %% [markdown]
# # Run MF

# %% [markdown]
# ### TikTok Experiment data

# %%
_ = calculate_density(df_mf_tiktok_exp)
# Out:
# Users: 80, Videos: 105
# Observed interactions: 5135
# Density: 0.6113
# Sparsity: 0.3887

# %%
df_mf_tiktok_exp.head()
# Out:
#    video_id  user_id  rating
# 0         0      169     5.0
# 1         1      169     2.0
# 2         2      169     1.0
# 3         3      169     2.0
# 4         4      169     4.0

# %%
param_grid = {
    'n_components': [2, 5, 10, 20, 50],
    'max_iter': [1000, 2000, 3000],
    'init': ['random'],
    'model_type': ['svd'],
    'n_iter': [1, 3, 5, 10, 15]
}

R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_normalized, best_param = grid_search_mf_bias(df_mf_tiktok_exp, param_grid, print_info=False)
# Out:
# (5135, 3) (4086, 3) (1049, 3)
# cold items [104]
# 4087 1048 1027.0
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 10}
# ✅ Best RMSE on TEST: 1.3325, NDCG@3: 0.8872 (len:80), normalized RMSE: 1.3325
#
# 📈 Explained Variance (for best SVD only): 0.2798844994489716
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None

# %%
cm_exp, accuracy_exp, precision_exp, recall_exp, f1_exp = plot_confusion_matrix_ratings(R_test, R_estimated)
# Out:
# Test size: 1048
# Accuracy: 0.3731
# Precision (macro): 0.3477
# Recall (macro): 0.3011
# F1 Score (macro): 0.2874

# %%
best_metrics = grid_search_mf_bias_loou_ndcg(df_mf_tiktok_exp, best_param)
# Out:
# (5135, 3)
# (5135, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 10} ===
#   Left-out user 48: NDCG@10=0.7969, n_test_items=38
#   Left-out user 53: NDCG@10=0.8871, n_test_items=68
#   Left-out user 84: NDCG@10=0.9216, n_test_items=50
#   Left-out user 95: NDCG@10=0.8108, n_test_items=105
#   Left-out user 115: NDCG@10=0.7625, n_test_items=105
#   Left-out user 135: NDCG@10=0.8116, n_test_items=37
#   Left-out user 146: NDCG@10=0.8953, n_test_items=43
#   Left-out user 147: NDCG@10=0.6871, n_test_items=105
#   Left-out user 155: NDCG@10=0.7691, n_test_items=39
#   Left-out user 169: NDCG@10=0.7837, n_test_items=90
#   Left-out user 175: NDCG@10=0.8686, n_test_items=43
#   Left-out user 246: NDCG@10=0.5583, n_test_items=21
#   Left-out user 270: NDCG@10=0.9686, n_test_items=70
#   Left-out user 272: NDCG@10=0.5583, n_test_items=25
#   Left-out user 280: NDCG@10=0.9696, n_test_items=58
#   Left-out user 293: NDCG@10=0.9216, n_test_items=54
#   Left-out user 297: NDCG@10=0.5583, n_test_items=23
#   Left-out user 299: NDCG@10=0.8116, n_test_items=34
#   Left-out user 359: NDCG@10=0.7628, n_test_items=40
#   Left-out user 363: NDCG@10=0.7913, n_test_items=105
#   Left-out user 388: NDCG@10=0.9359, n_test_items=72
#   Left-out user 402: NDCG@10=0.8967, n_test_items=45
#   Left-out user 437: NDCG@10=0.5583, n_test_items=23
#   Left-out user 440: NDCG@10=0.7965, n_test_items=72
#   Left-out user 442: NDCG@10=0.5827, n_test_items=105
#   Left-out user 443: NDCG@10=0.8285, n_test_items=63
#   Left-out user 447: NDCG@10=0.9231, n_test_items=105
#   Left-out user 456: NDCG@10=0.7766, n_test_items=53
#   Left-out user 465: NDCG@10=0.8189, n_test_items=105
#   Left-out user 485: NDCG@10=0.9489, n_test_items=98
#   Left-out user 489: NDCG@10=1.0000, n_test_items=85
#   Left-out user 494: NDCG@10=0.8303, n_test_items=48
#   Left-out user 499: NDCG@10=0.9216, n_test_items=44
#   Left-out user 501: NDCG@10=0.7597, n_test_items=105
#   Left-out user 502: NDCG@10=0.8842, n_test_items=63
#   Left-out user 510: NDCG@10=0.9526, n_test_items=65
#   Left-out user 516: NDCG@10=0.5444, n_test_items=25
#   Left-out user 533: NDCG@10=0.8131, n_test_items=105
#   Left-out user 560: NDCG@10=0.9502, n_test_items=105
#   Left-out user 561: NDCG@10=0.9216, n_test_items=44
#   Left-out user 566: NDCG@10=0.8763, n_test_items=46
#   Left-out user 594: NDCG@10=0.9196, n_test_items=73
#   Left-out user 605: NDCG@10=0.7556, n_test_items=81
#   Left-out user 611: NDCG@10=0.7820, n_test_items=79
#   Left-out user 653: NDCG@10=0.8116, n_test_items=34
#   Left-out user 663: NDCG@10=0.5583, n_test_items=23
#   Left-out user 679: NDCG@10=1.0000, n_test_items=94
#   Left-out user 688: NDCG@10=0.8785, n_test_items=105
#   Left-out user 690: NDCG@10=0.9383, n_test_items=63
#   Left-out user 702: NDCG@10=0.8752, n_test_items=94
#   Left-out user 722: NDCG@10=0.7328, n_test_items=60
#   Left-out user 731: NDCG@10=0.7314, n_test_items=105
#   Left-out user 732: NDCG@10=0.7488, n_test_items=97
#   Left-out user 766: NDCG@10=0.0636, n_test_items=13
#   Left-out user 776: NDCG@10=0.7132, n_test_items=105
#   Left-out user 778: NDCG@10=0.9216, n_test_items=51
#   Left-out user 780: NDCG@10=0.8145, n_test_items=96
#   Left-out user 783: NDCG@10=0.7078, n_test_items=105
#   Left-out user 786: NDCG@10=0.5914, n_test_items=30
#   Left-out user 788: NDCG@10=0.5583, n_test_items=23
#   Left-out user 802: NDCG@10=0.9216, n_test_items=46
#   Left-out user 814: NDCG@10=0.9069, n_test_items=48
#   Left-out user 815: NDCG@10=0.9686, n_test_items=76
#   Left-out user 823: NDCG@10=0.9216, n_test_items=49
#   Left-out user 824: NDCG@10=0.2025, n_test_items=16
#   Left-out user 826: NDCG@10=0.7412, n_test_items=34
#   Left-out user 842: NDCG@10=0.7939, n_test_items=105
#   Left-out user 844: NDCG@10=0.8729, n_test_items=52
#   Left-out user 853: NDCG@10=0.9751, n_test_items=75
#   Left-out user 867: NDCG@10=0.9216, n_test_items=53
#   Left-out user 874: NDCG@10=0.8116, n_test_items=34
#   Left-out user 882: NDCG@10=0.8397, n_test_items=45
#   Left-out user 883: NDCG@10=0.9621, n_test_items=56
#   Left-out user 891: NDCG@10=0.9301, n_test_items=75
#   Left-out user 895: NDCG@10=0.7696, n_test_items=37
#   Left-out user 907: NDCG@10=0.9843, n_test_items=100
#   Left-out user 925: NDCG@10=0.9513, n_test_items=61
#   Left-out user 934: NDCG@10=0.8934, n_test_items=58
#   Left-out user 954: NDCG@10=0.9069, n_test_items=50
#   Left-out user 960: NDCG@10=0.7788, n_test_items=105
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 10} -> Avg NDCG@10: 0.8071, RMSE: 1.3202, RMSE_norm: 0.7879323028605573

# %%
best_metrics
# Out:
# {'avg_ndcg_loo': 0.8071340084820692,
#  'k_ndcg_loo': 10,
#  'rmse_loo': 1.3201712937553562,
#  'rmse_normalized_loo': 0.7879323028605573,
#  'num_users_loo': 80}

# %%
latex_code = generate_latex_table(df_mf_tiktok_exp, df_tiktok_exp)
print(latex_code)
# Out:
# Density all 0.6113095238095239
# \begin{table}
# \caption{Dataset Statistics}
# \label{tab:dataset_stats}
# \begin{tabular}{lrrrrrrr}
# \toprule
# Dataset & Size & Density & 1 & 2 & 3 & 4 & 5 \\
# \midrule
# All & 5135 & 0.611 & 1507 (29.3%) & 961 (18.7%) & 656 (12.8%) & 463 (9.0%) & 1948 (37.9%) \\
# Short Q0.2 (12s) & 1105 & 0.628 & 118 (10.7%) & 142 (12.9%) & 165 (14.9%) & 105 (9.5%) & 655 (59.3%) \\
# Long Q0.2 (12s) & 4030 & 0.607 & 1389 (34.5%) & 819 (20.3%) & 491 (12.2%) & 358 (8.9%) & 1293 (32.1%) \\
# Short Q0.25 (13s) & 1365 & 0.656 & 122 (8.9%) & 179 (13.1%) & 215 (15.8%) & 140 (10.3%) & 789 (57.8%) \\
# Long Q0.25 (13s) & 3770 & 0.597 & 1385 (36.7%) & 782 (20.7%) & 441 (11.7%) & 323 (8.6%) & 1159 (30.7%) \\
# Short Q0.5 (39s) & 2612 & 0.695 & 286 (10.9%) & 389 (14.9%) & 365 (14.0%) & 326 (12.5%) & 1406 (53.8%) \\
# Long Q0.5 (39s) & 2523 & 0.544 & 1221 (48.4%) & 572 (22.7%) & 291 (11.5%) & 137 (5.4%) & 542 (21.5%) \\
# Short Q0.75 (70s) & 3888 & 0.639 & 736 (18.9%) & 648 (16.7%) & 506 (13.0%) & 416 (10.7%) & 1742 (44.8%) \\
# Long Q0.75 (70s) & 1247 & 0.537 & 771 (61.8%) & 313 (25.1%) & 150 (12.0%) & 47 (3.8%) & 206 (16.5%) \\
# Short Q0.8 (96s) & 4148 & 0.610 & 877 (21.1%) & 707 (17.0%) & 518 (12.5%) & 429 (10.3%) & 1777 (42.8%) \\
# Long Q0.8 (96s) & 987 & 0.617 & 630 (63.8%) & 254 (25.7%) & 138 (14.0%) & 34 (3.4%) & 171 (17.3%) \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
#✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 10}
#✅ Best RMSE on TEST: 1.3325, NDCG@3: 0.8872, normalized RMSE: 1.3325
param_grid = {
    'n_components': [2, 5, 10, 20],
    'max_iter': [1000, 2000, 3000],
    'init': ['random'],
    'model_type': ['svd'],
    'n_iter': [1, 3, 5, 10, 15]
}


results_exp = []
results_combine = []

R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_normalized, best_param = grid_search_mf_bias(df_mf_tiktok_exp, param_grid, print_info=False)
print("All videos")
cm, acc, pre, rec, f1s = plot_confusion_matrix_ratings(R_test, R_estimated)
best_metrics = grid_search_mf_bias_loou_ndcg(df_mf_tiktok_exp, best_param)

d = {"Data": "TikTok Experiment",
    "Quantile": 1.0, 
    "Duration": np.nan, 
    "Type": "all", 
    "Accuracy": accuracy_exp, 
    "Precision": precision_exp, 
    "Recall": recall_exp, 
    "F1 score": f1_exp,
    "ndcg": ndcg,
    "k_ndcg": k_ndcg,
    "rmse": rmse,
    "rmse_norm": rmse_normalized
}
d.update(best_metrics)
results_exp.append(d)

d = {"Data": "TikTok Experiment", 
    "Accuracy": acc, 
    "Precision": pre, 
    "Recall": rec, 
    "F1 score": f1s,
    "ndcg": ndcg,
    "k_ndcg": k_ndcg,
    "rmse": rmse,
    "rmse_norm": rmse_normalized,
    "density": calculate_density(df_mf_tiktok_exp)
}
d.update(best_metrics)
results_combine.append(d)


for q in [0.2, 0.25, 0.5, 0.75, 0.8]:
    t = int(df_tiktok_exp[["video_duration"]].quantile(q).iloc[0])
    print(f"Time split: {t}")
    video_ids_up_ts, video_ids_more_ts = select_short_videos(df_tiktok_exp, time=t, col="video_duration")

    data_up_ts = df_mf_tiktok_exp[df_mf_tiktok_exp["video_id"].isin(video_ids_up_ts)]
    R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_normalized, best_param = grid_search_mf_bias(data_up_ts, param_grid, print_info=False)
    print("Short videos")
    cm, acc, pre, rec, f1s = plot_confusion_matrix_ratings(R_test, R_estimated)
    best_metrics = grid_search_mf_bias_loou_ndcg(data_up_ts, best_param)

    d = {"Data": "TikTok Experiment", "Quantile": q, "Duration": t, "Type": "short", 
    "Accuracy": acc, 
    "Precision": pre, 
    "Recall": rec, 
    "F1 score": f1s,
    "ndcg": ndcg,
    "k_ndcg": k_ndcg,
    "rmse": rmse,
    "rmse_norm": rmse_normalized
    }
    d.update(best_metrics)
    results_exp.append(d)
    
    
    data_more_ts = df_mf_tiktok_exp[df_mf_tiktok_exp["video_id"].isin(video_ids_more_ts)]
    R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_normalized, best_param = grid_search_mf_bias(data_more_ts, param_grid, print_info=False)
    print("Long videos")
    cm, acc, pre, rec, f1s = plot_confusion_matrix_ratings(R_test, R_estimated)
    best_metrics = grid_search_mf_bias_loou_ndcg(data_more_ts, best_param)
    d = {"Data": "TikTok Experiment", "Quantile": q, "Duration": t, "Type": "long", 
    "Accuracy": acc, 
    "Precision": pre, 
    "Recall": rec, 
    "F1 score": f1s,
    "ndcg": ndcg,
    "k_ndcg": k_ndcg,
    "rmse": rmse,
    "rmse_norm": rmse_normalized
    }
    d.update(best_metrics)
    results_exp.append(d)
# Out:
# (5135, 3) (4086, 3) (1049, 3)
# cold items [104]
# 4087 1048 1027.0
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 10}
# ✅ Best RMSE on TEST: 1.3325, NDCG@3: 0.8872 (len:80), normalized RMSE: 1.3325
#
# 📈 Explained Variance (for best SVD only): 0.2798844994489716
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# All videos
# Test size: 1048
# Accuracy: 0.3731
# Precision (macro): 0.3477
# Recall (macro): 0.3011
# F1 Score (macro): 0.2874
# (5135, 3)
# (5135, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 10} ===
#   Left-out user 48: NDCG@10=0.7969, n_test_items=38
#   Left-out user 53: NDCG@10=0.8871, n_test_items=68
#   Left-out user 84: NDCG@10=0.9216, n_test_items=50
#   Left-out user 95: NDCG@10=0.8108, n_test_items=105
#   Left-out user 115: NDCG@10=0.7625, n_test_items=105
#   Left-out user 135: NDCG@10=0.8116, n_test_items=37
#   Left-out user 146: NDCG@10=0.8953, n_test_items=43
#   Left-out user 147: NDCG@10=0.6871, n_test_items=105
#   Left-out user 155: NDCG@10=0.7691, n_test_items=39
#   Left-out user 169: NDCG@10=0.7837, n_test_items=90
#   Left-out user 175: NDCG@10=0.8686, n_test_items=43
#   Left-out user 246: NDCG@10=0.5583, n_test_items=21
#   Left-out user 270: NDCG@10=0.9686, n_test_items=70
#   Left-out user 272: NDCG@10=0.5583, n_test_items=25
#   Left-out user 280: NDCG@10=0.9696, n_test_items=58
#   Left-out user 293: NDCG@10=0.9216, n_test_items=54
#   Left-out user 297: NDCG@10=0.5583, n_test_items=23
#   Left-out user 299: NDCG@10=0.8116, n_test_items=34
#   Left-out user 359: NDCG@10=0.7628, n_test_items=40
#   Left-out user 363: NDCG@10=0.7913, n_test_items=105
#   Left-out user 388: NDCG@10=0.9359, n_test_items=72
#   Left-out user 402: NDCG@10=0.8967, n_test_items=45
#   Left-out user 437: NDCG@10=0.5583, n_test_items=23
#   Left-out user 440: NDCG@10=0.7965, n_test_items=72
#   Left-out user 442: NDCG@10=0.5827, n_test_items=105
#   Left-out user 443: NDCG@10=0.8285, n_test_items=63
#   Left-out user 447: NDCG@10=0.9231, n_test_items=105
#   Left-out user 456: NDCG@10=0.7766, n_test_items=53
#   Left-out user 465: NDCG@10=0.8189, n_test_items=105
#   Left-out user 485: NDCG@10=0.9489, n_test_items=98
#   Left-out user 489: NDCG@10=1.0000, n_test_items=85
#   Left-out user 494: NDCG@10=0.8303, n_test_items=48
#   Left-out user 499: NDCG@10=0.9216, n_test_items=44
#   Left-out user 501: NDCG@10=0.7597, n_test_items=105
#   Left-out user 502: NDCG@10=0.8842, n_test_items=63
#   Left-out user 510: NDCG@10=0.9526, n_test_items=65
#   Left-out user 516: NDCG@10=0.5444, n_test_items=25
#   Left-out user 533: NDCG@10=0.8131, n_test_items=105
#   Left-out user 560: NDCG@10=0.9502, n_test_items=105
#   Left-out user 561: NDCG@10=0.9216, n_test_items=44
#   Left-out user 566: NDCG@10=0.8763, n_test_items=46
#   Left-out user 594: NDCG@10=0.9196, n_test_items=73
#   Left-out user 605: NDCG@10=0.7556, n_test_items=81
#   Left-out user 611: NDCG@10=0.7820, n_test_items=79
#   Left-out user 653: NDCG@10=0.8116, n_test_items=34
#   Left-out user 663: NDCG@10=0.5583, n_test_items=23
#   Left-out user 679: NDCG@10=1.0000, n_test_items=94
#   Left-out user 688: NDCG@10=0.8785, n_test_items=105
#   Left-out user 690: NDCG@10=0.9383, n_test_items=63
#   Left-out user 702: NDCG@10=0.8752, n_test_items=94
#   Left-out user 722: NDCG@10=0.7328, n_test_items=60
#   Left-out user 731: NDCG@10=0.7314, n_test_items=105
#   Left-out user 732: NDCG@10=0.7488, n_test_items=97
#   Left-out user 766: NDCG@10=0.0636, n_test_items=13
#   Left-out user 776: NDCG@10=0.7132, n_test_items=105
#   Left-out user 778: NDCG@10=0.9216, n_test_items=51
#   Left-out user 780: NDCG@10=0.8145, n_test_items=96
#   Left-out user 783: NDCG@10=0.7078, n_test_items=105
#   Left-out user 786: NDCG@10=0.5914, n_test_items=30
#   Left-out user 788: NDCG@10=0.5583, n_test_items=23
#   Left-out user 802: NDCG@10=0.9216, n_test_items=46
#   Left-out user 814: NDCG@10=0.9069, n_test_items=48
#   Left-out user 815: NDCG@10=0.9686, n_test_items=76
#   Left-out user 823: NDCG@10=0.9216, n_test_items=49
#   Left-out user 824: NDCG@10=0.2025, n_test_items=16
#   Left-out user 826: NDCG@10=0.7412, n_test_items=34
#   Left-out user 842: NDCG@10=0.7939, n_test_items=105
#   Left-out user 844: NDCG@10=0.8729, n_test_items=52
#   Left-out user 853: NDCG@10=0.9751, n_test_items=75
#   Left-out user 867: NDCG@10=0.9216, n_test_items=53
#   Left-out user 874: NDCG@10=0.8116, n_test_items=34
#   Left-out user 882: NDCG@10=0.8397, n_test_items=45
#   Left-out user 883: NDCG@10=0.9621, n_test_items=56
#   Left-out user 891: NDCG@10=0.9301, n_test_items=75
#   Left-out user 895: NDCG@10=0.7696, n_test_items=37
#   Left-out user 907: NDCG@10=0.9843, n_test_items=100
#   Left-out user 925: NDCG@10=0.9513, n_test_items=61
#   Left-out user 934: NDCG@10=0.8934, n_test_items=58
#   Left-out user 954: NDCG@10=0.9069, n_test_items=50
#   Left-out user 960: NDCG@10=0.7788, n_test_items=105
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 10} -> Avg NDCG@10: 0.8071, RMSE: 1.3202, RMSE_norm: 0.7879323028605573
# Users: 80, Videos: 105
# Observed interactions: 5135
# Density: 0.6113
# Sparsity: 0.3887
# Time split: 12
# (1105, 3) (851, 3) (254, 3)
# 851 254 221.0
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 1}
# ✅ Best RMSE on TEST: 1.1860, NDCG@3: 0.9089 (len:57), normalized RMSE: 1.1860
#
# 📈 Explained Variance (for best SVD only): 0.993028964062084
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Short videos
# Test size: 254
# Accuracy: 0.4173
# Precision (macro): 0.2623
# Recall (macro): 0.2534
# F1 Score (macro): 0.2199
# (1105, 3)
# (1105, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 1} ===
#   Left-out user 48: NDCG@10=0.8108, n_test_items=9
#   Left-out user 53: NDCG@10=0.8137, n_test_items=14
#   Left-out user 84: NDCG@10=0.8702, n_test_items=12
#   Left-out user 95: NDCG@10=0.9034, n_test_items=22
#   Left-out user 115: NDCG@10=0.8415, n_test_items=22
#   Left-out user 135: NDCG@10=0.8536, n_test_items=9
#   Left-out user 146: NDCG@10=0.8806, n_test_items=10
#   Left-out user 147: NDCG@10=0.6977, n_test_items=22
#   Left-out user 155: NDCG@10=0.8094, n_test_items=9
#   Left-out user 169: NDCG@10=0.8397, n_test_items=18
#   Left-out user 175: NDCG@10=0.8671, n_test_items=10
#   Left-out user 246: NDCG@10=0.7810, n_test_items=5
#   Left-out user 270: NDCG@10=0.9001, n_test_items=14
#   Left-out user 272: NDCG@10=0.7879, n_test_items=6
#   Left-out user 280: NDCG@10=0.9266, n_test_items=13
#   Left-out user 293: NDCG@10=0.8724, n_test_items=13
#   Left-out user 297: NDCG@10=0.7879, n_test_items=6
#   Left-out user 299: NDCG@10=0.8041, n_test_items=9
#   Left-out user 359: NDCG@10=0.7850, n_test_items=9
#   Left-out user 363: NDCG@10=0.8899, n_test_items=22
#   Left-out user 388: NDCG@10=0.8456, n_test_items=14
#   Left-out user 402: NDCG@10=0.8597, n_test_items=11
#   Left-out user 437: NDCG@10=0.8052, n_test_items=6
#   Left-out user 440: NDCG@10=0.8120, n_test_items=14
#   Left-out user 442: NDCG@10=0.7861, n_test_items=22
#   Left-out user 443: NDCG@10=0.7899, n_test_items=14
#   Left-out user 447: NDCG@10=0.9489, n_test_items=22
#   Left-out user 456: NDCG@10=0.8154, n_test_items=13
#   Left-out user 465: NDCG@10=0.8075, n_test_items=22
#   Left-out user 485: NDCG@10=1.0000, n_test_items=20
#   Left-out user 489: NDCG@10=1.0000, n_test_items=16
#   Left-out user 494: NDCG@10=0.8921, n_test_items=11
#   Left-out user 499: NDCG@10=0.8856, n_test_items=10
#   Left-out user 501: NDCG@10=0.7927, n_test_items=22
#   Left-out user 502: NDCG@10=0.7810, n_test_items=14
#   Left-out user 510: NDCG@10=0.8906, n_test_items=14
#   Left-out user 516: NDCG@10=0.7832, n_test_items=6
#   Left-out user 533: NDCG@10=0.8503, n_test_items=22
#   Left-out user 560: NDCG@10=0.9502, n_test_items=22
#   Left-out user 561: NDCG@10=0.8630, n_test_items=10
#   Left-out user 566: NDCG@10=0.9194, n_test_items=11
#   Left-out user 594: NDCG@10=0.8988, n_test_items=14
#   Left-out user 605: NDCG@10=0.8997, n_test_items=15
#   Left-out user 611: NDCG@10=0.9415, n_test_items=15
#   Left-out user 653: NDCG@10=0.8041, n_test_items=9
#   Left-out user 663: NDCG@10=0.7879, n_test_items=6
#   Left-out user 679: NDCG@10=0.9735, n_test_items=19
#   Left-out user 688: NDCG@10=0.9029, n_test_items=22
#   Left-out user 690: NDCG@10=0.8796, n_test_items=14
#   Left-out user 702: NDCG@10=0.9063, n_test_items=19
#   Left-out user 722: NDCG@10=0.7559, n_test_items=14
#   Left-out user 731: NDCG@10=0.8530, n_test_items=22
#   Left-out user 732: NDCG@10=0.7970, n_test_items=19
#   Left-out user 766: NDCG@10=0.1934, n_test_items=2
#   Left-out user 776: NDCG@10=0.8303, n_test_items=22
#   Left-out user 778: NDCG@10=0.9266, n_test_items=12
#   Left-out user 780: NDCG@10=0.8740, n_test_items=19
#   Left-out user 783: NDCG@10=0.7347, n_test_items=22
#   Left-out user 786: NDCG@10=0.7774, n_test_items=6
#   Left-out user 788: NDCG@10=0.7866, n_test_items=6
#   Left-out user 802: NDCG@10=0.9202, n_test_items=11
#   Left-out user 814: NDCG@10=0.8888, n_test_items=11
#   Left-out user 815: NDCG@10=0.9127, n_test_items=14
#   Left-out user 823: NDCG@10=0.9266, n_test_items=11
#   Left-out user 824: NDCG@10=0.4441, n_test_items=3
#   Left-out user 826: NDCG@10=0.8431, n_test_items=9
#   Left-out user 842: NDCG@10=0.9131, n_test_items=22
#   Left-out user 844: NDCG@10=0.8614, n_test_items=13
#   Left-out user 853: NDCG@10=0.9134, n_test_items=14
#   Left-out user 867: NDCG@10=0.9139, n_test_items=13
#   Left-out user 874: NDCG@10=0.8041, n_test_items=9
#   Left-out user 882: NDCG@10=0.8892, n_test_items=11
#   Left-out user 883: NDCG@10=0.9250, n_test_items=13
#   Left-out user 891: NDCG@10=0.8413, n_test_items=14
#   Left-out user 895: NDCG@10=0.8257, n_test_items=9
#   Left-out user 907: NDCG@10=0.9446, n_test_items=20
#   Left-out user 925: NDCG@10=0.9266, n_test_items=14
#   Left-out user 934: NDCG@10=0.8769, n_test_items=13
#   Left-out user 954: NDCG@10=0.8983, n_test_items=12
#   Left-out user 960: NDCG@10=0.7823, n_test_items=22
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 1} -> Avg NDCG@10: 0.8447, RMSE: 1.1795, RMSE_norm: 0.9447340940451495
# (4030, 3) (3195, 3) (835, 3)
# 3195 835 806.0
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 3}
# ✅ Best RMSE on TEST: 1.3436, NDCG@3: 0.8647 (len:80), normalized RMSE: 1.3436
#
# 📈 Explained Variance (for best SVD only): 0.1145272797551095
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Long videos
# Test size: 835
# Accuracy: 0.3102
# Precision (macro): 0.3389
# Recall (macro): 0.2717
# F1 Score (macro): 0.2509
# (4030, 3)
# (4030, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 3} ===
#   Left-out user 48: NDCG@10=0.5340, n_test_items=29
#   Left-out user 53: NDCG@10=0.9073, n_test_items=54
#   Left-out user 84: NDCG@10=0.7065, n_test_items=38
#   Left-out user 95: NDCG@10=0.5523, n_test_items=83
#   Left-out user 115: NDCG@10=0.6066, n_test_items=83
#   Left-out user 135: NDCG@10=0.6927, n_test_items=28
#   Left-out user 146: NDCG@10=0.6997, n_test_items=33
#   Left-out user 147: NDCG@10=0.6181, n_test_items=83
#   Left-out user 155: NDCG@10=0.6788, n_test_items=30
#   Left-out user 169: NDCG@10=0.6659, n_test_items=72
#   Left-out user 175: NDCG@10=0.6811, n_test_items=33
#   Left-out user 246: NDCG@10=0.4893, n_test_items=16
#   Left-out user 270: NDCG@10=0.8556, n_test_items=56
#   Left-out user 272: NDCG@10=0.4893, n_test_items=19
#   Left-out user 280: NDCG@10=0.7664, n_test_items=45
#   Left-out user 293: NDCG@10=0.6927, n_test_items=41
#   Left-out user 297: NDCG@10=0.4760, n_test_items=17
#   Left-out user 299: NDCG@10=0.6811, n_test_items=25
#   Left-out user 359: NDCG@10=0.6117, n_test_items=31
#   Left-out user 363: NDCG@10=0.7439, n_test_items=83
#   Left-out user 388: NDCG@10=0.8397, n_test_items=58
#   Left-out user 402: NDCG@10=0.6480, n_test_items=34
#   Left-out user 437: NDCG@10=0.4893, n_test_items=17
#   Left-out user 440: NDCG@10=0.6646, n_test_items=58
#   Left-out user 442: NDCG@10=0.5958, n_test_items=83
#   Left-out user 443: NDCG@10=0.7737, n_test_items=49
#   Left-out user 447: NDCG@10=0.9155, n_test_items=83
#   Left-out user 456: NDCG@10=0.6019, n_test_items=40
#   Left-out user 465: NDCG@10=0.7463, n_test_items=83
#   Left-out user 485: NDCG@10=0.8041, n_test_items=78
#   Left-out user 489: NDCG@10=0.9032, n_test_items=69
#   Left-out user 494: NDCG@10=0.6720, n_test_items=37
#   Left-out user 499: NDCG@10=0.6933, n_test_items=34
#   Left-out user 501: NDCG@10=0.6829, n_test_items=83
#   Left-out user 502: NDCG@10=0.9830, n_test_items=49
#   Left-out user 510: NDCG@10=0.9166, n_test_items=51
#   Left-out user 516: NDCG@10=0.4893, n_test_items=19
#   Left-out user 533: NDCG@10=0.7304, n_test_items=83
#   Left-out user 560: NDCG@10=0.8638, n_test_items=83
#   Left-out user 561: NDCG@10=0.7065, n_test_items=34
#   Left-out user 566: NDCG@10=0.6545, n_test_items=35
#   Left-out user 594: NDCG@10=0.6521, n_test_items=59
#   Left-out user 605: NDCG@10=0.6793, n_test_items=66
#   Left-out user 611: NDCG@10=0.7745, n_test_items=64
#   Left-out user 653: NDCG@10=0.6811, n_test_items=25
#   Left-out user 663: NDCG@10=0.4893, n_test_items=17
#   Left-out user 679: NDCG@10=0.8730, n_test_items=75
#   Left-out user 688: NDCG@10=0.6747, n_test_items=83
#   Left-out user 690: NDCG@10=0.9264, n_test_items=49
#   Left-out user 702: NDCG@10=0.7421, n_test_items=75
#   Left-out user 722: NDCG@10=0.6783, n_test_items=46
#   Left-out user 731: NDCG@10=0.6412, n_test_items=83
#   Left-out user 732: NDCG@10=0.5629, n_test_items=78
#   Left-out user 766: NDCG@10=0.2305, n_test_items=11
#   Left-out user 776: NDCG@10=0.7288, n_test_items=83
#   Left-out user 778: NDCG@10=0.7065, n_test_items=39
#   Left-out user 780: NDCG@10=0.6780, n_test_items=77
#   Left-out user 783: NDCG@10=0.7713, n_test_items=83
#   Left-out user 786: NDCG@10=0.6058, n_test_items=24
#   Left-out user 788: NDCG@10=0.4638, n_test_items=17
#   Left-out user 802: NDCG@10=0.7065, n_test_items=35
#   Left-out user 814: NDCG@10=0.6371, n_test_items=37
#   Left-out user 815: NDCG@10=0.9120, n_test_items=62
#   Left-out user 823: NDCG@10=0.6484, n_test_items=38
#   Left-out user 824: NDCG@10=0.3792, n_test_items=13
#   Left-out user 826: NDCG@10=0.6702, n_test_items=25
#   Left-out user 842: NDCG@10=0.5969, n_test_items=83
#   Left-out user 844: NDCG@10=0.6794, n_test_items=39
#   Left-out user 853: NDCG@10=0.9599, n_test_items=61
#   Left-out user 867: NDCG@10=0.6811, n_test_items=40
#   Left-out user 874: NDCG@10=0.7065, n_test_items=25
#   Left-out user 882: NDCG@10=0.6859, n_test_items=34
#   Left-out user 883: NDCG@10=0.8711, n_test_items=43
#   Left-out user 891: NDCG@10=0.8300, n_test_items=61
#   Left-out user 895: NDCG@10=0.6251, n_test_items=28
#   Left-out user 907: NDCG@10=0.9432, n_test_items=80
#   Left-out user 925: NDCG@10=0.8703, n_test_items=47
#   Left-out user 934: NDCG@10=0.7564, n_test_items=45
#   Left-out user 954: NDCG@10=0.6394, n_test_items=38
#   Left-out user 960: NDCG@10=0.6869, n_test_items=83
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 3} -> Avg NDCG@10: 0.6946, RMSE: 1.3562, RMSE_norm: 0.8113136832617149
# Time split: 13
# (1365, 3) (1053, 3) (312, 3)
# cold items [103]
# 1054 311 273.0
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 3}
# ✅ Best RMSE on TEST: 1.4145, NDCG@3: 0.9078 (len:66), normalized RMSE: 1.4145
#
# 📈 Explained Variance (for best SVD only): 0.9701082214718687
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Short videos
# Test size: 311
# Accuracy: 0.4148
# Precision (macro): 0.2797
# Recall (macro): 0.2320
# F1 Score (macro): 0.2040
# (1365, 3)
# (1365, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 3} ===
#   Left-out user 48: NDCG@10=0.7911, n_test_items=11
#   Left-out user 53: NDCG@10=0.8010, n_test_items=18
#   Left-out user 84: NDCG@10=0.8620, n_test_items=16
#   Left-out user 95: NDCG@10=0.8785, n_test_items=26
#   Left-out user 115: NDCG@10=0.7896, n_test_items=26
#   Left-out user 135: NDCG@10=0.8379, n_test_items=11
#   Left-out user 146: NDCG@10=0.8879, n_test_items=14
#   Left-out user 147: NDCG@10=0.6993, n_test_items=26
#   Left-out user 155: NDCG@10=0.7990, n_test_items=11
#   Left-out user 169: NDCG@10=0.8026, n_test_items=22
#   Left-out user 175: NDCG@10=0.8839, n_test_items=14
#   Left-out user 246: NDCG@10=0.7761, n_test_items=5
#   Left-out user 270: NDCG@10=0.9012, n_test_items=18
#   Left-out user 272: NDCG@10=0.6924, n_test_items=6
#   Left-out user 280: NDCG@10=0.9266, n_test_items=17
#   Left-out user 293: NDCG@10=0.8747, n_test_items=17
#   Left-out user 297: NDCG@10=0.6924, n_test_items=6
#   Left-out user 299: NDCG@10=0.7530, n_test_items=10
#   Left-out user 359: NDCG@10=0.7986, n_test_items=12
#   Left-out user 363: NDCG@10=0.8358, n_test_items=26
#   Left-out user 388: NDCG@10=0.7817, n_test_items=18
#   Left-out user 402: NDCG@10=0.8231, n_test_items=15
#   Left-out user 437: NDCG@10=0.7077, n_test_items=6
#   Left-out user 440: NDCG@10=0.7132, n_test_items=18
#   Left-out user 442: NDCG@10=0.7519, n_test_items=26
#   Left-out user 443: NDCG@10=0.7644, n_test_items=18
#   Left-out user 447: NDCG@10=0.9369, n_test_items=26
#   Left-out user 456: NDCG@10=0.7947, n_test_items=17
#   Left-out user 465: NDCG@10=0.7978, n_test_items=26
#   Left-out user 485: NDCG@10=0.9746, n_test_items=24
#   Left-out user 489: NDCG@10=0.9873, n_test_items=20
#   Left-out user 494: NDCG@10=0.8344, n_test_items=15
#   Left-out user 499: NDCG@10=0.9266, n_test_items=14
#   Left-out user 501: NDCG@10=0.7938, n_test_items=26
#   Left-out user 502: NDCG@10=0.7727, n_test_items=18
#   Left-out user 510: NDCG@10=0.8797, n_test_items=18
#   Left-out user 516: NDCG@10=0.6856, n_test_items=6
#   Left-out user 533: NDCG@10=0.8641, n_test_items=26
#   Left-out user 560: NDCG@10=0.9375, n_test_items=26
#   Left-out user 561: NDCG@10=0.9266, n_test_items=14
#   Left-out user 566: NDCG@10=0.8799, n_test_items=15
#   Left-out user 594: NDCG@10=0.8595, n_test_items=18
#   Left-out user 605: NDCG@10=0.8717, n_test_items=19
#   Left-out user 611: NDCG@10=0.9017, n_test_items=19
#   Left-out user 653: NDCG@10=0.7530, n_test_items=10
#   Left-out user 663: NDCG@10=0.6924, n_test_items=6
#   Left-out user 679: NDCG@10=0.9468, n_test_items=23
#   Left-out user 688: NDCG@10=0.9045, n_test_items=26
#   Left-out user 690: NDCG@10=0.8657, n_test_items=18
#   Left-out user 702: NDCG@10=0.8808, n_test_items=23
#   Left-out user 722: NDCG@10=0.6638, n_test_items=18
#   Left-out user 731: NDCG@10=0.7785, n_test_items=26
#   Left-out user 732: NDCG@10=0.7963, n_test_items=23
#   Left-out user 766: NDCG@10=0.1846, n_test_items=2
#   Left-out user 776: NDCG@10=0.7786, n_test_items=26
#   Left-out user 778: NDCG@10=0.9139, n_test_items=16
#   Left-out user 780: NDCG@10=0.8634, n_test_items=23
#   Left-out user 783: NDCG@10=0.7404, n_test_items=26
#   Left-out user 786: NDCG@10=0.6925, n_test_items=7
#   Left-out user 788: NDCG@10=0.7792, n_test_items=6
#   Left-out user 802: NDCG@10=0.8747, n_test_items=15
#   Left-out user 814: NDCG@10=0.8329, n_test_items=15
#   Left-out user 815: NDCG@10=0.9134, n_test_items=18
#   Left-out user 823: NDCG@10=0.9127, n_test_items=15
#   Left-out user 824: NDCG@10=0.4373, n_test_items=3
#   Left-out user 826: NDCG@10=0.7774, n_test_items=10
#   Left-out user 842: NDCG@10=0.9150, n_test_items=26
#   Left-out user 844: NDCG@10=0.8515, n_test_items=17
#   Left-out user 853: NDCG@10=0.8763, n_test_items=18
#   Left-out user 867: NDCG@10=0.9266, n_test_items=17
#   Left-out user 874: NDCG@10=0.7530, n_test_items=10
#   Left-out user 882: NDCG@10=0.8324, n_test_items=15
#   Left-out user 883: NDCG@10=0.8928, n_test_items=17
#   Left-out user 891: NDCG@10=0.8183, n_test_items=18
#   Left-out user 895: NDCG@10=0.8001, n_test_items=11
#   Left-out user 907: NDCG@10=0.9184, n_test_items=24
#   Left-out user 925: NDCG@10=0.9266, n_test_items=18
#   Left-out user 934: NDCG@10=0.8329, n_test_items=17
#   Left-out user 954: NDCG@10=0.8885, n_test_items=16
#   Left-out user 960: NDCG@10=0.7443, n_test_items=26
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 3} -> Avg NDCG@10: 0.8176, RMSE: 1.1818, RMSE_norm: 0.9545745599246722
# (3770, 3) (2988, 3) (782, 3)
# 2988 782 754.0
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 3}
# ✅ Best RMSE on TEST: 1.3424, NDCG@3: 0.8471 (len:80), normalized RMSE: 1.3424
#
# 📈 Explained Variance (for best SVD only): 0.28493362011833256
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Long videos
# Test size: 782
# Accuracy: 0.3031
# Precision (macro): 0.3361
# Recall (macro): 0.2565
# F1 Score (macro): 0.2428
# (3770, 3)
# (3770, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 3} ===
#   Left-out user 48: NDCG@10=0.5498, n_test_items=27
#   Left-out user 53: NDCG@10=0.9049, n_test_items=50
#   Left-out user 84: NDCG@10=0.6633, n_test_items=34
#   Left-out user 95: NDCG@10=0.5780, n_test_items=79
#   Left-out user 115: NDCG@10=0.6666, n_test_items=79
#   Left-out user 135: NDCG@10=0.6487, n_test_items=26
#   Left-out user 146: NDCG@10=0.6947, n_test_items=29
#   Left-out user 147: NDCG@10=0.5880, n_test_items=79
#   Left-out user 155: NDCG@10=0.6610, n_test_items=28
#   Left-out user 169: NDCG@10=0.6563, n_test_items=68
#   Left-out user 175: NDCG@10=0.6750, n_test_items=29
#   Left-out user 246: NDCG@10=0.5626, n_test_items=16
#   Left-out user 270: NDCG@10=0.8421, n_test_items=52
#   Left-out user 272: NDCG@10=0.5626, n_test_items=19
#   Left-out user 280: NDCG@10=0.7585, n_test_items=41
#   Left-out user 293: NDCG@10=0.6868, n_test_items=37
#   Left-out user 297: NDCG@10=0.5488, n_test_items=17
#   Left-out user 299: NDCG@10=0.6496, n_test_items=24
#   Left-out user 359: NDCG@10=0.6297, n_test_items=28
#   Left-out user 363: NDCG@10=0.7765, n_test_items=79
#   Left-out user 388: NDCG@10=0.8849, n_test_items=54
#   Left-out user 402: NDCG@10=0.6475, n_test_items=30
#   Left-out user 437: NDCG@10=0.5626, n_test_items=17
#   Left-out user 440: NDCG@10=0.7145, n_test_items=54
#   Left-out user 442: NDCG@10=0.6171, n_test_items=79
#   Left-out user 443: NDCG@10=0.7466, n_test_items=45
#   Left-out user 447: NDCG@10=0.8879, n_test_items=79
#   Left-out user 456: NDCG@10=0.5699, n_test_items=36
#   Left-out user 465: NDCG@10=0.7340, n_test_items=79
#   Left-out user 485: NDCG@10=0.7782, n_test_items=74
#   Left-out user 489: NDCG@10=0.9032, n_test_items=65
#   Left-out user 494: NDCG@10=0.6654, n_test_items=33
#   Left-out user 499: NDCG@10=0.6876, n_test_items=30
#   Left-out user 501: NDCG@10=0.6552, n_test_items=79
#   Left-out user 502: NDCG@10=0.9448, n_test_items=45
#   Left-out user 510: NDCG@10=0.8766, n_test_items=47
#   Left-out user 516: NDCG@10=0.5626, n_test_items=19
#   Left-out user 533: NDCG@10=0.7396, n_test_items=79
#   Left-out user 560: NDCG@10=0.8347, n_test_items=79
#   Left-out user 561: NDCG@10=0.7015, n_test_items=30
#   Left-out user 566: NDCG@10=0.6800, n_test_items=31
#   Left-out user 594: NDCG@10=0.6972, n_test_items=55
#   Left-out user 605: NDCG@10=0.6759, n_test_items=62
#   Left-out user 611: NDCG@10=0.7700, n_test_items=60
#   Left-out user 653: NDCG@10=0.6750, n_test_items=24
#   Left-out user 663: NDCG@10=0.5626, n_test_items=17
#   Left-out user 679: NDCG@10=0.8991, n_test_items=71
#   Left-out user 688: NDCG@10=0.6339, n_test_items=79
#   Left-out user 690: NDCG@10=0.9413, n_test_items=45
#   Left-out user 702: NDCG@10=0.7703, n_test_items=71
#   Left-out user 722: NDCG@10=0.7612, n_test_items=42
#   Left-out user 731: NDCG@10=0.6623, n_test_items=79
#   Left-out user 732: NDCG@10=0.5636, n_test_items=74
#   Left-out user 766: NDCG@10=0.3012, n_test_items=11
#   Left-out user 776: NDCG@10=0.7258, n_test_items=79
#   Left-out user 778: NDCG@10=0.7015, n_test_items=35
#   Left-out user 780: NDCG@10=0.6237, n_test_items=73
#   Left-out user 783: NDCG@10=0.7870, n_test_items=79
#   Left-out user 786: NDCG@10=0.6297, n_test_items=23
#   Left-out user 788: NDCG@10=0.5361, n_test_items=17
#   Left-out user 802: NDCG@10=0.7015, n_test_items=31
#   Left-out user 814: NDCG@10=0.6297, n_test_items=33
#   Left-out user 815: NDCG@10=0.9120, n_test_items=58
#   Left-out user 823: NDCG@10=0.6580, n_test_items=34
#   Left-out user 824: NDCG@10=0.4526, n_test_items=13
#   Left-out user 826: NDCG@10=0.6419, n_test_items=24
#   Left-out user 842: NDCG@10=0.6066, n_test_items=79
#   Left-out user 844: NDCG@10=0.6475, n_test_items=35
#   Left-out user 853: NDCG@10=0.9843, n_test_items=57
#   Left-out user 867: NDCG@10=0.6496, n_test_items=36
#   Left-out user 874: NDCG@10=0.7015, n_test_items=24
#   Left-out user 882: NDCG@10=0.6800, n_test_items=30
#   Left-out user 883: NDCG@10=0.8375, n_test_items=39
#   Left-out user 891: NDCG@10=0.8411, n_test_items=57
#   Left-out user 895: NDCG@10=0.6158, n_test_items=26
#   Left-out user 907: NDCG@10=0.9873, n_test_items=76
#   Left-out user 925: NDCG@10=0.8695, n_test_items=43
#   Left-out user 934: NDCG@10=0.7895, n_test_items=41
#   Left-out user 954: NDCG@10=0.6021, n_test_items=34
#   Left-out user 960: NDCG@10=0.6863, n_test_items=79
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 3} -> Avg NDCG@10: 0.7014, RMSE: 1.3668, RMSE_norm: 0.8191408666595569
# Time split: 39
# (2612, 3) (2052, 3) (560, 3)
# 2052 560 522.4
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1}
# ✅ Best RMSE on TEST: 1.3559, NDCG@3: 0.8821 (len:78), normalized RMSE: 1.3559
#
# 📈 Explained Variance (for best SVD only): 0.1720305078659023
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Short videos
# Test size: 560
# Accuracy: 0.3000
# Precision (macro): 0.2292
# Recall (macro): 0.1964
# F1 Score (macro): 0.1664
# (2612, 3)
# (2612, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1} ===
#   Left-out user 48: NDCG@10=0.7969, n_test_items=22
#   Left-out user 53: NDCG@10=0.8871, n_test_items=36
#   Left-out user 84: NDCG@10=0.9216, n_test_items=30
#   Left-out user 95: NDCG@10=0.8108, n_test_items=47
#   Left-out user 115: NDCG@10=0.7625, n_test_items=47
#   Left-out user 135: NDCG@10=0.8116, n_test_items=22
#   Left-out user 146: NDCG@10=0.8953, n_test_items=26
#   Left-out user 147: NDCG@10=0.6871, n_test_items=47
#   Left-out user 155: NDCG@10=0.7691, n_test_items=22
#   Left-out user 169: NDCG@10=0.7837, n_test_items=42
#   Left-out user 175: NDCG@10=0.8686, n_test_items=26
#   Left-out user 246: NDCG@10=0.5583, n_test_items=13
#   Left-out user 270: NDCG@10=0.9686, n_test_items=36
#   Left-out user 272: NDCG@10=0.5583, n_test_items=14
#   Left-out user 280: NDCG@10=0.9696, n_test_items=33
#   Left-out user 293: NDCG@10=0.9216, n_test_items=31
#   Left-out user 297: NDCG@10=0.5583, n_test_items=14
#   Left-out user 299: NDCG@10=0.8116, n_test_items=20
#   Left-out user 359: NDCG@10=0.7628, n_test_items=23
#   Left-out user 363: NDCG@10=0.7913, n_test_items=47
#   Left-out user 388: NDCG@10=0.9359, n_test_items=37
#   Left-out user 402: NDCG@10=0.8967, n_test_items=27
#   Left-out user 437: NDCG@10=0.5583, n_test_items=14
#   Left-out user 440: NDCG@10=0.7965, n_test_items=37
#   Left-out user 442: NDCG@10=0.6365, n_test_items=47
#   Left-out user 443: NDCG@10=0.8285, n_test_items=36
#   Left-out user 447: NDCG@10=0.9231, n_test_items=47
#   Left-out user 456: NDCG@10=0.7766, n_test_items=31
#   Left-out user 465: NDCG@10=0.8189, n_test_items=47
#   Left-out user 485: NDCG@10=0.9489, n_test_items=44
#   Left-out user 489: NDCG@10=1.0000, n_test_items=39
#   Left-out user 494: NDCG@10=0.8303, n_test_items=29
#   Left-out user 499: NDCG@10=0.9216, n_test_items=26
#   Left-out user 501: NDCG@10=0.7597, n_test_items=47
#   Left-out user 502: NDCG@10=0.8842, n_test_items=36
#   Left-out user 510: NDCG@10=0.9526, n_test_items=36
#   Left-out user 516: NDCG@10=0.5444, n_test_items=14
#   Left-out user 533: NDCG@10=0.8131, n_test_items=47
#   Left-out user 560: NDCG@10=0.9502, n_test_items=47
#   Left-out user 561: NDCG@10=0.9216, n_test_items=26
#   Left-out user 566: NDCG@10=0.8763, n_test_items=28
#   Left-out user 594: NDCG@10=0.9196, n_test_items=37
#   Left-out user 605: NDCG@10=0.7556, n_test_items=38
#   Left-out user 611: NDCG@10=0.7820, n_test_items=38
#   Left-out user 653: NDCG@10=0.8116, n_test_items=20
#   Left-out user 663: NDCG@10=0.5583, n_test_items=14
#   Left-out user 679: NDCG@10=1.0000, n_test_items=43
#   Left-out user 688: NDCG@10=0.8785, n_test_items=47
#   Left-out user 690: NDCG@10=0.9383, n_test_items=36
#   Left-out user 702: NDCG@10=0.8752, n_test_items=43
#   Left-out user 722: NDCG@10=0.7328, n_test_items=35
#   Left-out user 731: NDCG@10=0.7637, n_test_items=47
#   Left-out user 732: NDCG@10=0.7488, n_test_items=43
#   Left-out user 766: NDCG@10=0.0875, n_test_items=6
#   Left-out user 776: NDCG@10=0.7132, n_test_items=47
#   Left-out user 778: NDCG@10=0.9216, n_test_items=30
#   Left-out user 780: NDCG@10=0.8145, n_test_items=43
#   Left-out user 783: NDCG@10=0.7078, n_test_items=47
#   Left-out user 786: NDCG@10=0.5914, n_test_items=17
#   Left-out user 788: NDCG@10=0.5583, n_test_items=14
#   Left-out user 802: NDCG@10=0.9216, n_test_items=28
#   Left-out user 814: NDCG@10=0.9069, n_test_items=29
#   Left-out user 815: NDCG@10=0.9686, n_test_items=37
#   Left-out user 823: NDCG@10=0.9216, n_test_items=29
#   Left-out user 824: NDCG@10=0.2162, n_test_items=9
#   Left-out user 826: NDCG@10=0.7412, n_test_items=20
#   Left-out user 842: NDCG@10=0.7939, n_test_items=47
#   Left-out user 844: NDCG@10=0.8729, n_test_items=31
#   Left-out user 853: NDCG@10=0.9751, n_test_items=37
#   Left-out user 867: NDCG@10=0.9216, n_test_items=31
#   Left-out user 874: NDCG@10=0.8116, n_test_items=20
#   Left-out user 882: NDCG@10=0.8397, n_test_items=27
#   Left-out user 883: NDCG@10=0.9621, n_test_items=33
#   Left-out user 891: NDCG@10=0.9301, n_test_items=37
#   Left-out user 895: NDCG@10=0.7696, n_test_items=22
#   Left-out user 907: NDCG@10=0.9843, n_test_items=45
#   Left-out user 925: NDCG@10=0.9513, n_test_items=35
#   Left-out user 934: NDCG@10=0.8934, n_test_items=33
#   Left-out user 954: NDCG@10=0.9069, n_test_items=30
#   Left-out user 960: NDCG@10=0.7788, n_test_items=47
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1} -> Avg NDCG@10: 0.8087, RMSE: 1.2966, RMSE_norm: 0.9249777337595008
# (2523, 3) (1987, 3) (536, 3)
# 1987 536 504.6
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 15}
# ✅ Best RMSE on TEST: 1.3883, NDCG@3: 0.8156 (len:73), normalized RMSE: 1.3883
#
# 📈 Explained Variance (for best SVD only): 0.15976736093305163
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Long videos
# Test size: 536
# Accuracy: 0.3228
# Precision (macro): 0.2872
# Recall (macro): 0.2370
# F1 Score (macro): 0.2264
# (2523, 3)
# (2523, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 15} ===
#   Left-out user 48: NDCG@10=0.6350, n_test_items=16
#   Left-out user 53: NDCG@10=0.6150, n_test_items=32
#   Left-out user 84: NDCG@10=0.8337, n_test_items=20
#   Left-out user 95: NDCG@10=0.6231, n_test_items=58
#   Left-out user 115: NDCG@10=0.4783, n_test_items=58
#   Left-out user 135: NDCG@10=0.4614, n_test_items=15
#   Left-out user 146: NDCG@10=0.7783, n_test_items=17
#   Left-out user 147: NDCG@10=0.6305, n_test_items=58
#   Left-out user 155: NDCG@10=0.7388, n_test_items=17
#   Left-out user 169: NDCG@10=0.7806, n_test_items=48
#   Left-out user 175: NDCG@10=0.7649, n_test_items=17
#   Left-out user 246: NDCG@10=0.6805, n_test_items=8
#   Left-out user 270: NDCG@10=0.7334, n_test_items=34
#   Left-out user 272: NDCG@10=0.6128, n_test_items=11
#   Left-out user 280: NDCG@10=0.7611, n_test_items=25
#   Left-out user 293: NDCG@10=0.7759, n_test_items=23
#   Left-out user 297: NDCG@10=0.7282, n_test_items=9
#   Left-out user 299: NDCG@10=0.7032, n_test_items=14
#   Left-out user 359: NDCG@10=0.4128, n_test_items=17
#   Left-out user 363: NDCG@10=0.7944, n_test_items=58
#   Left-out user 388: NDCG@10=0.7462, n_test_items=35
#   Left-out user 402: NDCG@10=0.7357, n_test_items=18
#   Left-out user 437: NDCG@10=0.6365, n_test_items=9
#   Left-out user 440: NDCG@10=0.6588, n_test_items=35
#   Left-out user 442: NDCG@10=0.5656, n_test_items=58
#   Left-out user 443: NDCG@10=0.6784, n_test_items=27
#   Left-out user 447: NDCG@10=0.6893, n_test_items=58
#   Left-out user 456: NDCG@10=0.7276, n_test_items=22
#   Left-out user 465: NDCG@10=0.7617, n_test_items=58
#   Left-out user 485: NDCG@10=0.5903, n_test_items=54
#   Left-out user 489: NDCG@10=0.7385, n_test_items=46
#   Left-out user 494: NDCG@10=0.8421, n_test_items=19
#   Left-out user 499: NDCG@10=0.6963, n_test_items=18
#   Left-out user 501: NDCG@10=0.4346, n_test_items=58
#   Left-out user 502: NDCG@10=0.7815, n_test_items=27
#   Left-out user 510: NDCG@10=0.8054, n_test_items=29
#   Left-out user 516: NDCG@10=0.6834, n_test_items=11
#   Left-out user 533: NDCG@10=0.6591, n_test_items=58
#   Left-out user 560: NDCG@10=0.6639, n_test_items=58
#   Left-out user 561: NDCG@10=0.8103, n_test_items=18
#   Left-out user 566: NDCG@10=0.9080, n_test_items=18
#   Left-out user 594: NDCG@10=0.6686, n_test_items=36
#   Left-out user 605: NDCG@10=0.4805, n_test_items=43
#   Left-out user 611: NDCG@10=0.6555, n_test_items=41
#   Left-out user 653: NDCG@10=0.7066, n_test_items=14
#   Left-out user 663: NDCG@10=0.6484, n_test_items=9
#   Left-out user 679: NDCG@10=0.5891, n_test_items=51
#   Left-out user 688: NDCG@10=0.7625, n_test_items=58
#   Left-out user 690: NDCG@10=0.8447, n_test_items=27
#   Left-out user 702: NDCG@10=0.6258, n_test_items=51
#   Left-out user 722: NDCG@10=0.6791, n_test_items=25
#   Left-out user 731: NDCG@10=0.3571, n_test_items=58
#   Left-out user 732: NDCG@10=0.6198, n_test_items=54
#   Left-out user 766: NDCG@10=0.5882, n_test_items=7
#   Left-out user 776: NDCG@10=0.6962, n_test_items=58
#   Left-out user 778: NDCG@10=0.8458, n_test_items=21
#   Left-out user 780: NDCG@10=0.4758, n_test_items=53
#   Left-out user 783: NDCG@10=0.5866, n_test_items=58
#   Left-out user 786: NDCG@10=0.5761, n_test_items=13
#   Left-out user 788: NDCG@10=0.7506, n_test_items=9
#   Left-out user 802: NDCG@10=0.8701, n_test_items=18
#   Left-out user 814: NDCG@10=0.7240, n_test_items=19
#   Left-out user 815: NDCG@10=0.7661, n_test_items=39
#   Left-out user 823: NDCG@10=0.9022, n_test_items=20
#   Left-out user 824: NDCG@10=0.5667, n_test_items=7
#   Left-out user 826: NDCG@10=0.7736, n_test_items=14
#   Left-out user 842: NDCG@10=0.8416, n_test_items=58
#   Left-out user 844: NDCG@10=0.6188, n_test_items=21
#   Left-out user 853: NDCG@10=0.7901, n_test_items=38
#   Left-out user 867: NDCG@10=0.8539, n_test_items=22
#   Left-out user 874: NDCG@10=0.7113, n_test_items=14
#   Left-out user 882: NDCG@10=0.8285, n_test_items=18
#   Left-out user 883: NDCG@10=0.6067, n_test_items=23
#   Left-out user 891: NDCG@10=0.7957, n_test_items=38
#   Left-out user 895: NDCG@10=0.5200, n_test_items=15
#   Left-out user 907: NDCG@10=0.7410, n_test_items=55
#   Left-out user 925: NDCG@10=0.8463, n_test_items=26
#   Left-out user 934: NDCG@10=0.8440, n_test_items=25
#   Left-out user 954: NDCG@10=0.7410, n_test_items=20
#   Left-out user 960: NDCG@10=0.5991, n_test_items=58
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 15} -> Avg NDCG@10: 0.6932, RMSE: 1.3441, RMSE_norm: 0.8737407258536897
# Time split: 70
# (3888, 3) (3069, 3) (819, 3)
# 3069 819 777.6
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1}
# ✅ Best RMSE on TEST: 1.3455, NDCG@3: 0.8745 (len:79), normalized RMSE: 1.3455
#
# 📈 Explained Variance (for best SVD only): 0.13551568354435287
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Short videos
# Test size: 819
# Accuracy: 0.3260
# Precision (macro): 0.3901
# Recall (macro): 0.2944
# F1 Score (macro): 0.2846
# (3888, 3)
# (3888, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1} ===
#   Left-out user 48: NDCG@10=0.7969, n_test_items=30
#   Left-out user 53: NDCG@10=0.8871, n_test_items=54
#   Left-out user 84: NDCG@10=0.9216, n_test_items=40
#   Left-out user 95: NDCG@10=0.8108, n_test_items=76
#   Left-out user 115: NDCG@10=0.7625, n_test_items=76
#   Left-out user 135: NDCG@10=0.8116, n_test_items=29
#   Left-out user 146: NDCG@10=0.8953, n_test_items=34
#   Left-out user 147: NDCG@10=0.6871, n_test_items=76
#   Left-out user 155: NDCG@10=0.7691, n_test_items=30
#   Left-out user 169: NDCG@10=0.7837, n_test_items=67
#   Left-out user 175: NDCG@10=0.8686, n_test_items=34
#   Left-out user 246: NDCG@10=0.5583, n_test_items=17
#   Left-out user 270: NDCG@10=0.9686, n_test_items=55
#   Left-out user 272: NDCG@10=0.5583, n_test_items=19
#   Left-out user 280: NDCG@10=0.9696, n_test_items=46
#   Left-out user 293: NDCG@10=0.9216, n_test_items=42
#   Left-out user 297: NDCG@10=0.5583, n_test_items=18
#   Left-out user 299: NDCG@10=0.8116, n_test_items=27
#   Left-out user 359: NDCG@10=0.7628, n_test_items=31
#   Left-out user 363: NDCG@10=0.7913, n_test_items=76
#   Left-out user 388: NDCG@10=0.9359, n_test_items=56
#   Left-out user 402: NDCG@10=0.8967, n_test_items=36
#   Left-out user 437: NDCG@10=0.5583, n_test_items=18
#   Left-out user 440: NDCG@10=0.7965, n_test_items=56
#   Left-out user 442: NDCG@10=0.5992, n_test_items=76
#   Left-out user 443: NDCG@10=0.8285, n_test_items=51
#   Left-out user 447: NDCG@10=0.9231, n_test_items=76
#   Left-out user 456: NDCG@10=0.7766, n_test_items=41
#   Left-out user 465: NDCG@10=0.8189, n_test_items=76
#   Left-out user 485: NDCG@10=0.9489, n_test_items=72
#   Left-out user 489: NDCG@10=1.0000, n_test_items=63
#   Left-out user 494: NDCG@10=0.8303, n_test_items=38
#   Left-out user 499: NDCG@10=0.9216, n_test_items=35
#   Left-out user 501: NDCG@10=0.7597, n_test_items=76
#   Left-out user 502: NDCG@10=0.8842, n_test_items=51
#   Left-out user 510: NDCG@10=0.9526, n_test_items=52
#   Left-out user 516: NDCG@10=0.5444, n_test_items=19
#   Left-out user 533: NDCG@10=0.8131, n_test_items=76
#   Left-out user 560: NDCG@10=0.9502, n_test_items=76
#   Left-out user 561: NDCG@10=0.9216, n_test_items=35
#   Left-out user 566: NDCG@10=0.8763, n_test_items=37
#   Left-out user 594: NDCG@10=0.9196, n_test_items=56
#   Left-out user 605: NDCG@10=0.7556, n_test_items=59
#   Left-out user 611: NDCG@10=0.7820, n_test_items=59
#   Left-out user 653: NDCG@10=0.8116, n_test_items=27
#   Left-out user 663: NDCG@10=0.5583, n_test_items=18
#   Left-out user 679: NDCG@10=1.0000, n_test_items=69
#   Left-out user 688: NDCG@10=0.8785, n_test_items=76
#   Left-out user 690: NDCG@10=0.9383, n_test_items=51
#   Left-out user 702: NDCG@10=0.8752, n_test_items=69
#   Left-out user 722: NDCG@10=0.7328, n_test_items=48
#   Left-out user 731: NDCG@10=0.7413, n_test_items=76
#   Left-out user 732: NDCG@10=0.7488, n_test_items=71
#   Left-out user 766: NDCG@10=0.0679, n_test_items=9
#   Left-out user 776: NDCG@10=0.7132, n_test_items=76
#   Left-out user 778: NDCG@10=0.9216, n_test_items=40
#   Left-out user 780: NDCG@10=0.8145, n_test_items=71
#   Left-out user 783: NDCG@10=0.7078, n_test_items=76
#   Left-out user 786: NDCG@10=0.5914, n_test_items=24
#   Left-out user 788: NDCG@10=0.5583, n_test_items=18
#   Left-out user 802: NDCG@10=0.9216, n_test_items=37
#   Left-out user 814: NDCG@10=0.9069, n_test_items=38
#   Left-out user 815: NDCG@10=0.9686, n_test_items=57
#   Left-out user 823: NDCG@10=0.9216, n_test_items=39
#   Left-out user 824: NDCG@10=0.2025, n_test_items=12
#   Left-out user 826: NDCG@10=0.7412, n_test_items=27
#   Left-out user 842: NDCG@10=0.7939, n_test_items=76
#   Left-out user 844: NDCG@10=0.8729, n_test_items=41
#   Left-out user 853: NDCG@10=0.9751, n_test_items=57
#   Left-out user 867: NDCG@10=0.9216, n_test_items=41
#   Left-out user 874: NDCG@10=0.8116, n_test_items=27
#   Left-out user 882: NDCG@10=0.8397, n_test_items=36
#   Left-out user 883: NDCG@10=0.9621, n_test_items=44
#   Left-out user 891: NDCG@10=0.9301, n_test_items=57
#   Left-out user 895: NDCG@10=0.7696, n_test_items=29
#   Left-out user 907: NDCG@10=0.9843, n_test_items=73
#   Left-out user 925: NDCG@10=0.9513, n_test_items=49
#   Left-out user 934: NDCG@10=0.8934, n_test_items=46
#   Left-out user 954: NDCG@10=0.9069, n_test_items=40
#   Left-out user 960: NDCG@10=0.7788, n_test_items=76
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1} -> Avg NDCG@10: 0.8075, RMSE: 1.3513, RMSE_norm: 0.8561542029873286
# (1247, 3) (970, 3) (277, 3)
# cold items [100]
# 971 276 249.4
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 1}
# ✅ Best RMSE on TEST: 1.3300, NDCG@3: 0.8341 (len:48), normalized RMSE: 1.3300
#
# 📈 Explained Variance (for best SVD only): 0.9828569258788883
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Long videos
# Test size: 276
# Accuracy: 0.3623
# Precision (macro): 0.2430
# Recall (macro): 0.2287
# F1 Score (macro): 0.2025
# (1247, 3)
# (1247, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 1} ===
#   Left-out user 48: NDCG@10=0.2963, n_test_items=8
#   Left-out user 53: NDCG@10=0.8752, n_test_items=14
#   Left-out user 84: NDCG@10=0.6643, n_test_items=10
#   Left-out user 95: NDCG@10=0.7914, n_test_items=29
#   Left-out user 115: NDCG@10=0.6911, n_test_items=29
#   Left-out user 135: NDCG@10=0.6302, n_test_items=8
#   Left-out user 146: NDCG@10=0.6908, n_test_items=9
#   Left-out user 147: NDCG@10=0.6530, n_test_items=29
#   Left-out user 155: NDCG@10=0.7720, n_test_items=9
#   Left-out user 169: NDCG@10=0.7737, n_test_items=23
#   Left-out user 175: NDCG@10=0.7503, n_test_items=9
#   Left-out user 246: NDCG@10=0.3550, n_test_items=4
#   Left-out user 270: NDCG@10=0.7456, n_test_items=15
#   Left-out user 272: NDCG@10=0.4475, n_test_items=6
#   Left-out user 280: NDCG@10=0.7361, n_test_items=12
#   Left-out user 293: NDCG@10=0.7513, n_test_items=12
#   Left-out user 297: NDCG@10=0.3590, n_test_items=5
#   Left-out user 299: NDCG@10=0.4328, n_test_items=7
#   Left-out user 359: NDCG@10=0.7084, n_test_items=9
#   Left-out user 363: NDCG@10=0.6273, n_test_items=29
#   Left-out user 388: NDCG@10=0.8675, n_test_items=16
#   Left-out user 402: NDCG@10=0.6284, n_test_items=9
#   Left-out user 437: NDCG@10=0.3895, n_test_items=5
#   Left-out user 440: NDCG@10=0.6865, n_test_items=16
#   Left-out user 442: NDCG@10=0.7641, n_test_items=29
#   Left-out user 443: NDCG@10=0.7649, n_test_items=12
#   Left-out user 447: NDCG@10=0.9050, n_test_items=29
#   Left-out user 456: NDCG@10=0.8429, n_test_items=12
#   Left-out user 465: NDCG@10=0.7420, n_test_items=29
#   Left-out user 485: NDCG@10=0.5945, n_test_items=26
#   Left-out user 489: NDCG@10=0.7449, n_test_items=22
#   Left-out user 494: NDCG@10=0.7527, n_test_items=10
#   Left-out user 499: NDCG@10=0.5097, n_test_items=9
#   Left-out user 501: NDCG@10=0.5812, n_test_items=29
#   Left-out user 502: NDCG@10=0.6646, n_test_items=12
#   Left-out user 510: NDCG@10=0.8460, n_test_items=13
#   Left-out user 516: NDCG@10=0.3478, n_test_items=6
#   Left-out user 533: NDCG@10=0.5589, n_test_items=29
#   Left-out user 560: NDCG@10=0.7357, n_test_items=29
#   Left-out user 561: NDCG@10=0.7814, n_test_items=9
#   Left-out user 566: NDCG@10=0.7902, n_test_items=9
#   Left-out user 594: NDCG@10=0.5851, n_test_items=17
#   Left-out user 605: NDCG@10=0.8396, n_test_items=22
#   Left-out user 611: NDCG@10=0.4606, n_test_items=20
#   Left-out user 653: NDCG@10=0.3911, n_test_items=7
#   Left-out user 663: NDCG@10=0.3450, n_test_items=5
#   Left-out user 679: NDCG@10=0.8816, n_test_items=25
#   Left-out user 688: NDCG@10=0.6077, n_test_items=29
#   Left-out user 690: NDCG@10=0.7685, n_test_items=12
#   Left-out user 702: NDCG@10=0.6806, n_test_items=25
#   Left-out user 722: NDCG@10=0.6104, n_test_items=12
#   Left-out user 731: NDCG@10=0.7126, n_test_items=29
#   Left-out user 732: NDCG@10=0.6332, n_test_items=26
#   Left-out user 766: NDCG@10=0.2701, n_test_items=4
#   Left-out user 776: NDCG@10=0.6070, n_test_items=29
#   Left-out user 778: NDCG@10=0.7354, n_test_items=11
#   Left-out user 780: NDCG@10=0.5339, n_test_items=25
#   Left-out user 783: NDCG@10=0.5856, n_test_items=29
#   Left-out user 786: NDCG@10=0.4027, n_test_items=6
#   Left-out user 788: NDCG@10=0.3211, n_test_items=5
#   Left-out user 802: NDCG@10=0.7948, n_test_items=9
#   Left-out user 814: NDCG@10=0.5141, n_test_items=10
#   Left-out user 815: NDCG@10=0.6426, n_test_items=19
#   Left-out user 823: NDCG@10=0.6759, n_test_items=10
#   Left-out user 824: NDCG@10=0.3191, n_test_items=4
#   Left-out user 826: NDCG@10=0.4034, n_test_items=7
#   Left-out user 842: NDCG@10=0.6923, n_test_items=29
#   Left-out user 844: NDCG@10=0.6685, n_test_items=11
#   Left-out user 853: NDCG@10=0.6044, n_test_items=18
#   Left-out user 867: NDCG@10=0.7239, n_test_items=12
#   Left-out user 874: NDCG@10=0.4244, n_test_items=7
#   Left-out user 882: NDCG@10=0.6470, n_test_items=9
#   Left-out user 883: NDCG@10=0.7504, n_test_items=12
#   Left-out user 891: NDCG@10=0.6658, n_test_items=18
#   Left-out user 895: NDCG@10=0.5832, n_test_items=8
#   Left-out user 907: NDCG@10=0.6187, n_test_items=27
#   Left-out user 925: NDCG@10=0.6632, n_test_items=12
#   Left-out user 934: NDCG@10=0.8531, n_test_items=12
#   Left-out user 954: NDCG@10=0.8047, n_test_items=10
#   Left-out user 960: NDCG@10=0.8122, n_test_items=29
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 1} -> Avg NDCG@10: 0.6385, RMSE: 1.2179, RMSE_norm: 0.9338364654049571
# Time split: 96
# (4148, 3) (3293, 3) (855, 3)
# cold items [102]
# 3294 854 829.6
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 3}
# ✅ Best RMSE on TEST: 1.4175, NDCG@3: 0.8465 (len:79), normalized RMSE: 1.4175
#
# 📈 Explained Variance (for best SVD only): 0.48751094645839776
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Short videos
# Test size: 854
# Accuracy: 0.3677
# Precision (macro): 0.3199
# Recall (macro): 0.2747
# F1 Score (macro): 0.2720
# (4148, 3)
# (4148, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 3} ===
#   Left-out user 48: NDCG@10=0.7969, n_test_items=30
#   Left-out user 53: NDCG@10=0.8871, n_test_items=56
#   Left-out user 84: NDCG@10=0.9216, n_test_items=41
#   Left-out user 95: NDCG@10=0.8108, n_test_items=85
#   Left-out user 115: NDCG@10=0.7625, n_test_items=85
#   Left-out user 135: NDCG@10=0.8116, n_test_items=29
#   Left-out user 146: NDCG@10=0.8953, n_test_items=35
#   Left-out user 147: NDCG@10=0.6871, n_test_items=85
#   Left-out user 155: NDCG@10=0.7691, n_test_items=31
#   Left-out user 169: NDCG@10=0.7837, n_test_items=71
#   Left-out user 175: NDCG@10=0.8686, n_test_items=35
#   Left-out user 246: NDCG@10=0.5583, n_test_items=17
#   Left-out user 270: NDCG@10=0.9686, n_test_items=58
#   Left-out user 272: NDCG@10=0.5583, n_test_items=19
#   Left-out user 280: NDCG@10=0.9696, n_test_items=48
#   Left-out user 293: NDCG@10=0.9216, n_test_items=44
#   Left-out user 297: NDCG@10=0.5583, n_test_items=18
#   Left-out user 299: NDCG@10=0.8116, n_test_items=27
#   Left-out user 359: NDCG@10=0.7628, n_test_items=32
#   Left-out user 363: NDCG@10=0.7913, n_test_items=85
#   Left-out user 388: NDCG@10=0.9359, n_test_items=59
#   Left-out user 402: NDCG@10=0.8967, n_test_items=37
#   Left-out user 437: NDCG@10=0.5583, n_test_items=18
#   Left-out user 440: NDCG@10=0.7965, n_test_items=59
#   Left-out user 442: NDCG@10=0.5907, n_test_items=85
#   Left-out user 443: NDCG@10=0.8285, n_test_items=53
#   Left-out user 447: NDCG@10=0.9231, n_test_items=85
#   Left-out user 456: NDCG@10=0.7766, n_test_items=43
#   Left-out user 465: NDCG@10=0.8189, n_test_items=85
#   Left-out user 485: NDCG@10=0.9489, n_test_items=78
#   Left-out user 489: NDCG@10=1.0000, n_test_items=66
#   Left-out user 494: NDCG@10=0.8303, n_test_items=39
#   Left-out user 499: NDCG@10=0.9216, n_test_items=36
#   Left-out user 501: NDCG@10=0.7597, n_test_items=85
#   Left-out user 502: NDCG@10=0.8842, n_test_items=53
#   Left-out user 510: NDCG@10=0.9526, n_test_items=54
#   Left-out user 516: NDCG@10=0.5444, n_test_items=19
#   Left-out user 533: NDCG@10=0.8131, n_test_items=85
#   Left-out user 560: NDCG@10=0.9502, n_test_items=85
#   Left-out user 561: NDCG@10=0.9216, n_test_items=36
#   Left-out user 566: NDCG@10=0.8763, n_test_items=38
#   Left-out user 594: NDCG@10=0.9196, n_test_items=59
#   Left-out user 605: NDCG@10=0.7556, n_test_items=62
#   Left-out user 611: NDCG@10=0.7820, n_test_items=62
#   Left-out user 653: NDCG@10=0.8116, n_test_items=27
#   Left-out user 663: NDCG@10=0.5583, n_test_items=18
#   Left-out user 679: NDCG@10=1.0000, n_test_items=75
#   Left-out user 688: NDCG@10=0.8785, n_test_items=85
#   Left-out user 690: NDCG@10=0.9383, n_test_items=53
#   Left-out user 702: NDCG@10=0.8752, n_test_items=75
#   Left-out user 722: NDCG@10=0.7328, n_test_items=50
#   Left-out user 731: NDCG@10=0.7413, n_test_items=85
#   Left-out user 732: NDCG@10=0.7488, n_test_items=77
#   Left-out user 766: NDCG@10=0.0679, n_test_items=9
#   Left-out user 776: NDCG@10=0.7132, n_test_items=85
#   Left-out user 778: NDCG@10=0.9216, n_test_items=42
#   Left-out user 780: NDCG@10=0.8145, n_test_items=77
#   Left-out user 783: NDCG@10=0.7078, n_test_items=85
#   Left-out user 786: NDCG@10=0.5914, n_test_items=24
#   Left-out user 788: NDCG@10=0.5583, n_test_items=18
#   Left-out user 802: NDCG@10=0.9216, n_test_items=38
#   Left-out user 814: NDCG@10=0.9069, n_test_items=39
#   Left-out user 815: NDCG@10=0.9686, n_test_items=60
#   Left-out user 823: NDCG@10=0.9216, n_test_items=40
#   Left-out user 824: NDCG@10=0.2025, n_test_items=12
#   Left-out user 826: NDCG@10=0.7412, n_test_items=27
#   Left-out user 842: NDCG@10=0.7939, n_test_items=85
#   Left-out user 844: NDCG@10=0.8729, n_test_items=43
#   Left-out user 853: NDCG@10=0.9751, n_test_items=60
#   Left-out user 867: NDCG@10=0.9216, n_test_items=43
#   Left-out user 874: NDCG@10=0.8116, n_test_items=27
#   Left-out user 882: NDCG@10=0.8397, n_test_items=37
#   Left-out user 883: NDCG@10=0.9621, n_test_items=46
#   Left-out user 891: NDCG@10=0.9301, n_test_items=60
#   Left-out user 895: NDCG@10=0.7696, n_test_items=29
#   Left-out user 907: NDCG@10=0.9843, n_test_items=80
#   Left-out user 925: NDCG@10=0.9513, n_test_items=51
#   Left-out user 934: NDCG@10=0.8934, n_test_items=48
#   Left-out user 954: NDCG@10=0.9069, n_test_items=41
#   Left-out user 960: NDCG@10=0.7788, n_test_items=85
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 3} -> Avg NDCG@10: 0.8074, RMSE: 1.3436, RMSE_norm: 0.8352882435595722
# (987, 3) (772, 3) (215, 3)
# 772 215 197.4
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 5}
# ✅ Best RMSE on TEST: 1.3161, NDCG@3: 0.9087 (len:35), normalized RMSE: 1.3161
#
# 📈 Explained Variance (for best SVD only): 0.33309078884087934
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Long videos
# Test size: 215
# Accuracy: 0.3395
# Precision (macro): 0.2884
# Recall (macro): 0.2288
# F1 Score (macro): 0.2148
# (987, 3)
# (987, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 5} ===
#   Left-out user 48: NDCG@10=0.4318, n_test_items=8
#   Left-out user 53: NDCG@10=0.7502, n_test_items=12
#   Left-out user 84: NDCG@10=0.7773, n_test_items=9
#   Left-out user 95: NDCG@10=0.8230, n_test_items=20
#   Left-out user 115: NDCG@10=0.8196, n_test_items=20
#   Left-out user 135: NDCG@10=0.8612, n_test_items=8
#   Left-out user 146: NDCG@10=0.5181, n_test_items=8
#   Left-out user 147: NDCG@10=0.7706, n_test_items=20
#   Left-out user 155: NDCG@10=0.6662, n_test_items=8
#   Left-out user 169: NDCG@10=0.6918, n_test_items=19
#   Left-out user 175: NDCG@10=0.5596, n_test_items=8
#   Left-out user 246: NDCG@10=0.4564, n_test_items=4
#   Left-out user 270: NDCG@10=0.6442, n_test_items=12
#   Left-out user 272: NDCG@10=0.5300, n_test_items=6
#   Left-out user 280: NDCG@10=0.5985, n_test_items=10
#   Left-out user 293: NDCG@10=0.6563, n_test_items=10
#   Left-out user 297: NDCG@10=0.4993, n_test_items=5
#   Left-out user 299: NDCG@10=0.5423, n_test_items=7
#   Left-out user 359: NDCG@10=0.5764, n_test_items=8
#   Left-out user 363: NDCG@10=0.7408, n_test_items=20
#   Left-out user 388: NDCG@10=0.8443, n_test_items=13
#   Left-out user 402: NDCG@10=0.6183, n_test_items=8
#   Left-out user 437: NDCG@10=0.4650, n_test_items=5
#   Left-out user 440: NDCG@10=0.6523, n_test_items=13
#   Left-out user 442: NDCG@10=0.6075, n_test_items=20
#   Left-out user 443: NDCG@10=0.6616, n_test_items=10
#   Left-out user 447: NDCG@10=0.8398, n_test_items=20
#   Left-out user 456: NDCG@10=0.7320, n_test_items=10
#   Left-out user 465: NDCG@10=0.9036, n_test_items=20
#   Left-out user 485: NDCG@10=0.6964, n_test_items=20
#   Left-out user 489: NDCG@10=0.8853, n_test_items=19
#   Left-out user 494: NDCG@10=0.5789, n_test_items=9
#   Left-out user 499: NDCG@10=0.5158, n_test_items=8
#   Left-out user 501: NDCG@10=0.8827, n_test_items=20
#   Left-out user 502: NDCG@10=0.7305, n_test_items=10
#   Left-out user 510: NDCG@10=0.7378, n_test_items=11
#   Left-out user 516: NDCG@10=0.4681, n_test_items=6
#   Left-out user 533: NDCG@10=0.6576, n_test_items=20
#   Left-out user 560: NDCG@10=0.5836, n_test_items=20
#   Left-out user 561: NDCG@10=0.7732, n_test_items=8
#   Left-out user 566: NDCG@10=0.7614, n_test_items=8
#   Left-out user 594: NDCG@10=0.5708, n_test_items=14
#   Left-out user 605: NDCG@10=0.8923, n_test_items=19
#   Left-out user 611: NDCG@10=0.4377, n_test_items=17
#   Left-out user 653: NDCG@10=0.4660, n_test_items=7
#   Left-out user 663: NDCG@10=0.3925, n_test_items=5
#   Left-out user 679: NDCG@10=0.8835, n_test_items=19
#   Left-out user 688: NDCG@10=0.5752, n_test_items=20
#   Left-out user 690: NDCG@10=0.7569, n_test_items=10
#   Left-out user 702: NDCG@10=0.8320, n_test_items=19
#   Left-out user 722: NDCG@10=0.5899, n_test_items=10
#   Left-out user 731: NDCG@10=0.7090, n_test_items=20
#   Left-out user 732: NDCG@10=0.6436, n_test_items=20
#   Left-out user 766: NDCG@10=0.3058, n_test_items=4
#   Left-out user 776: NDCG@10=0.5836, n_test_items=20
#   Left-out user 778: NDCG@10=0.6332, n_test_items=9
#   Left-out user 780: NDCG@10=0.7692, n_test_items=19
#   Left-out user 783: NDCG@10=0.7027, n_test_items=20
#   Left-out user 786: NDCG@10=0.4821, n_test_items=6
#   Left-out user 788: NDCG@10=0.4037, n_test_items=5
#   Left-out user 802: NDCG@10=0.7970, n_test_items=8
#   Left-out user 814: NDCG@10=0.6876, n_test_items=9
#   Left-out user 815: NDCG@10=0.6980, n_test_items=16
#   Left-out user 823: NDCG@10=0.6314, n_test_items=9
#   Left-out user 824: NDCG@10=0.3633, n_test_items=4
#   Left-out user 826: NDCG@10=0.4877, n_test_items=7
#   Left-out user 842: NDCG@10=0.6372, n_test_items=20
#   Left-out user 844: NDCG@10=0.5265, n_test_items=9
#   Left-out user 853: NDCG@10=0.6781, n_test_items=15
#   Left-out user 867: NDCG@10=0.5917, n_test_items=10
#   Left-out user 874: NDCG@10=0.5082, n_test_items=7
#   Left-out user 882: NDCG@10=0.4891, n_test_items=8
#   Left-out user 883: NDCG@10=0.5610, n_test_items=10
#   Left-out user 891: NDCG@10=0.6631, n_test_items=15
#   Left-out user 895: NDCG@10=0.7777, n_test_items=8
#   Left-out user 907: NDCG@10=0.7405, n_test_items=20
#   Left-out user 925: NDCG@10=0.7359, n_test_items=10
#   Left-out user 934: NDCG@10=0.7901, n_test_items=10
#   Left-out user 954: NDCG@10=0.7745, n_test_items=9
#   Left-out user 960: NDCG@10=0.8340, n_test_items=20
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 5} -> Avg NDCG@10: 0.6514, RMSE: 1.2166, RMSE_norm: 0.9588508064071385

# %%
df_results_exp = pd.DataFrame(results_exp)
df_results_exp
# Out:
#                  Data  Quantile  Duration   Type  Accuracy  Precision  \
# 0   TikTok Experiment      1.00       NaN    all  0.373092   0.347676
# 1   TikTok Experiment      0.20      12.0  short  0.417323   0.262258
# 2   TikTok Experiment      0.20      12.0   long  0.310180   0.338945
# 3   TikTok Experiment      0.25      13.0  short  0.414791   0.279650
# 4   TikTok Experiment      0.25      13.0   long  0.303069   0.336072
# 5   TikTok Experiment      0.50      39.0  short  0.300000   0.229198
# 6   TikTok Experiment      0.50      39.0   long  0.322761   0.287249
# 7   TikTok Experiment      0.75      70.0  short  0.326007   0.390129
# 8   TikTok Experiment      0.75      70.0   long  0.362319   0.242987
# 9   TikTok Experiment      0.80      96.0  short  0.367681   0.319880
# 10  TikTok Experiment      0.80      96.0   long  0.339535   0.288377
#
#       Recall  F1 score      ndcg  k_ndcg      rmse  rmse_norm  avg_ndcg_loo  \
# 0   0.301097  0.287353  0.887181       3  1.332465   0.809023      0.807134
# 1   0.253427  0.219877  0.908932       3  1.186027   0.947479      0.844692
# 2   0.271735  0.250866  0.864730       3  1.343601   0.802794      0.694605
# 3   0.231988  0.204036  0.907812       3  1.414547   1.151942      0.817625
# 4   0.256472  0.242816  0.847054       3  1.342449   0.801861      0.701374
# 5   0.196370  0.166445  0.882140       3  1.355876   0.932455      0.808681
# 6   0.237019  0.226446  0.815626       3  1.388349   0.981821      0.693158
# 7   0.294432  0.284628  0.874528       3  1.345527   0.848288      0.807518
# 8   0.228664  0.202491  0.834114       3  1.330008   1.012375      0.638541
# 9   0.274651  0.271985  0.846547       3  1.417454   0.864551      0.807412
# 10  0.228810  0.214798  0.908725       3  1.316075   0.968744      0.651393
#
#     k_ndcg_loo  rmse_loo  rmse_normalized_loo  num_users_loo
# 0           10  1.320171             0.787932             80
# 1           10  1.179473             0.944734             80
# 2           10  1.356202             0.811314             80
# 3           10  1.181765             0.954575             80
# 4           10  1.366832             0.819141             80
# 5           10  1.296641             0.924978             80
# 6           10  1.344098             0.873741             80
# 7           10  1.351342             0.856154             80
# 8           10  1.217874             0.933836             80
# 9           10  1.343642             0.835288             80
# 10          10  1.216594             0.958851             80

# %%
plot_mf_summary(df_results_exp, note="tiktok-exp")

# %%
df_results_exp.to_csv("data/results_mf_exp.csv")

# %% [markdown]
# # Matrix Factorization TikTok Real World data and ML

# %% [markdown]
# ## TikTok Real World data

# %%
df_tiktok_real = pd.read_csv("data/mf_perc_all_donations_real_world.csv", index_col=0)
df_tiktok_real.rename(columns={"email_md5": "user_id"}, inplace=True)
df_tiktok_real.head(5)
# Out:
#                             user_id             video_id  video_duration  \
# 0  4b11a2f56b0d686648a07460df5c0b76  6904810145583287557            13.0
# 1  4b11a2f56b0d686648a07460df5c0b76  6924107678360931590            32.0
# 2  4b11a2f56b0d686648a07460df5c0b76  6927315557029104902            21.0
# 3  4b11a2f56b0d686648a07460df5c0b76  6936164872799538438            15.0
# 4  4b11a2f56b0d686648a07460df5c0b76  6933686129736682757            33.0
#
#    percentage_watched
# 0               154.0
# 1                38.0
# 2               114.0
# 3                33.0
# 4                42.0

# %%
_ = calculate_density(df_tiktok_real)
# Out:
# Users: 347, Videos: 4121911
# Observed interactions: 7941712
# Density: 0.0056
# Sparsity: 0.9944

# %% [markdown]
# #### Reduzing the sparcity of TikTok Real World data

# %%
def create_subsample_videos_users(df, col_user='user_id', col_video='video_id', num=15):
    while True:
        # Filter videos
        video_user_counts = df.groupby(col_video)[col_user].nunique()
        valid_videos = video_user_counts[video_user_counts >= num].index
        df = df[df[col_video].isin(valid_videos)]
        
        # Filter users
        user_video_counts = df.groupby(col_user)[col_video].nunique()
        valid_users = user_video_counts[user_video_counts >= num].index
        df = df[df[col_user].isin(valid_users)]
        
        # Check if all constraints are satisfied
        if df.groupby(col_user)[col_video].nunique().min() >= num and \
           df.groupby(col_video)[col_user].nunique().min() >= num:
            break

    print(f"Remaining users: {df[col_user].nunique()}")
    print(f"Remaining videos: {df[col_video].nunique()}")
    print(f"Remaining interactions: {len(df)}")
    
    return df

# %%
df_tiktok_real = create_subsample_videos_users(df_tiktok_real, num=15) 
# only videos watched by AT LEAST *NUM* people & people who watched AT LEAST *NUM* videos
# Out:
# Remaining users: 334
# Remaining videos: 21416
# Remaining interactions: 598251

# %%
df_mf_tiktok_real = df_tiktok_real.loc[:,["video_id", "user_id", "percentage_watched"]]

# %% [markdown]
# ### Rating 1-5

# %%
df_mf_tiktok_real = df_mf_tiktok_real.rename(columns={"percentage_watched": "rating"})
df_mf_tiktok_real["rating"] = df_mf_tiktok_real["rating"].clip(0, 100)
df_mf_tiktok_real["rating"] = round((df_mf_tiktok_real["rating"]/100) * 4 + 1, 0) #rating 1-5

# %%
df_mf_tiktok_real[["rating"]].hist(figsize=(5,2))
plt.title("Distribution of video percentage watched \"rating\"")
# Out:
# Text(0.5, 1.0, 'Distribution of video percentage watched "rating"')

# %%
_ = calculate_density(df_mf_tiktok_real)
# Out:
# Users: 334, Videos: 21416
# Observed interactions: 598251
# Density: 0.0836
# Sparsity: 0.9164

# %%
summary_plot_ratings(df_mf_tiktok_real)
# Out:
# Most active user: db528c1228870a562aabb4e85f81636d (8531 ratings)
# Most rated video: 6979490739889753350 (157 ratings)

# %%
df_tiktok_real[["video_duration"]].describe()
# Out:
#        video_duration
# count   598251.000000
# mean        28.861688
# std         30.549176
# min          0.000000
# 25%         12.000000
# 50%         17.000000
# 75%         33.000000
# max        300.000000

# %%
df_tiktok_real[["video_duration"]].hist(figsize=(5,2))
plt.title("Distribution of video duration")
# Out:
# Text(0.5, 1.0, 'Distribution of video duration')

# %%
param_grid = {
    'n_components': [2, 5, 10, 20, 50, 100, 124],
    'max_iter': [1000, 2000, 3000],
    'init': ['random'],
    'model_type': ['svd'],
    'n_iter': [1, 3, 5, 10, 15]
}

R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_normalized, best_param = grid_search_mf_bias(df_mf_tiktok_real, param_grid, print_info=False)
# Out:
# (598251, 3) (478471, 3) (119780, 3)
# 478471 119780 119650.20000000001
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1}
# ✅ Best RMSE on TEST: 1.5466, NDCG@3: 0.8031 (len:334), normalized RMSE: 1.5466
#
# 📈 Explained Variance (for best SVD only): 0.027520242669569688
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None

# %%
cm = plot_confusion_matrix_ratings(R_test, R_estimated)
# Out:
# Test size: 114212
# Accuracy: 0.1854
# Precision (macro): 0.3054
# Recall (macro): 0.2113
# F1 Score (macro): 0.1447

# %%
best_metrics = grid_search_mf_bias_loou_ndcg(df_mf_tiktok_real, best_param)
# Out:
# (598251, 3)
# (598251, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1} ===
#   Left-out user 052f9630e3db689123da58fc108031d9: NDCG@10=0.0000, n_test_items=323
#   Left-out user 05ab0303fcacd5a317b2ae09139d2f90: NDCG@10=0.2091, n_test_items=3647
#   Left-out user 05e5cb7c62f3231151833fc2f9c14e26: NDCG@10=0.0000, n_test_items=251
#   Left-out user 076f72958232d0807c41c7e9f998f700: NDCG@10=0.0000, n_test_items=3043
#   Left-out user 087b10f90b88c964f3753b2e96d692af: NDCG@10=0.0000, n_test_items=35
#   Left-out user 0b21e0687828ef44ea07681a70516403: NDCG@10=0.2381, n_test_items=2400
#   Left-out user 0d3e5f43ebd0e0e1e7b6cd0dea2c834a: NDCG@10=0.0000, n_test_items=57
#   Left-out user 0d9cb0e2fc8cdcc2c14f9280e68d7675: NDCG@10=0.0000, n_test_items=198
#   Left-out user 0dbe1e9bc9b5fa04df02d7d41387200f: NDCG@10=0.0000, n_test_items=56
#   Left-out user 0e69a81894779495dc08cecca018fb58: NDCG@10=0.0000, n_test_items=888
#   Left-out user 0e95162c2b3c14828987a49621134ffd: NDCG@10=0.0000, n_test_items=707
#   Left-out user 0ea625614dacc2750aaf93ba9386f04b: NDCG@10=0.1913, n_test_items=1292
#   Left-out user 0ef1b453b67410d98c1367403349ae33: NDCG@10=0.0000, n_test_items=163
#   Left-out user 0fd17efbacf85c58a77377d252e05a6c: NDCG@10=0.0000, n_test_items=862
#   Left-out user 102150a808c31e245734412261431d32: NDCG@10=0.0000, n_test_items=518
#   Left-out user 12abb37f503259b8a48c86077c27ba03: NDCG@10=0.0476, n_test_items=2357
#   Left-out user 137804c0e789adde207f4cf0e524fc3a: NDCG@10=0.0000, n_test_items=173
#   Left-out user 13cbe3e4b325cd5b555a46f18c68fa59: NDCG@10=0.0000, n_test_items=50
#   Left-out user 15424295d7705106ef5e24ac9eea096d: NDCG@10=0.0000, n_test_items=1556
#   Left-out user 15459844d914a9c74b876b5807168b82: NDCG@10=0.0000, n_test_items=276
#   Left-out user 17a9ea69fccd32487949dee7750c3295: NDCG@10=0.0000, n_test_items=960
#   Left-out user 1964bf8f4c07ecdf673761a7e2f9d0b8: NDCG@10=0.0000, n_test_items=1259
#   Left-out user 1996515c9517c0cb01b93b7c5d765bd7: NDCG@10=0.0000, n_test_items=61
#   Left-out user 19ac140ea80427a6356e696615285c72: NDCG@10=0.0000, n_test_items=36
#   Left-out user 19c44519c804fed6d647029703d8a6fb: NDCG@10=0.0000, n_test_items=395
#   Left-out user 1bce27bbf94b95096a4066bd599313fa: NDCG@10=0.0000, n_test_items=109
#   Left-out user 1c0003f8e50eb4f4fb92fb9c0c46eaa7: NDCG@10=0.0000, n_test_items=985
#   Left-out user 1cce06370bb01af6a542cf896880600e: NDCG@10=0.0000, n_test_items=121
#   Left-out user 1e7bb1200c8b4d4a6998c9a82c35ef8f: NDCG@10=0.0000, n_test_items=23
#   Left-out user 1ef2f6ff5d6d43d79afccfdd5cb36f2f: NDCG@10=0.0000, n_test_items=487
#   Left-out user 1fe00c9118a3274f914159331ee52f52: NDCG@10=0.0000, n_test_items=462
#   Left-out user 21102041d7ba33f8002f059b5d340bc7: NDCG@10=0.1429, n_test_items=2845
#   Left-out user 2302b2facf7649c5a7fc99987c001344: NDCG@10=0.0000, n_test_items=948
#   Left-out user 23e4254f85d251e950894139fcaf49e2: NDCG@10=0.0476, n_test_items=998
#   Left-out user 255a985563ad1261d47e9208a7152e1b: NDCG@10=0.0000, n_test_items=210
#   Left-out user 25cb2512c9b12ed5d8f81daa57d5aae2: NDCG@10=0.0000, n_test_items=556
#   Left-out user 28a092120f0ed6d1b3c2d334e4af5568: NDCG@10=0.4818, n_test_items=5025
#   Left-out user 2917f6163e8e4ff90b9216b4c2809f38: NDCG@10=0.0952, n_test_items=3045
#   Left-out user 2aa21a7b3f8e5f365ab7131e15ea5594: NDCG@10=0.0960, n_test_items=4962
#   Left-out user 2b5b34dd7e218c96a725b9fa436c2c92: NDCG@10=0.0545, n_test_items=2175
#   Left-out user 2bc8b180f7cddc63c3aac9c3735dbd5f: NDCG@10=0.0000, n_test_items=1871
#   Left-out user 2d5130067f092afdb354be9ed2bc08c0: NDCG@10=0.0000, n_test_items=832
#   Left-out user 2dfa08a38607d7b2defdfeb495640d51: NDCG@10=0.0000, n_test_items=235
#   Left-out user 2e529ee770042ddca25437929e74c4f8: NDCG@10=0.0636, n_test_items=1121
#   Left-out user 2ecf17461d0902650f3b429d4bf9e635: NDCG@10=0.0000, n_test_items=530
#   Left-out user 30a9d7f9a643a5e737538e6704d9ac0a: NDCG@10=0.0000, n_test_items=512
#   Left-out user 30f492cc2f83d120cc717657264a493d: NDCG@10=0.0000, n_test_items=915
#   Left-out user 3317144fdcd77eeadeb0159766d9e101: NDCG@10=0.0000, n_test_items=138
#   Left-out user 332d80d28657ac16f3e8eb12789220e2: NDCG@10=0.0000, n_test_items=3208
#   Left-out user 336827fdc3789e6bd2010eae5ab0f9c7: NDCG@10=0.3810, n_test_items=5998
#   Left-out user 343f92c0e1899b010c7c0edf0ebe7a7d: NDCG@10=0.0000, n_test_items=479
#   Left-out user 34e6785c087dd04f7017637fdaac6935: NDCG@10=0.0818, n_test_items=4217
#   Left-out user 3547fb5186df001d444756e4ee5f2591: NDCG@10=0.1429, n_test_items=4947
#   Left-out user 37fe1f2671505d68d1b0f8840dd8647d: NDCG@10=0.0000, n_test_items=300
#   Left-out user 3823d017a87751a777883f3ecf6bcd7b: NDCG@10=0.0000, n_test_items=638
#   Left-out user 38a0265b9fe0e0b72f5704e972bc2514: NDCG@10=0.0476, n_test_items=817
#   Left-out user 3974f7feab8685e2fab51493f3f9440e: NDCG@10=0.2160, n_test_items=2740
#   Left-out user 39aa010cf288ebb8eacf338ef044c10c: NDCG@10=0.0000, n_test_items=87
#   Left-out user 3a92a13fe50df44c206dbfa28657a970: NDCG@10=0.0000, n_test_items=2627
#   Left-out user 3b1dd81b22ca85221075f2a0247e76b6: NDCG@10=0.0000, n_test_items=2274
#   Left-out user 3e45119c86cf3833ee15e1713223f189: NDCG@10=0.0476, n_test_items=2928
#   Left-out user 3e715fee944f2092a0eeb0ab8faa23d0: NDCG@10=0.0000, n_test_items=2026
#   Left-out user 3f13460fee63f7e60264cdaadc02cb28: NDCG@10=0.0000, n_test_items=525
#   Left-out user 3fd079e17ad60c9c6aad2d047935a4fa: NDCG@10=0.0000, n_test_items=73
#   Left-out user 4068ad24fede755988ada6f2afced976: NDCG@10=0.0476, n_test_items=5542
#   Left-out user 406daeec631e809cc1bdfa76de6d52d9: NDCG@10=0.1417, n_test_items=3282
#   Left-out user 40a03696dbdb0ee85336b9ca9e7a695f: NDCG@10=0.0000, n_test_items=295
#   Left-out user 40ba2c296a0ef074f0cbe157f125c77a: NDCG@10=0.0000, n_test_items=1159
#   Left-out user 41ac64f0197420ef325649f39fd6c009: NDCG@10=0.0000, n_test_items=558
#   Left-out user 4297f216570039d1b3dd115cee43c8b5: NDCG@10=0.0000, n_test_items=1740
#   Left-out user 42b55c91da8f2dfc8a3811e7560ba476: NDCG@10=0.2167, n_test_items=4727
#   Left-out user 42e4eeaf8f6aaaab2e26b3d9f7cdf6dc: NDCG@10=0.0000, n_test_items=1354
#   Left-out user 43376387e78ea356a179511fd199aa84: NDCG@10=0.1905, n_test_items=3007
#   Left-out user 44348b56c7a6629e3b06586cc5ccccde: NDCG@10=0.0696, n_test_items=2407
#   Left-out user 46c4306fb1b6e7086ed289b3f79e36d1: NDCG@10=0.1429, n_test_items=4784
#   Left-out user 4884fad8f1ef4c64e667fe35b59ae2d2: NDCG@10=0.0476, n_test_items=816
#   Left-out user 499140967d3c5a0471b82643791c385a: NDCG@10=0.0000, n_test_items=141
#   Left-out user 49afcdfeefb9d054c38692ea54f6cccc: NDCG@10=0.0476, n_test_items=746
#   Left-out user 49b7d10e7254ab76d59dfdda71585074: NDCG@10=0.0000, n_test_items=109
#   Left-out user 4a0af3921fb7aac0f78dbccde7b441fd: NDCG@10=0.0476, n_test_items=3220
#   Left-out user 4a0de4b76c69664b16fed903626b1ed5: NDCG@10=0.0182, n_test_items=1470
#   Left-out user 4b11a2f56b0d686648a07460df5c0b76: NDCG@10=0.1429, n_test_items=2119
#   Left-out user 4c189c06d7ba7bbd012b9c145e25619b: NDCG@10=0.0000, n_test_items=28
#   Left-out user 4c71c19ac7b08c18a995f0a65333f71f: NDCG@10=0.0000, n_test_items=1155
#   Left-out user 4dcf5beeb2ab6c55415663b0c5d9f95e: NDCG@10=0.0000, n_test_items=197
#   Left-out user 4de03bb326ea2d91bc18a1dff1f29e09: NDCG@10=0.0000, n_test_items=417
#   Left-out user 4e04810735ee047d9b9be48e136ab5d1: NDCG@10=0.0000, n_test_items=875
#   Left-out user 4f26e2367e813265511193120050a83a: NDCG@10=0.1000, n_test_items=5590
#   Left-out user 507bb312519d0352acb3dc92a7bcfeb2: NDCG@10=0.3185, n_test_items=3475
#   Left-out user 5103a66de51fd6c79a902e5a533fd0d3: NDCG@10=0.0000, n_test_items=24
#   Left-out user 51c768b0847e5e3110cc1ee553cab5bb: NDCG@10=0.0348, n_test_items=895
#   Left-out user 520c7ca606f866cd05f96a99a5781857: NDCG@10=0.1739, n_test_items=4782
#   Left-out user 528805dfa4495d6e8ac97f881ba54a93: NDCG@10=0.0000, n_test_items=63
#   Left-out user 548da090423d7988b4cee214a6ee7d1c: NDCG@10=0.0636, n_test_items=1821
#   Left-out user 5520bd4de4a77552c1d9094a0533bcde: NDCG@10=0.0000, n_test_items=42
#   Left-out user 570c9378801a8b7bcc508bf3888dacdd: NDCG@10=0.1545, n_test_items=3387
#   Left-out user 5715af9f68d0bc5b9874d912439468a4: NDCG@10=0.0545, n_test_items=2391
#   Left-out user 57323ce3500a7a866d69d7f104eb4890: NDCG@10=0.0000, n_test_items=556
#   Left-out user 57ae16c4ed0a5dca87925881413938d8: NDCG@10=0.1478, n_test_items=2835
#   Left-out user 57af84aa4b30181d4d9d7c2a626dc06e: NDCG@10=0.0000, n_test_items=1129
#   Left-out user 57c9cc2ac02b4894eb027323a0c50010: NDCG@10=0.0000, n_test_items=904
#   Left-out user 599ceff0a84dc8cf9178880acca5213f: NDCG@10=0.0000, n_test_items=63
#   Left-out user 5a22d0fc0842fd9194f1ea38712f66f6: NDCG@10=0.0609, n_test_items=1951
#   Left-out user 5a86cf996f5da8513530d839aefec9a5: NDCG@10=0.0000, n_test_items=698
#   Left-out user 5b0e3171111759b19d32ed6b8f71dfbc: NDCG@10=0.3478, n_test_items=3692
#   Left-out user 5bac7fedbf1056f90292483c7bdaa3f7: NDCG@10=0.0000, n_test_items=1071
#   Left-out user 5c71a22110f8799370bde7f45349ceed: NDCG@10=0.0000, n_test_items=342
#   Left-out user 5c94f3e0be7e65faf11d480a7fc76d88: NDCG@10=0.0000, n_test_items=363
#   Left-out user 5ddaf79effbe3d0b9b8a7f41e8eee944: NDCG@10=0.0000, n_test_items=168
#   Left-out user 5e4e748682843750177dedd54abc6817: NDCG@10=0.0636, n_test_items=684
#   Left-out user 5edc7fac7178f39672b9387bde6b45c3: NDCG@10=0.0000, n_test_items=55
#   Left-out user 5ef7eb7ed57c696c5ae8602ee22706b3: NDCG@10=0.4000, n_test_items=4004
#   Left-out user 60196aa0ec61d5fc79ccd2d4c02c46af: NDCG@10=0.0000, n_test_items=631
#   Left-out user 604f7333f04114b863497d0159e65e78: NDCG@10=0.0000, n_test_items=593
#   Left-out user 6061ee13eef22979c9b019bbb5526069: NDCG@10=0.2333, n_test_items=2338
#   Left-out user 607cb1a5d022cd92eae9932c3191a732: NDCG@10=0.1130, n_test_items=1414
#   Left-out user 60d2994860f1d12b76f594e3543e6e71: NDCG@10=0.0952, n_test_items=1422
#   Left-out user 629287b369ac062b5aabf335b57be814: NDCG@10=0.4286, n_test_items=3457
#   Left-out user 630c54bf5947f4518d41c758d55f3620: NDCG@10=0.0000, n_test_items=211
#   Left-out user 6338c66185bed178e2842c313e91bd16: NDCG@10=0.1905, n_test_items=2129
#   Left-out user 6400c1f18085936e736b4f9da4fcac54: NDCG@10=0.0000, n_test_items=189
#   Left-out user 67491ceff046cc7972f4502a6491e652: NDCG@10=0.4000, n_test_items=3663
#   Left-out user 67eda3f0faec6c8db4d3aaf0bfb8cd89: NDCG@10=0.1905, n_test_items=2662
#   Left-out user 691be87b9359f1a523d662b30aebaeaa: NDCG@10=0.0000, n_test_items=213
#   Left-out user 6aa5523048f6d068d395da3491e50aec: NDCG@10=0.0476, n_test_items=734
#   Left-out user 6aabc825deeac290f05b481a4c3b4b2f: NDCG@10=0.1478, n_test_items=5125
#   Left-out user 6dc440420258c0dc658eeb7087175447: NDCG@10=0.0000, n_test_items=511
#   Left-out user 6e12e1dfb66974cb5b7926c1a93370e6: NDCG@10=0.0000, n_test_items=209
#   Left-out user 6e2a5a480c1b3794db9ef93704bf7911: NDCG@10=0.0000, n_test_items=69
#   Left-out user 6f030cca3695043fbd1ab28a80fa1642: NDCG@10=0.0000, n_test_items=72
#   Left-out user 6f3ee61714f01a03a1f336016a971c98: NDCG@10=0.0000, n_test_items=588
#   Left-out user 6ffdc203c4100200dc86e79a4627a4a2: NDCG@10=0.0000, n_test_items=220
#   Left-out user 7091415866d5d0b9cb0f9be9cca3dbe9: NDCG@10=0.0000, n_test_items=298
#   Left-out user 736f55466e60cc5b89efff729c6aead1: NDCG@10=0.0000, n_test_items=81
#   Left-out user 75beba3a959306b160d8e550de5d0828: NDCG@10=0.0952, n_test_items=4950
#   Left-out user 75d0a99bbe07bd245b3e0bf14dde4a7a: NDCG@10=0.0000, n_test_items=136
#   Left-out user 75f74ef71a30ea288a1080cfc003270b: NDCG@10=0.0476, n_test_items=2280
#   Left-out user 760876a30551767cb8dbfd9540033fc0: NDCG@10=0.0476, n_test_items=1071
#   Left-out user 76b19aa2995ca4b75d0a00ea8697a952: NDCG@10=0.0000, n_test_items=180
#   Left-out user 78bd94ee2fb6e1d7689192c52d0ce784: NDCG@10=0.0000, n_test_items=295
#   Left-out user 7937913e1b3414ed466bd7468c537681: NDCG@10=0.0476, n_test_items=1705
#   Left-out user 7997e04a523b022071b7946830bfec9a: NDCG@10=0.0476, n_test_items=695
#   Left-out user 7bebee95d3a8f58bd668f9b3a9a37ac9: NDCG@10=0.0000, n_test_items=930
#   Left-out user 7cd41b5e73b3a86f2301b66d207c9db6: NDCG@10=0.0000, n_test_items=576
#   Left-out user 7d25c880b7427084b5a0001abd6cef21: NDCG@10=0.1000, n_test_items=2750
#   Left-out user 7d3b625c9e1756e7eccadb5e7507d785: NDCG@10=0.0000, n_test_items=200
#   Left-out user 7e5d5c610d39a23bf469a4cf86a68159: NDCG@10=0.0000, n_test_items=65
#   Left-out user 7e7f3042796772b9720f875648e1e390: NDCG@10=0.0476, n_test_items=622
#   Left-out user 7ed4dec827db3ef02d0c3260704f72b2: NDCG@10=0.1545, n_test_items=2526
#   Left-out user 7eef5f8cf623fa53cd76144928bbd075: NDCG@10=0.0000, n_test_items=458
#   Left-out user 7f4248d5d43dce6c96972008b627a58f: NDCG@10=0.0000, n_test_items=74
#   Left-out user 7f7d5323d00cda473c6cccf3cd1dd350: NDCG@10=0.0348, n_test_items=4721
#   Left-out user 8029fea2643a45f6c3346aae9ab56596: NDCG@10=0.0000, n_test_items=473
#   Left-out user 806fc581a43ba60b0f46c4e4717692e6: NDCG@10=0.0000, n_test_items=16
#   Left-out user 80abd77077bdc11308178d830d50966b: NDCG@10=0.0000, n_test_items=1444
#   Left-out user 8272c4f28e6b137c4b3139118e5a493f: NDCG@10=0.0783, n_test_items=2686
#   Left-out user 82fa387d8dffd9832ee488542a068d15: NDCG@10=0.0000, n_test_items=638
#   Left-out user 8322389ae010fbd858d7fd1981159292: NDCG@10=0.0000, n_test_items=3282
#   Left-out user 841831a1f2fb0209030ac0426cb430c8: NDCG@10=0.0000, n_test_items=1080
#   Left-out user 8471a959fed8614e8dd5a62c97530fe8: NDCG@10=0.0000, n_test_items=132
#   Left-out user 84e4d48000f53b053bb6e713fd9f0ff6: NDCG@10=0.0000, n_test_items=94
#   Left-out user 8579f5442d69fef62c14ef0089b53120: NDCG@10=0.0000, n_test_items=124
#   Left-out user 85991072f65697d7ae7cc35ff4ff6421: NDCG@10=0.0000, n_test_items=1006
#   Left-out user 85cfa0f9e44950c26f5b5d65cb2f3d2e: NDCG@10=0.1429, n_test_items=3734
#   Left-out user 85f3fa94f6d5cfc6d2b3ea0f944ccb7b: NDCG@10=0.0000, n_test_items=229
#   Left-out user 863c4b751397e49e5d335f84a99e041f: NDCG@10=0.0000, n_test_items=1085
#   Left-out user 88f430db28e75019041a51776cd759f9: NDCG@10=0.0000, n_test_items=132
#   Left-out user 8a614460361b54fc395b8bd133f3d53a: NDCG@10=0.3750, n_test_items=3605
#   Left-out user 8afff0bd59b3e9e2915c56d848503189: NDCG@10=0.0000, n_test_items=2750
#   Left-out user 8b5874fb0a1f2aac47ca477a2f8810f5: NDCG@10=0.0000, n_test_items=471
#   Left-out user 8c8b78d09aabfeb56e0cff6bdadf9932: NDCG@10=0.0000, n_test_items=1758
#   Left-out user 8d125ec3ed4e911cc40fc2c7feca4665: NDCG@10=0.0000, n_test_items=116
#   Left-out user 8d3fb00a64dd788221f3aecbfbfee218: NDCG@10=0.0000, n_test_items=998
#   Left-out user 8e8570de6673c5c33386a25fcc76c249: NDCG@10=0.1905, n_test_items=6197
#   Left-out user 8f73da1e8ae660c7513641d9d59e8f6b: NDCG@10=0.0000, n_test_items=1512
#   Left-out user 90d64ce67a462da5e3e72e9a6ed6cf72: NDCG@10=0.0000, n_test_items=211
#   Left-out user 918e2de571fe5d21a5cb03df0972106d: NDCG@10=0.5391, n_test_items=4158
#   Left-out user 92120756a22d7133085b14eec1bbd96b: NDCG@10=0.1182, n_test_items=3097
#   Left-out user 9275cf3a9831f938667626eeec7b7c74: NDCG@10=0.4640, n_test_items=5267
#   Left-out user 92ec19edd2ed135056691b13cb35ff63: NDCG@10=0.1905, n_test_items=2771
#   Left-out user 935adc97adb465b94b07a241069425cc: NDCG@10=0.0917, n_test_items=1208
#   Left-out user 936afe4c6c620965afea35c37b44f833: NDCG@10=0.0273, n_test_items=1807
#   Left-out user 9466223293e5ddf532ce93b87dd04fad: NDCG@10=0.0000, n_test_items=70
#   Left-out user 94bd6242868ab1d3f43f085ad757ff7b: NDCG@10=0.0000, n_test_items=2003
#   Left-out user 95dfc7e4ac06738557fad16ee021644b: NDCG@10=0.0000, n_test_items=810
#   Left-out user 95fea58479822e5942a339b817d92b6b: NDCG@10=0.0000, n_test_items=524
#   Left-out user 9610f77463aa1dc2bda5f923337a21d7: NDCG@10=0.0000, n_test_items=223
#   Left-out user 98e5244f8bb68b5740850ab24573c017: NDCG@10=0.0000, n_test_items=65
#   Left-out user 9913d7d4c4014e75f4d71c1fb709f7b9: NDCG@10=0.0000, n_test_items=460
#   Left-out user 99959ca3dfe40d82568db050596948b4: NDCG@10=0.0000, n_test_items=606
#   Left-out user 99cd9e6aeccdec9e6bf744e292171c18: NDCG@10=0.0000, n_test_items=145
#   Left-out user 99d56dfa2bf934a4a48435271c9015a3: NDCG@10=0.0000, n_test_items=417
#   Left-out user 9a31ea87f222c2ed002d81cf237fcc9d: NDCG@10=0.0000, n_test_items=2299
#   Left-out user 9a3390e99fa2f377e6a91a586f89af0e: NDCG@10=0.0000, n_test_items=669
#   Left-out user 9b763981424074df93c6b9aa101c4485: NDCG@10=0.0000, n_test_items=910
#   Left-out user 9bc296bebd5a88045279fac4abde279e: NDCG@10=0.2783, n_test_items=1581
#   Left-out user 9d30bf7bc95f0ce348ff947cbf5b1dca: NDCG@10=0.0000, n_test_items=460
#   Left-out user 9e29c60e447028e52d9b52c3059ecbe7: NDCG@10=0.0952, n_test_items=1226
#   Left-out user 9ea7daabbdc3c56d9e54235bddb889d7: NDCG@10=0.0000, n_test_items=520
#   Left-out user 9fb20ba713b179f24495f6d969bf42fd: NDCG@10=0.0000, n_test_items=368
#   Left-out user 9fcef0961596a361e45178cbe7664b76: NDCG@10=0.0476, n_test_items=354
#   Left-out user 9fe384d5aae32897fb237f0bc1fa735f: NDCG@10=0.0476, n_test_items=1345
#   Left-out user 9fe9468f2714c2f43acff287fd785985: NDCG@10=0.0000, n_test_items=240
#   Left-out user a0283278a2762f9f893c172ce2ae28ae: NDCG@10=0.1429, n_test_items=1380
#   Left-out user a21805b93948e07b3ca19399aaa26a1b: NDCG@10=0.0000, n_test_items=113
#   Left-out user a25995ac5c430a097fe42c5b80cbca93: NDCG@10=0.0000, n_test_items=52
#   Left-out user a2dc9281b961eef6e29d66335a20b7bf: NDCG@10=0.0000, n_test_items=564
#   Left-out user a3c9df5b15b0a6b1926a929f745f6355: NDCG@10=0.4087, n_test_items=2714
#   Left-out user a60f9da2acfcd81a1722df5938f1e1a7: NDCG@10=0.2381, n_test_items=3794
#   Left-out user a670f905b78ce21ec5ae78fb1e514d88: NDCG@10=0.0000, n_test_items=523
#   Left-out user a6c0cda9061b82a0951cc1de293af62e: NDCG@10=0.0000, n_test_items=1413
#   Left-out user aa4a6fa20ef0be3b9e8f8ceb3f075858: NDCG@10=0.4667, n_test_items=3299
#   Left-out user aa4c1abbf29d76cf70f7740bfc85a35f: NDCG@10=0.1304, n_test_items=7208
#   Left-out user aa98334a880507fb150021be7b2a37e0: NDCG@10=0.0476, n_test_items=526
#   Left-out user aace0606f25529cb645f28c6c0586577: NDCG@10=0.0000, n_test_items=527
#   Left-out user add03e608bef35f1c5bc13d990b9f317: NDCG@10=0.0000, n_test_items=136
#   Left-out user add247ff11a1cdd16f3117878d70b7f2: NDCG@10=0.0000, n_test_items=6460
#   Left-out user aeb4a7d549713081c22fac75981733fb: NDCG@10=0.1545, n_test_items=2832
#   Left-out user af225c460d5c2574c30c1233e040437c: NDCG@10=0.0091, n_test_items=1746
#   Left-out user b0a136d836a3dc742bd514ac3c6f4b92: NDCG@10=0.2783, n_test_items=6935
#   Left-out user b12e08675d640e90df6dfa3923574286: NDCG@10=0.0000, n_test_items=1374
#   Left-out user b30192f8313c378cc0a158f0563ae1d9: NDCG@10=0.0000, n_test_items=1193
#   Left-out user b3740aaa07240ffa5201a93b09899e77: NDCG@10=0.0476, n_test_items=833
#   Left-out user b4e1d8d3fe1381c841c9c8a87ca6753f: NDCG@10=0.0000, n_test_items=497
#   Left-out user b7053409ecb49ac940b9c43f1cd43de8: NDCG@10=0.0000, n_test_items=908
#   Left-out user b719e3f0e9502a6955333f344a864d0c: NDCG@10=0.0000, n_test_items=2789
#   Left-out user b78c646642bdefa4358dbe41c7fd8519: NDCG@10=0.1429, n_test_items=1804
#   Left-out user b81c3bab6d9c61ba9833434717095b6c: NDCG@10=0.0000, n_test_items=437
#   Left-out user b91d595b94b0dbf77368c65d799a51fc: NDCG@10=0.0000, n_test_items=335
#   Left-out user ba17211868c4341e8beb1e05d15ee35a: NDCG@10=0.0000, n_test_items=5552
#   Left-out user ba1c26c63f66b311541d7f7d4f330a99: NDCG@10=0.0000, n_test_items=458
#   Left-out user ba2d5114cfba51db92fb1076f543998c: NDCG@10=0.0000, n_test_items=1250
#   Left-out user ba3aead3e7d97af7c8447f68db6926d0: NDCG@10=0.0000, n_test_items=28
#   Left-out user bb953b3f720c17ef70b54b1433edf042: NDCG@10=0.1000, n_test_items=2452
#   Left-out user bc4b888d497b89951ecccb7bbf6116d4: NDCG@10=0.0636, n_test_items=1891
#   Left-out user bc7584dd10c17c7ab7b13e6ac9523a4d: NDCG@10=0.0000, n_test_items=51
#   Left-out user bc7dbd351ed5e2bc359ac6a36247590d: NDCG@10=0.0000, n_test_items=1443
#   Left-out user bdb3c7577a14fd1cd125290c197504fb: NDCG@10=0.1429, n_test_items=4115
#   Left-out user bdf87a5f07383649d749765e8db6f3a7: NDCG@10=0.0476, n_test_items=769
#   Left-out user be95d2d16b9220ea3906643d54b59a90: NDCG@10=0.0000, n_test_items=193
#   Left-out user c055083da103f98b8c75d24e933a73d5: NDCG@10=0.0000, n_test_items=319
#   Left-out user c11b38b53d8d318d4321d31922de1852: NDCG@10=0.0000, n_test_items=37
#   Left-out user c2f4f8d9c3d4836c783fb25db228bdcc: NDCG@10=0.0000, n_test_items=333
#   Left-out user c3fed64b100f211f4fa106b65dfde8d2: NDCG@10=0.0476, n_test_items=1452
#   Left-out user c4360c1edb8b4195581ae0f0ca366449: NDCG@10=0.0364, n_test_items=1722
#   Left-out user c4b5ed8e35f0a55a4bfbdcbbcacfe131: NDCG@10=0.0182, n_test_items=3685
#   Left-out user c4cbbbf32176fcc196795d56eb21d0e5: NDCG@10=0.0000, n_test_items=252
#   Left-out user c55eb3a5c4871e90cf83519d30b8f9c9: NDCG@10=0.0476, n_test_items=789
#   Left-out user c625e60059faad10f733ab395917506b: NDCG@10=0.0476, n_test_items=2393
#   Left-out user c78859a8b046c9e6ee28094abe874e83: NDCG@10=0.0182, n_test_items=2358
#   Left-out user c87b7cc0f0baae94203da80370f4990b: NDCG@10=0.0476, n_test_items=451
#   Left-out user c8de92d9ad2a1b6e90b8ab7eedb6ebeb: NDCG@10=0.0000, n_test_items=1433
#   Left-out user c9a7b8be73ebd53a4fe482cb1ff05e52: NDCG@10=0.1429, n_test_items=2906
#   Left-out user caf6b231df17d862a8afb50fedd7497d: NDCG@10=0.0182, n_test_items=973
#   Left-out user cb4d02891b7388a483d4d62f08b0b898: NDCG@10=0.0476, n_test_items=534
#   Left-out user cb6370414c535a767a05f4fb8584e4e0: NDCG@10=0.1909, n_test_items=5252
#   Left-out user ccbdf84a9f25aba01e8eed1b6e402cfc: NDCG@10=0.1182, n_test_items=1964
#   Left-out user cde5c36cf21a04c93c5d638a47d93a14: NDCG@10=0.0000, n_test_items=83
#   Left-out user cdeb1f2e7d41de1a12dd891dd0da9b7a: NDCG@10=0.0000, n_test_items=97
#   Left-out user ce619e04a6c578502eb47d2e8fa0734d: NDCG@10=0.0000, n_test_items=909
#   Left-out user ceb9a212ab4d8fb0be9828beb020a848: NDCG@10=0.1391, n_test_items=5004
#   Left-out user cf780f4ddcb8c00c6ac23afb37d52dae: NDCG@10=0.0000, n_test_items=29
#   Left-out user cfa4293588943a18e329ec9450fe4f58: NDCG@10=0.0182, n_test_items=321
#   Left-out user d0b81b79c5da3ee544a0b549ab11bf36: NDCG@10=0.2091, n_test_items=5001
#   Left-out user d117b1fa4816274bad3b124f9bc9b836: NDCG@10=0.0476, n_test_items=463
#   Left-out user d13d54bc573490213cee7196c2d99198: NDCG@10=0.0000, n_test_items=1351
#   Left-out user d17757f195bed106b840b05c31620d90: NDCG@10=0.0000, n_test_items=306
#   Left-out user d3da2778eaf14237dde32b08093ba865: NDCG@10=0.0476, n_test_items=663
#   Left-out user d4cdb2e4a1175556acdd10284391ce30: NDCG@10=0.1091, n_test_items=1747
#   Left-out user d6b6d8a6c6346626c8d673519ae16c5d: NDCG@10=0.1000, n_test_items=6812
#   Left-out user d91f62b3addd8857dfd7f15f5dc19144: NDCG@10=0.4583, n_test_items=3590
#   Left-out user d94f12386537c7bb53c64c7f95c72dae: NDCG@10=0.0273, n_test_items=769
#   Left-out user da1aa3e04bbce323b1bdf31e1c2e11de: NDCG@10=0.0000, n_test_items=23
#   Left-out user db22c3330010b7395e482bfd30499d5d: NDCG@10=0.0091, n_test_items=448
#   Left-out user db528c1228870a562aabb4e85f81636d: NDCG@10=0.4741, n_test_items=8531
#   Left-out user db7b75dd3496d2f16b3dc8c789128389: NDCG@10=0.0476, n_test_items=4245
#   Left-out user dc503db1918adfdb82e50018075e4e86: NDCG@10=0.0000, n_test_items=544
#   Left-out user dca8dee49b5b5498e153a81baa6ffb83: NDCG@10=0.0182, n_test_items=2544
#   Left-out user dcb9bd758192391033375e09b35c4f86: NDCG@10=0.1429, n_test_items=939
#   Left-out user e1b8d11473458133ac34f21f84e68cc2: NDCG@10=0.0000, n_test_items=396
#   Left-out user e327f9b0d0253e05a2eb27da88a5978e: NDCG@10=0.1905, n_test_items=1038
#   Left-out user e4973ba7fb519cb1ae2712fe22336fc5: NDCG@10=0.0000, n_test_items=101
#   Left-out user e498ee8ef660429ee298d3b03851f633: NDCG@10=0.0091, n_test_items=288
#   Left-out user e4e65ae9328f589369fe193b4615fb47: NDCG@10=0.1429, n_test_items=2705
#   Left-out user e5274c8192b0f0baed7503da938ec7c6: NDCG@10=0.0273, n_test_items=2743
#   Left-out user e53917e067246f32375050cf300cb4b1: NDCG@10=0.2545, n_test_items=1756
#   Left-out user e5638817a49654844029877d07dde483: NDCG@10=0.3920, n_test_items=2688
#   Left-out user e583814caefc5c78f3fd2dc01571e862: NDCG@10=0.0000, n_test_items=3372
#   Left-out user e607194702fd4205848d2c3b5b164a51: NDCG@10=0.0000, n_test_items=495
#   Left-out user e628020db39ca283d83a6e5a5beb6289: NDCG@10=0.0000, n_test_items=279
#   Left-out user e63b5aaaf83943bfdc003af680d991f6: NDCG@10=0.0182, n_test_items=2091
#   Left-out user e6633a23f7ba8b1c231fbb5a7afd210b: NDCG@10=0.0000, n_test_items=3391
#   Left-out user e7aea83bd3881673b3997a3aae04246f: NDCG@10=0.0000, n_test_items=1283
#   Left-out user e95a3f90318b20cb34eb53b1661c6410: NDCG@10=0.2364, n_test_items=4174
#   Left-out user ea1f218dadb90c02a55e44fc1702c661: NDCG@10=0.0000, n_test_items=166
#   Left-out user eacaf8e8255da6a24858fcf0fd74119a: NDCG@10=0.0091, n_test_items=3455
#   Left-out user eb61cbb4b4d06c55abff1275d948c5c1: NDCG@10=0.0000, n_test_items=733
#   Left-out user eb8e38b302bcfbbfdf733053ea35ec0d: NDCG@10=0.0000, n_test_items=373
#   Left-out user eba9fa22681fa1464dbed7172d293429: NDCG@10=0.0000, n_test_items=179
#   Left-out user eefa81fd4a1e5ec72714527b20d5d064: NDCG@10=0.0000, n_test_items=973
#   Left-out user f00b1cc4098002bc33257ff3b6ad76a8: NDCG@10=0.0000, n_test_items=408
#   Left-out user f058da4cda7a047f1172c5f88a0a12de: NDCG@10=0.0000, n_test_items=70
#   Left-out user f0d8193888d5082bea4a9297a8fa1bc5: NDCG@10=0.3364, n_test_items=3848
#   Left-out user f13a2d26493632933a42f18040c1dafa: NDCG@10=0.0000, n_test_items=150
#   Left-out user f279dc20a57ca6e9c1e51fcebfd181d6: NDCG@10=0.0000, n_test_items=57
#   Left-out user f2cb35d7fde9d956b3de5dfa28d675af: NDCG@10=0.0952, n_test_items=1399
#   Left-out user f2df90328d03f94db7a421267dade931: NDCG@10=0.0000, n_test_items=113
#   Left-out user f353436d61cbda22cc7b7d4a8d2a734a: NDCG@10=0.0000, n_test_items=696
#   Left-out user f4625def3cd5f9b14b72af3d468a318c: NDCG@10=0.0000, n_test_items=1032
#   Left-out user f467382e1b52562ae15e151e0605c712: NDCG@10=0.0000, n_test_items=2438
#   Left-out user f49ecad2937f54ea688a95df503ff6a4: NDCG@10=0.0952, n_test_items=2442
#   Left-out user f4b983df51c8f36d9f277bf25e345a2e: NDCG@10=0.1520, n_test_items=3115
#   Left-out user f4e6d3e9954c8622e70a706e123d54f6: NDCG@10=0.0476, n_test_items=1003
#   Left-out user f6cefebbf6af74b3cb5564d274c73974: NDCG@10=0.0000, n_test_items=56
#   Left-out user f897d285b5939bce6b195002a7ccf7b1: NDCG@10=0.0000, n_test_items=206
#   Left-out user f8bde75134fadc750d7a6daeca685bdf: NDCG@10=0.0000, n_test_items=39
#   Left-out user f90fe34419be55e9007c820eb5772524: NDCG@10=0.0000, n_test_items=135
#   Left-out user f94fc655cf65e0187f96a833252ea923: NDCG@10=0.0000, n_test_items=446
#   Left-out user f9789c1bb9a0f71d11ee13fa2f31fbfc: NDCG@10=0.0952, n_test_items=2627
#   Left-out user f9f219a8ea089721d5fdfc91978d01d2: NDCG@10=0.0583, n_test_items=6206
#   Left-out user fa44ebc9638368e9f2e23e122e26ee9a: NDCG@10=0.0000, n_test_items=2619
#   Left-out user fac9b25bfb788251893522845b400bf1: NDCG@10=0.0000, n_test_items=358
#   Left-out user fbbfbcc25919d85047836acd18669270: NDCG@10=0.0000, n_test_items=1366
#   Left-out user fc5720a7d99321573c359757cba2e8fd: NDCG@10=0.0000, n_test_items=31
#   Left-out user fc94354770dd3adc7871c6d060d9c645: NDCG@10=0.1545, n_test_items=2906
#   Left-out user fcf2183bbbd7a733740436ec6ee26916: NDCG@10=0.0000, n_test_items=586
#   Left-out user fd10090105a23ab614edca1a7c7ef2d9: NDCG@10=0.0000, n_test_items=576
#   Left-out user fdff7032d1d9a7ff3aa665d4903536cf: NDCG@10=0.0000, n_test_items=2230
#   Left-out user fe47f68d9eb9487681126544cc1afee7: NDCG@10=0.0000, n_test_items=1462
#   Left-out user fe661b9169b4ec9a1e0fccf3179efe93: NDCG@10=0.0000, n_test_items=236
#   Left-out user fec1a8d5daa5bf4c02b18b8b7f1f53e5: NDCG@10=0.2182, n_test_items=6240
#   Left-out user ff12d43a6f260e06737dacb3a924b46d: NDCG@10=0.0000, n_test_items=217
#   Left-out user ff1e549fd5258a410b185f595f526f4e: NDCG@10=0.0476, n_test_items=964
#   Left-out user ff424c09231fe62240539c754e347972: NDCG@10=0.0000, n_test_items=303
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1} -> Avg NDCG@10: 0.0551, RMSE: 1.5484, RMSE_norm: 0.9504533296381085

# %%
best_metrics
# Out:
# {'avg_ndcg_loo': 0.05509899424439909,
#  'k_ndcg_loo': 10,
#  'rmse_loo': 1.5483815838399166,
#  'rmse_normalized_loo': 0.9504533296381085,
#  'num_users_loo': 334}

# %%
latex_code = generate_latex_table(df_mf_tiktok_real, df_tiktok_real)
print(latex_code)
# Out:
# Density all 0.08363703113011929
# \begin{table}
# \caption{Dataset Statistics}
# \label{tab:dataset_stats}
# \begin{tabular}{lrrrrrrr}
# \toprule
# Dataset & Size & Density & 1 & 2 & 3 & 4 & 5 \\
# \midrule
# All & 598251 & 0.084 & 123911 (20.7%) & 84947 (14.2%) & 48754 (8.1%) & 41889 (7.0%) & 298750 (49.9%) \\
# Short Q0.2 (11s) & 133444 & 0.078 & 14794 (11.1%) & 15433 (11.6%) & 10171 (7.6%) & 7958 (6.0%) & 85088 (63.8%) \\
# Long Q0.2 (11s) & 464807 & 0.085 & 109117 (23.5%) & 69514 (15.0%) & 38583 (8.3%) & 33931 (7.3%) & 213662 (46.0%) \\
# Short Q0.25 (12s) & 155449 & 0.079 & 17809 (11.5%) & 18595 (12.0%) & 11862 (7.6%) & 9522 (6.1%) & 97661 (62.8%) \\
# Long Q0.25 (12s) & 442802 & 0.086 & 106102 (24.0%) & 66352 (15.0%) & 36892 (8.3%) & 32367 (7.3%) & 201089 (45.4%) \\
# Short Q0.5 (17s) & 307619 & 0.082 & 40728 (13.2%) & 43412 (14.1%) & 25441 (8.3%) & 22447 (7.3%) & 175591 (57.1%) \\
# Long Q0.5 (17s) & 290632 & 0.085 & 83183 (28.6%) & 41535 (14.3%) & 23313 (8.0%) & 19442 (6.7%) & 123159 (42.4%) \\
# Short Q0.75 (33s) & 449844 & 0.083 & 73306 (16.3%) & 63552 (14.1%) & 37719 (8.4%) & 32953 (7.3%) & 242314 (53.9%) \\
# Long Q0.75 (33s) & 148407 & 0.084 & 50605 (34.1%) & 21395 (14.4%) & 11035 (7.4%) & 8936 (6.0%) & 56436 (38.0%) \\
# Short Q0.8 (41s) & 478608 & 0.084 & 81723 (17.1%) & 67486 (14.1%) & 40081 (8.4%) & 34896 (7.3%) & 254422 (53.2%) \\
# Long Q0.8 (41s) & 119643 & 0.084 & 42188 (35.3%) & 17461 (14.6%) & 8673 (7.2%) & 6993 (5.8%) & 44328 (37.1%) \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
#✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1}
#✅ Best RMSE on TEST: 1.5466, NDCG@3: 0.8031, normalized RMSE: 1.5466

param_grid = {
    'n_components': [2, 5, 10, 20, 50, 100, 124],
    'max_iter': [1000, 2000, 3000],
    'init': ['random'],
    'model_type': ['svd'],
    'n_iter': [1, 3, 5, 10, 15]
}

results_real = []

R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_normalized, best_param = grid_search_mf_bias(df_mf_tiktok_real, param_grid, print_info=False)
print("All videos")
cm, acc, pre, rec, f1s = plot_confusion_matrix_ratings(R_test, R_estimated)
best_metrics = grid_search_mf_bias_loou_ndcg(df_mf_tiktok_real, best_param)

d = {"Data": "TikTok Real-World",
    "Quantile": 1.0, 
    "Duration": np.nan, 
    "Type": "all", 
    "Accuracy": accuracy_exp, 
    "Precision": precision_exp, 
    "Recall": recall_exp, 
    "F1 score": f1_exp,
    "ndcg": ndcg,
    "k_ndcg": k_ndcg,
    "rmse": rmse,
    "rmse_norm": rmse_normalized
}
d.update(best_metrics)
results_real.append(d)

d = {"Data": "TikTok Real-World", 
    "Accuracy": acc, 
    "Precision": pre, 
    "Recall": rec, 
    "F1 score": f1s,
    "ndcg": ndcg,
    "k_ndcg": k_ndcg,
    "rmse": rmse,
    "rmse_norm": rmse_normalized,
    "density": calculate_density(df_mf_tiktok_real)
    }
d.update(best_metrics)
results_combine.append(d)

for q in [0.2, 0.25, 0.5, 0.75, 0.8]:
    t = int(df_tiktok_real[["video_duration"]].quantile(q).iloc[0])
    print(f"Time split: {t}")
    video_ids_up_ts, video_ids_more_ts = select_short_videos(df_tiktok_real, time=t, col="video_duration")

    data_up_ts = df_mf_tiktok_real[df_mf_tiktok_real["video_id"].isin(video_ids_up_ts)]
    R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_normalized, best_param = grid_search_mf_bias(data_up_ts, param_grid, print_info=False)
    print("Short videos")
    cm, acc, pre, rec, f1s = plot_confusion_matrix_ratings(R_test, R_estimated)
    best_metrics = grid_search_mf_bias_loou_ndcg(data_up_ts, best_param)
    d = {"Data": "TikTok Real-World", "Quantile": q, "Duration": t, "Type": "short", 
        "Accuracy": acc, 
        "Precision": pre, 
        "Recall": rec, 
        "F1 score": f1s,
        "ndcg": ndcg,
        "k_ndcg": k_ndcg,
        "rmse": rmse,
        "rmse_norm": rmse_normalized
        }
    d.update(best_metrics)
    results_real.append(d)
    
    
    
    data_more_ts = df_mf_tiktok_real[df_mf_tiktok_real["video_id"].isin(video_ids_more_ts)]
    R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_normalized, best_param = grid_search_mf_bias(data_more_ts, param_grid, print_info=False)
    print("Long videos")
    cm, acc, pre, rec, f1s = plot_confusion_matrix_ratings(R_test, R_estimated)
    best_metrics = grid_search_mf_bias_loou_ndcg(data_more_ts, best_param)
    d = {"Data": "TikTok Real-World", "Quantile": q, "Duration": t, "Type": "long", 
        "Accuracy": acc, 
        "Precision": pre, 
        "Recall": rec, 
        "F1 score": f1s,
        "ndcg": ndcg,
        "k_ndcg": k_ndcg,
        "rmse": rmse,
        "rmse_norm": rmse_normalized
        }
    d.update(best_metrics)
    results_real.append(d)
# Out:
# (598251, 3) (478471, 3) (119780, 3)
# 478471 119780 119650.20000000001
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1}
# ✅ Best RMSE on TEST: 1.5466, NDCG@3: 0.8031 (len:334), normalized RMSE: 1.5466
#
# 📈 Explained Variance (for best SVD only): 0.027520242669569688
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# All videos
# Test size: 114212
# Accuracy: 0.1854
# Precision (macro): 0.3054
# Recall (macro): 0.2113
# F1 Score (macro): 0.1447
# (598251, 3)
# (598251, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1} ===
#   Left-out user 052f9630e3db689123da58fc108031d9: NDCG@10=0.0000, n_test_items=323
#   Left-out user 05ab0303fcacd5a317b2ae09139d2f90: NDCG@10=0.2091, n_test_items=3647
#   Left-out user 05e5cb7c62f3231151833fc2f9c14e26: NDCG@10=0.0000, n_test_items=251
#   Left-out user 076f72958232d0807c41c7e9f998f700: NDCG@10=0.0000, n_test_items=3043
#   Left-out user 087b10f90b88c964f3753b2e96d692af: NDCG@10=0.0000, n_test_items=35
#   Left-out user 0b21e0687828ef44ea07681a70516403: NDCG@10=0.2381, n_test_items=2400
#   Left-out user 0d3e5f43ebd0e0e1e7b6cd0dea2c834a: NDCG@10=0.0000, n_test_items=57
#   Left-out user 0d9cb0e2fc8cdcc2c14f9280e68d7675: NDCG@10=0.0000, n_test_items=198
#   Left-out user 0dbe1e9bc9b5fa04df02d7d41387200f: NDCG@10=0.0000, n_test_items=56
#   Left-out user 0e69a81894779495dc08cecca018fb58: NDCG@10=0.0000, n_test_items=888
#   Left-out user 0e95162c2b3c14828987a49621134ffd: NDCG@10=0.0000, n_test_items=707
#   Left-out user 0ea625614dacc2750aaf93ba9386f04b: NDCG@10=0.1913, n_test_items=1292
#   Left-out user 0ef1b453b67410d98c1367403349ae33: NDCG@10=0.0000, n_test_items=163
#   Left-out user 0fd17efbacf85c58a77377d252e05a6c: NDCG@10=0.0000, n_test_items=862
#   Left-out user 102150a808c31e245734412261431d32: NDCG@10=0.0000, n_test_items=518
#   Left-out user 12abb37f503259b8a48c86077c27ba03: NDCG@10=0.0476, n_test_items=2357
#   Left-out user 137804c0e789adde207f4cf0e524fc3a: NDCG@10=0.0000, n_test_items=173
#   Left-out user 13cbe3e4b325cd5b555a46f18c68fa59: NDCG@10=0.0000, n_test_items=50
#   Left-out user 15424295d7705106ef5e24ac9eea096d: NDCG@10=0.0000, n_test_items=1556
#   Left-out user 15459844d914a9c74b876b5807168b82: NDCG@10=0.0000, n_test_items=276
#   Left-out user 17a9ea69fccd32487949dee7750c3295: NDCG@10=0.0000, n_test_items=960
#   Left-out user 1964bf8f4c07ecdf673761a7e2f9d0b8: NDCG@10=0.0000, n_test_items=1259
#   Left-out user 1996515c9517c0cb01b93b7c5d765bd7: NDCG@10=0.0000, n_test_items=61
#   Left-out user 19ac140ea80427a6356e696615285c72: NDCG@10=0.0000, n_test_items=36
#   Left-out user 19c44519c804fed6d647029703d8a6fb: NDCG@10=0.0000, n_test_items=395
#   Left-out user 1bce27bbf94b95096a4066bd599313fa: NDCG@10=0.0000, n_test_items=109
#   Left-out user 1c0003f8e50eb4f4fb92fb9c0c46eaa7: NDCG@10=0.0000, n_test_items=985
#   Left-out user 1cce06370bb01af6a542cf896880600e: NDCG@10=0.0000, n_test_items=121
#   Left-out user 1e7bb1200c8b4d4a6998c9a82c35ef8f: NDCG@10=0.0000, n_test_items=23
#   Left-out user 1ef2f6ff5d6d43d79afccfdd5cb36f2f: NDCG@10=0.0000, n_test_items=487
#   Left-out user 1fe00c9118a3274f914159331ee52f52: NDCG@10=0.0000, n_test_items=462
#   Left-out user 21102041d7ba33f8002f059b5d340bc7: NDCG@10=0.1429, n_test_items=2845
#   Left-out user 2302b2facf7649c5a7fc99987c001344: NDCG@10=0.0000, n_test_items=948
#   Left-out user 23e4254f85d251e950894139fcaf49e2: NDCG@10=0.0476, n_test_items=998
#   Left-out user 255a985563ad1261d47e9208a7152e1b: NDCG@10=0.0000, n_test_items=210
#   Left-out user 25cb2512c9b12ed5d8f81daa57d5aae2: NDCG@10=0.0000, n_test_items=556
#   Left-out user 28a092120f0ed6d1b3c2d334e4af5568: NDCG@10=0.4818, n_test_items=5025
#   Left-out user 2917f6163e8e4ff90b9216b4c2809f38: NDCG@10=0.0952, n_test_items=3045
#   Left-out user 2aa21a7b3f8e5f365ab7131e15ea5594: NDCG@10=0.0960, n_test_items=4962
#   Left-out user 2b5b34dd7e218c96a725b9fa436c2c92: NDCG@10=0.0545, n_test_items=2175
#   Left-out user 2bc8b180f7cddc63c3aac9c3735dbd5f: NDCG@10=0.0000, n_test_items=1871
#   Left-out user 2d5130067f092afdb354be9ed2bc08c0: NDCG@10=0.0000, n_test_items=832
#   Left-out user 2dfa08a38607d7b2defdfeb495640d51: NDCG@10=0.0000, n_test_items=235
#   Left-out user 2e529ee770042ddca25437929e74c4f8: NDCG@10=0.0636, n_test_items=1121
#   Left-out user 2ecf17461d0902650f3b429d4bf9e635: NDCG@10=0.0000, n_test_items=530
#   Left-out user 30a9d7f9a643a5e737538e6704d9ac0a: NDCG@10=0.0000, n_test_items=512
#   Left-out user 30f492cc2f83d120cc717657264a493d: NDCG@10=0.0000, n_test_items=915
#   Left-out user 3317144fdcd77eeadeb0159766d9e101: NDCG@10=0.0000, n_test_items=138
#   Left-out user 332d80d28657ac16f3e8eb12789220e2: NDCG@10=0.0000, n_test_items=3208
#   Left-out user 336827fdc3789e6bd2010eae5ab0f9c7: NDCG@10=0.3810, n_test_items=5998
#   Left-out user 343f92c0e1899b010c7c0edf0ebe7a7d: NDCG@10=0.0000, n_test_items=479
#   Left-out user 34e6785c087dd04f7017637fdaac6935: NDCG@10=0.0818, n_test_items=4217
#   Left-out user 3547fb5186df001d444756e4ee5f2591: NDCG@10=0.1429, n_test_items=4947
#   Left-out user 37fe1f2671505d68d1b0f8840dd8647d: NDCG@10=0.0000, n_test_items=300
#   Left-out user 3823d017a87751a777883f3ecf6bcd7b: NDCG@10=0.0000, n_test_items=638
#   Left-out user 38a0265b9fe0e0b72f5704e972bc2514: NDCG@10=0.0476, n_test_items=817
#   Left-out user 3974f7feab8685e2fab51493f3f9440e: NDCG@10=0.2160, n_test_items=2740
#   Left-out user 39aa010cf288ebb8eacf338ef044c10c: NDCG@10=0.0000, n_test_items=87
#   Left-out user 3a92a13fe50df44c206dbfa28657a970: NDCG@10=0.0000, n_test_items=2627
#   Left-out user 3b1dd81b22ca85221075f2a0247e76b6: NDCG@10=0.0000, n_test_items=2274
#   Left-out user 3e45119c86cf3833ee15e1713223f189: NDCG@10=0.0476, n_test_items=2928
#   Left-out user 3e715fee944f2092a0eeb0ab8faa23d0: NDCG@10=0.0000, n_test_items=2026
#   Left-out user 3f13460fee63f7e60264cdaadc02cb28: NDCG@10=0.0000, n_test_items=525
#   Left-out user 3fd079e17ad60c9c6aad2d047935a4fa: NDCG@10=0.0000, n_test_items=73
#   Left-out user 4068ad24fede755988ada6f2afced976: NDCG@10=0.0476, n_test_items=5542
#   Left-out user 406daeec631e809cc1bdfa76de6d52d9: NDCG@10=0.1417, n_test_items=3282
#   Left-out user 40a03696dbdb0ee85336b9ca9e7a695f: NDCG@10=0.0000, n_test_items=295
#   Left-out user 40ba2c296a0ef074f0cbe157f125c77a: NDCG@10=0.0000, n_test_items=1159
#   Left-out user 41ac64f0197420ef325649f39fd6c009: NDCG@10=0.0000, n_test_items=558
#   Left-out user 4297f216570039d1b3dd115cee43c8b5: NDCG@10=0.0000, n_test_items=1740
#   Left-out user 42b55c91da8f2dfc8a3811e7560ba476: NDCG@10=0.2167, n_test_items=4727
#   Left-out user 42e4eeaf8f6aaaab2e26b3d9f7cdf6dc: NDCG@10=0.0000, n_test_items=1354
#   Left-out user 43376387e78ea356a179511fd199aa84: NDCG@10=0.1905, n_test_items=3007
#   Left-out user 44348b56c7a6629e3b06586cc5ccccde: NDCG@10=0.0696, n_test_items=2407
#   Left-out user 46c4306fb1b6e7086ed289b3f79e36d1: NDCG@10=0.1429, n_test_items=4784
#   Left-out user 4884fad8f1ef4c64e667fe35b59ae2d2: NDCG@10=0.0476, n_test_items=816
#   Left-out user 499140967d3c5a0471b82643791c385a: NDCG@10=0.0000, n_test_items=141
#   Left-out user 49afcdfeefb9d054c38692ea54f6cccc: NDCG@10=0.0476, n_test_items=746
#   Left-out user 49b7d10e7254ab76d59dfdda71585074: NDCG@10=0.0000, n_test_items=109
#   Left-out user 4a0af3921fb7aac0f78dbccde7b441fd: NDCG@10=0.0476, n_test_items=3220
#   Left-out user 4a0de4b76c69664b16fed903626b1ed5: NDCG@10=0.0182, n_test_items=1470
#   Left-out user 4b11a2f56b0d686648a07460df5c0b76: NDCG@10=0.1429, n_test_items=2119
#   Left-out user 4c189c06d7ba7bbd012b9c145e25619b: NDCG@10=0.0000, n_test_items=28
#   Left-out user 4c71c19ac7b08c18a995f0a65333f71f: NDCG@10=0.0000, n_test_items=1155
#   Left-out user 4dcf5beeb2ab6c55415663b0c5d9f95e: NDCG@10=0.0000, n_test_items=197
#   Left-out user 4de03bb326ea2d91bc18a1dff1f29e09: NDCG@10=0.0000, n_test_items=417
#   Left-out user 4e04810735ee047d9b9be48e136ab5d1: NDCG@10=0.0000, n_test_items=875
#   Left-out user 4f26e2367e813265511193120050a83a: NDCG@10=0.1000, n_test_items=5590
#   Left-out user 507bb312519d0352acb3dc92a7bcfeb2: NDCG@10=0.3185, n_test_items=3475
#   Left-out user 5103a66de51fd6c79a902e5a533fd0d3: NDCG@10=0.0000, n_test_items=24
#   Left-out user 51c768b0847e5e3110cc1ee553cab5bb: NDCG@10=0.0348, n_test_items=895
#   Left-out user 520c7ca606f866cd05f96a99a5781857: NDCG@10=0.1739, n_test_items=4782
#   Left-out user 528805dfa4495d6e8ac97f881ba54a93: NDCG@10=0.0000, n_test_items=63
#   Left-out user 548da090423d7988b4cee214a6ee7d1c: NDCG@10=0.0636, n_test_items=1821
#   Left-out user 5520bd4de4a77552c1d9094a0533bcde: NDCG@10=0.0000, n_test_items=42
#   Left-out user 570c9378801a8b7bcc508bf3888dacdd: NDCG@10=0.1545, n_test_items=3387
#   Left-out user 5715af9f68d0bc5b9874d912439468a4: NDCG@10=0.0545, n_test_items=2391
#   Left-out user 57323ce3500a7a866d69d7f104eb4890: NDCG@10=0.0000, n_test_items=556
#   Left-out user 57ae16c4ed0a5dca87925881413938d8: NDCG@10=0.1478, n_test_items=2835
#   Left-out user 57af84aa4b30181d4d9d7c2a626dc06e: NDCG@10=0.0000, n_test_items=1129
#   Left-out user 57c9cc2ac02b4894eb027323a0c50010: NDCG@10=0.0000, n_test_items=904
#   Left-out user 599ceff0a84dc8cf9178880acca5213f: NDCG@10=0.0000, n_test_items=63
#   Left-out user 5a22d0fc0842fd9194f1ea38712f66f6: NDCG@10=0.0609, n_test_items=1951
#   Left-out user 5a86cf996f5da8513530d839aefec9a5: NDCG@10=0.0000, n_test_items=698
#   Left-out user 5b0e3171111759b19d32ed6b8f71dfbc: NDCG@10=0.3478, n_test_items=3692
#   Left-out user 5bac7fedbf1056f90292483c7bdaa3f7: NDCG@10=0.0000, n_test_items=1071
#   Left-out user 5c71a22110f8799370bde7f45349ceed: NDCG@10=0.0000, n_test_items=342
#   Left-out user 5c94f3e0be7e65faf11d480a7fc76d88: NDCG@10=0.0000, n_test_items=363
#   Left-out user 5ddaf79effbe3d0b9b8a7f41e8eee944: NDCG@10=0.0000, n_test_items=168
#   Left-out user 5e4e748682843750177dedd54abc6817: NDCG@10=0.0636, n_test_items=684
#   Left-out user 5edc7fac7178f39672b9387bde6b45c3: NDCG@10=0.0000, n_test_items=55
#   Left-out user 5ef7eb7ed57c696c5ae8602ee22706b3: NDCG@10=0.4000, n_test_items=4004
#   Left-out user 60196aa0ec61d5fc79ccd2d4c02c46af: NDCG@10=0.0000, n_test_items=631
#   Left-out user 604f7333f04114b863497d0159e65e78: NDCG@10=0.0000, n_test_items=593
#   Left-out user 6061ee13eef22979c9b019bbb5526069: NDCG@10=0.2333, n_test_items=2338
#   Left-out user 607cb1a5d022cd92eae9932c3191a732: NDCG@10=0.1130, n_test_items=1414
#   Left-out user 60d2994860f1d12b76f594e3543e6e71: NDCG@10=0.0952, n_test_items=1422
#   Left-out user 629287b369ac062b5aabf335b57be814: NDCG@10=0.4286, n_test_items=3457
#   Left-out user 630c54bf5947f4518d41c758d55f3620: NDCG@10=0.0000, n_test_items=211
#   Left-out user 6338c66185bed178e2842c313e91bd16: NDCG@10=0.1905, n_test_items=2129
#   Left-out user 6400c1f18085936e736b4f9da4fcac54: NDCG@10=0.0000, n_test_items=189
#   Left-out user 67491ceff046cc7972f4502a6491e652: NDCG@10=0.4000, n_test_items=3663
#   Left-out user 67eda3f0faec6c8db4d3aaf0bfb8cd89: NDCG@10=0.1905, n_test_items=2662
#   Left-out user 691be87b9359f1a523d662b30aebaeaa: NDCG@10=0.0000, n_test_items=213
#   Left-out user 6aa5523048f6d068d395da3491e50aec: NDCG@10=0.0476, n_test_items=734
#   Left-out user 6aabc825deeac290f05b481a4c3b4b2f: NDCG@10=0.1478, n_test_items=5125
#   Left-out user 6dc440420258c0dc658eeb7087175447: NDCG@10=0.0000, n_test_items=511
#   Left-out user 6e12e1dfb66974cb5b7926c1a93370e6: NDCG@10=0.0000, n_test_items=209
#   Left-out user 6e2a5a480c1b3794db9ef93704bf7911: NDCG@10=0.0000, n_test_items=69
#   Left-out user 6f030cca3695043fbd1ab28a80fa1642: NDCG@10=0.0000, n_test_items=72
#   Left-out user 6f3ee61714f01a03a1f336016a971c98: NDCG@10=0.0000, n_test_items=588
#   Left-out user 6ffdc203c4100200dc86e79a4627a4a2: NDCG@10=0.0000, n_test_items=220
#   Left-out user 7091415866d5d0b9cb0f9be9cca3dbe9: NDCG@10=0.0000, n_test_items=298
#   Left-out user 736f55466e60cc5b89efff729c6aead1: NDCG@10=0.0000, n_test_items=81
#   Left-out user 75beba3a959306b160d8e550de5d0828: NDCG@10=0.0952, n_test_items=4950
#   Left-out user 75d0a99bbe07bd245b3e0bf14dde4a7a: NDCG@10=0.0000, n_test_items=136
#   Left-out user 75f74ef71a30ea288a1080cfc003270b: NDCG@10=0.0476, n_test_items=2280
#   Left-out user 760876a30551767cb8dbfd9540033fc0: NDCG@10=0.0476, n_test_items=1071
#   Left-out user 76b19aa2995ca4b75d0a00ea8697a952: NDCG@10=0.0000, n_test_items=180
#   Left-out user 78bd94ee2fb6e1d7689192c52d0ce784: NDCG@10=0.0000, n_test_items=295
#   Left-out user 7937913e1b3414ed466bd7468c537681: NDCG@10=0.0476, n_test_items=1705
#   Left-out user 7997e04a523b022071b7946830bfec9a: NDCG@10=0.0476, n_test_items=695
#   Left-out user 7bebee95d3a8f58bd668f9b3a9a37ac9: NDCG@10=0.0000, n_test_items=930
#   Left-out user 7cd41b5e73b3a86f2301b66d207c9db6: NDCG@10=0.0000, n_test_items=576
#   Left-out user 7d25c880b7427084b5a0001abd6cef21: NDCG@10=0.1000, n_test_items=2750
#   Left-out user 7d3b625c9e1756e7eccadb5e7507d785: NDCG@10=0.0000, n_test_items=200
#   Left-out user 7e5d5c610d39a23bf469a4cf86a68159: NDCG@10=0.0000, n_test_items=65
#   Left-out user 7e7f3042796772b9720f875648e1e390: NDCG@10=0.0476, n_test_items=622
#   Left-out user 7ed4dec827db3ef02d0c3260704f72b2: NDCG@10=0.1545, n_test_items=2526
#   Left-out user 7eef5f8cf623fa53cd76144928bbd075: NDCG@10=0.0000, n_test_items=458
#   Left-out user 7f4248d5d43dce6c96972008b627a58f: NDCG@10=0.0000, n_test_items=74
#   Left-out user 7f7d5323d00cda473c6cccf3cd1dd350: NDCG@10=0.0348, n_test_items=4721
#   Left-out user 8029fea2643a45f6c3346aae9ab56596: NDCG@10=0.0000, n_test_items=473
#   Left-out user 806fc581a43ba60b0f46c4e4717692e6: NDCG@10=0.0000, n_test_items=16
#   Left-out user 80abd77077bdc11308178d830d50966b: NDCG@10=0.0000, n_test_items=1444
#   Left-out user 8272c4f28e6b137c4b3139118e5a493f: NDCG@10=0.0783, n_test_items=2686
#   Left-out user 82fa387d8dffd9832ee488542a068d15: NDCG@10=0.0000, n_test_items=638
#   Left-out user 8322389ae010fbd858d7fd1981159292: NDCG@10=0.0000, n_test_items=3282
#   Left-out user 841831a1f2fb0209030ac0426cb430c8: NDCG@10=0.0000, n_test_items=1080
#   Left-out user 8471a959fed8614e8dd5a62c97530fe8: NDCG@10=0.0000, n_test_items=132
#   Left-out user 84e4d48000f53b053bb6e713fd9f0ff6: NDCG@10=0.0000, n_test_items=94
#   Left-out user 8579f5442d69fef62c14ef0089b53120: NDCG@10=0.0000, n_test_items=124
#   Left-out user 85991072f65697d7ae7cc35ff4ff6421: NDCG@10=0.0000, n_test_items=1006
#   Left-out user 85cfa0f9e44950c26f5b5d65cb2f3d2e: NDCG@10=0.1429, n_test_items=3734
#   Left-out user 85f3fa94f6d5cfc6d2b3ea0f944ccb7b: NDCG@10=0.0000, n_test_items=229
#   Left-out user 863c4b751397e49e5d335f84a99e041f: NDCG@10=0.0000, n_test_items=1085
#   Left-out user 88f430db28e75019041a51776cd759f9: NDCG@10=0.0000, n_test_items=132
#   Left-out user 8a614460361b54fc395b8bd133f3d53a: NDCG@10=0.3750, n_test_items=3605
#   Left-out user 8afff0bd59b3e9e2915c56d848503189: NDCG@10=0.0000, n_test_items=2750
#   Left-out user 8b5874fb0a1f2aac47ca477a2f8810f5: NDCG@10=0.0000, n_test_items=471
#   Left-out user 8c8b78d09aabfeb56e0cff6bdadf9932: NDCG@10=0.0000, n_test_items=1758
#   Left-out user 8d125ec3ed4e911cc40fc2c7feca4665: NDCG@10=0.0000, n_test_items=116
#   Left-out user 8d3fb00a64dd788221f3aecbfbfee218: NDCG@10=0.0000, n_test_items=998
#   Left-out user 8e8570de6673c5c33386a25fcc76c249: NDCG@10=0.1905, n_test_items=6197
#   Left-out user 8f73da1e8ae660c7513641d9d59e8f6b: NDCG@10=0.0000, n_test_items=1512
#   Left-out user 90d64ce67a462da5e3e72e9a6ed6cf72: NDCG@10=0.0000, n_test_items=211
#   Left-out user 918e2de571fe5d21a5cb03df0972106d: NDCG@10=0.5391, n_test_items=4158
#   Left-out user 92120756a22d7133085b14eec1bbd96b: NDCG@10=0.1182, n_test_items=3097
#   Left-out user 9275cf3a9831f938667626eeec7b7c74: NDCG@10=0.4640, n_test_items=5267
#   Left-out user 92ec19edd2ed135056691b13cb35ff63: NDCG@10=0.1905, n_test_items=2771
#   Left-out user 935adc97adb465b94b07a241069425cc: NDCG@10=0.0917, n_test_items=1208
#   Left-out user 936afe4c6c620965afea35c37b44f833: NDCG@10=0.0273, n_test_items=1807
#   Left-out user 9466223293e5ddf532ce93b87dd04fad: NDCG@10=0.0000, n_test_items=70
#   Left-out user 94bd6242868ab1d3f43f085ad757ff7b: NDCG@10=0.0000, n_test_items=2003
#   Left-out user 95dfc7e4ac06738557fad16ee021644b: NDCG@10=0.0000, n_test_items=810
#   Left-out user 95fea58479822e5942a339b817d92b6b: NDCG@10=0.0000, n_test_items=524
#   Left-out user 9610f77463aa1dc2bda5f923337a21d7: NDCG@10=0.0000, n_test_items=223
#   Left-out user 98e5244f8bb68b5740850ab24573c017: NDCG@10=0.0000, n_test_items=65
#   Left-out user 9913d7d4c4014e75f4d71c1fb709f7b9: NDCG@10=0.0000, n_test_items=460
#   Left-out user 99959ca3dfe40d82568db050596948b4: NDCG@10=0.0000, n_test_items=606
#   Left-out user 99cd9e6aeccdec9e6bf744e292171c18: NDCG@10=0.0000, n_test_items=145
#   Left-out user 99d56dfa2bf934a4a48435271c9015a3: NDCG@10=0.0000, n_test_items=417
#   Left-out user 9a31ea87f222c2ed002d81cf237fcc9d: NDCG@10=0.0000, n_test_items=2299
#   Left-out user 9a3390e99fa2f377e6a91a586f89af0e: NDCG@10=0.0000, n_test_items=669
#   Left-out user 9b763981424074df93c6b9aa101c4485: NDCG@10=0.0000, n_test_items=910
#   Left-out user 9bc296bebd5a88045279fac4abde279e: NDCG@10=0.2783, n_test_items=1581
#   Left-out user 9d30bf7bc95f0ce348ff947cbf5b1dca: NDCG@10=0.0000, n_test_items=460
#   Left-out user 9e29c60e447028e52d9b52c3059ecbe7: NDCG@10=0.0952, n_test_items=1226
#   Left-out user 9ea7daabbdc3c56d9e54235bddb889d7: NDCG@10=0.0000, n_test_items=520
#   Left-out user 9fb20ba713b179f24495f6d969bf42fd: NDCG@10=0.0000, n_test_items=368
#   Left-out user 9fcef0961596a361e45178cbe7664b76: NDCG@10=0.0476, n_test_items=354
#   Left-out user 9fe384d5aae32897fb237f0bc1fa735f: NDCG@10=0.0476, n_test_items=1345
#   Left-out user 9fe9468f2714c2f43acff287fd785985: NDCG@10=0.0000, n_test_items=240
#   Left-out user a0283278a2762f9f893c172ce2ae28ae: NDCG@10=0.1429, n_test_items=1380
#   Left-out user a21805b93948e07b3ca19399aaa26a1b: NDCG@10=0.0000, n_test_items=113
#   Left-out user a25995ac5c430a097fe42c5b80cbca93: NDCG@10=0.0000, n_test_items=52
#   Left-out user a2dc9281b961eef6e29d66335a20b7bf: NDCG@10=0.0000, n_test_items=564
#   Left-out user a3c9df5b15b0a6b1926a929f745f6355: NDCG@10=0.4087, n_test_items=2714
#   Left-out user a60f9da2acfcd81a1722df5938f1e1a7: NDCG@10=0.2381, n_test_items=3794
#   Left-out user a670f905b78ce21ec5ae78fb1e514d88: NDCG@10=0.0000, n_test_items=523
#   Left-out user a6c0cda9061b82a0951cc1de293af62e: NDCG@10=0.0000, n_test_items=1413
#   Left-out user aa4a6fa20ef0be3b9e8f8ceb3f075858: NDCG@10=0.4667, n_test_items=3299
#   Left-out user aa4c1abbf29d76cf70f7740bfc85a35f: NDCG@10=0.1304, n_test_items=7208
#   Left-out user aa98334a880507fb150021be7b2a37e0: NDCG@10=0.0476, n_test_items=526
#   Left-out user aace0606f25529cb645f28c6c0586577: NDCG@10=0.0000, n_test_items=527
#   Left-out user add03e608bef35f1c5bc13d990b9f317: NDCG@10=0.0000, n_test_items=136
#   Left-out user add247ff11a1cdd16f3117878d70b7f2: NDCG@10=0.0000, n_test_items=6460
#   Left-out user aeb4a7d549713081c22fac75981733fb: NDCG@10=0.1545, n_test_items=2832
#   Left-out user af225c460d5c2574c30c1233e040437c: NDCG@10=0.0091, n_test_items=1746
#   Left-out user b0a136d836a3dc742bd514ac3c6f4b92: NDCG@10=0.2783, n_test_items=6935
#   Left-out user b12e08675d640e90df6dfa3923574286: NDCG@10=0.0000, n_test_items=1374
#   Left-out user b30192f8313c378cc0a158f0563ae1d9: NDCG@10=0.0000, n_test_items=1193
#   Left-out user b3740aaa07240ffa5201a93b09899e77: NDCG@10=0.0476, n_test_items=833
#   Left-out user b4e1d8d3fe1381c841c9c8a87ca6753f: NDCG@10=0.0000, n_test_items=497
#   Left-out user b7053409ecb49ac940b9c43f1cd43de8: NDCG@10=0.0000, n_test_items=908
#   Left-out user b719e3f0e9502a6955333f344a864d0c: NDCG@10=0.0000, n_test_items=2789
#   Left-out user b78c646642bdefa4358dbe41c7fd8519: NDCG@10=0.1429, n_test_items=1804
#   Left-out user b81c3bab6d9c61ba9833434717095b6c: NDCG@10=0.0000, n_test_items=437
#   Left-out user b91d595b94b0dbf77368c65d799a51fc: NDCG@10=0.0000, n_test_items=335
#   Left-out user ba17211868c4341e8beb1e05d15ee35a: NDCG@10=0.0000, n_test_items=5552
#   Left-out user ba1c26c63f66b311541d7f7d4f330a99: NDCG@10=0.0000, n_test_items=458
#   Left-out user ba2d5114cfba51db92fb1076f543998c: NDCG@10=0.0000, n_test_items=1250
#   Left-out user ba3aead3e7d97af7c8447f68db6926d0: NDCG@10=0.0000, n_test_items=28
#   Left-out user bb953b3f720c17ef70b54b1433edf042: NDCG@10=0.1000, n_test_items=2452
#   Left-out user bc4b888d497b89951ecccb7bbf6116d4: NDCG@10=0.0636, n_test_items=1891
#   Left-out user bc7584dd10c17c7ab7b13e6ac9523a4d: NDCG@10=0.0000, n_test_items=51
#   Left-out user bc7dbd351ed5e2bc359ac6a36247590d: NDCG@10=0.0000, n_test_items=1443
#   Left-out user bdb3c7577a14fd1cd125290c197504fb: NDCG@10=0.1429, n_test_items=4115
#   Left-out user bdf87a5f07383649d749765e8db6f3a7: NDCG@10=0.0476, n_test_items=769
#   Left-out user be95d2d16b9220ea3906643d54b59a90: NDCG@10=0.0000, n_test_items=193
#   Left-out user c055083da103f98b8c75d24e933a73d5: NDCG@10=0.0000, n_test_items=319
#   Left-out user c11b38b53d8d318d4321d31922de1852: NDCG@10=0.0000, n_test_items=37
#   Left-out user c2f4f8d9c3d4836c783fb25db228bdcc: NDCG@10=0.0000, n_test_items=333
#   Left-out user c3fed64b100f211f4fa106b65dfde8d2: NDCG@10=0.0476, n_test_items=1452
#   Left-out user c4360c1edb8b4195581ae0f0ca366449: NDCG@10=0.0364, n_test_items=1722
#   Left-out user c4b5ed8e35f0a55a4bfbdcbbcacfe131: NDCG@10=0.0182, n_test_items=3685
#   Left-out user c4cbbbf32176fcc196795d56eb21d0e5: NDCG@10=0.0000, n_test_items=252
#   Left-out user c55eb3a5c4871e90cf83519d30b8f9c9: NDCG@10=0.0476, n_test_items=789
#   Left-out user c625e60059faad10f733ab395917506b: NDCG@10=0.0476, n_test_items=2393
#   Left-out user c78859a8b046c9e6ee28094abe874e83: NDCG@10=0.0182, n_test_items=2358
#   Left-out user c87b7cc0f0baae94203da80370f4990b: NDCG@10=0.0476, n_test_items=451
#   Left-out user c8de92d9ad2a1b6e90b8ab7eedb6ebeb: NDCG@10=0.0000, n_test_items=1433
#   Left-out user c9a7b8be73ebd53a4fe482cb1ff05e52: NDCG@10=0.1429, n_test_items=2906
#   Left-out user caf6b231df17d862a8afb50fedd7497d: NDCG@10=0.0182, n_test_items=973
#   Left-out user cb4d02891b7388a483d4d62f08b0b898: NDCG@10=0.0476, n_test_items=534
#   Left-out user cb6370414c535a767a05f4fb8584e4e0: NDCG@10=0.1909, n_test_items=5252
#   Left-out user ccbdf84a9f25aba01e8eed1b6e402cfc: NDCG@10=0.1182, n_test_items=1964
#   Left-out user cde5c36cf21a04c93c5d638a47d93a14: NDCG@10=0.0000, n_test_items=83
#   Left-out user cdeb1f2e7d41de1a12dd891dd0da9b7a: NDCG@10=0.0000, n_test_items=97
#   Left-out user ce619e04a6c578502eb47d2e8fa0734d: NDCG@10=0.0000, n_test_items=909
#   Left-out user ceb9a212ab4d8fb0be9828beb020a848: NDCG@10=0.1391, n_test_items=5004
#   Left-out user cf780f4ddcb8c00c6ac23afb37d52dae: NDCG@10=0.0000, n_test_items=29
#   Left-out user cfa4293588943a18e329ec9450fe4f58: NDCG@10=0.0182, n_test_items=321
#   Left-out user d0b81b79c5da3ee544a0b549ab11bf36: NDCG@10=0.2091, n_test_items=5001
#   Left-out user d117b1fa4816274bad3b124f9bc9b836: NDCG@10=0.0476, n_test_items=463
#   Left-out user d13d54bc573490213cee7196c2d99198: NDCG@10=0.0000, n_test_items=1351
#   Left-out user d17757f195bed106b840b05c31620d90: NDCG@10=0.0000, n_test_items=306
#   Left-out user d3da2778eaf14237dde32b08093ba865: NDCG@10=0.0476, n_test_items=663
#   Left-out user d4cdb2e4a1175556acdd10284391ce30: NDCG@10=0.1091, n_test_items=1747
#   Left-out user d6b6d8a6c6346626c8d673519ae16c5d: NDCG@10=0.1000, n_test_items=6812
#   Left-out user d91f62b3addd8857dfd7f15f5dc19144: NDCG@10=0.4583, n_test_items=3590
#   Left-out user d94f12386537c7bb53c64c7f95c72dae: NDCG@10=0.0273, n_test_items=769
#   Left-out user da1aa3e04bbce323b1bdf31e1c2e11de: NDCG@10=0.0000, n_test_items=23
#   Left-out user db22c3330010b7395e482bfd30499d5d: NDCG@10=0.0091, n_test_items=448
#   Left-out user db528c1228870a562aabb4e85f81636d: NDCG@10=0.4741, n_test_items=8531
#   Left-out user db7b75dd3496d2f16b3dc8c789128389: NDCG@10=0.0476, n_test_items=4245
#   Left-out user dc503db1918adfdb82e50018075e4e86: NDCG@10=0.0000, n_test_items=544
#   Left-out user dca8dee49b5b5498e153a81baa6ffb83: NDCG@10=0.0182, n_test_items=2544
#   Left-out user dcb9bd758192391033375e09b35c4f86: NDCG@10=0.1429, n_test_items=939
#   Left-out user e1b8d11473458133ac34f21f84e68cc2: NDCG@10=0.0000, n_test_items=396
#   Left-out user e327f9b0d0253e05a2eb27da88a5978e: NDCG@10=0.1905, n_test_items=1038
#   Left-out user e4973ba7fb519cb1ae2712fe22336fc5: NDCG@10=0.0000, n_test_items=101
#   Left-out user e498ee8ef660429ee298d3b03851f633: NDCG@10=0.0091, n_test_items=288
#   Left-out user e4e65ae9328f589369fe193b4615fb47: NDCG@10=0.1429, n_test_items=2705
#   Left-out user e5274c8192b0f0baed7503da938ec7c6: NDCG@10=0.0273, n_test_items=2743
#   Left-out user e53917e067246f32375050cf300cb4b1: NDCG@10=0.2545, n_test_items=1756
#   Left-out user e5638817a49654844029877d07dde483: NDCG@10=0.3920, n_test_items=2688
#   Left-out user e583814caefc5c78f3fd2dc01571e862: NDCG@10=0.0000, n_test_items=3372
#   Left-out user e607194702fd4205848d2c3b5b164a51: NDCG@10=0.0000, n_test_items=495
#   Left-out user e628020db39ca283d83a6e5a5beb6289: NDCG@10=0.0000, n_test_items=279
#   Left-out user e63b5aaaf83943bfdc003af680d991f6: NDCG@10=0.0182, n_test_items=2091
#   Left-out user e6633a23f7ba8b1c231fbb5a7afd210b: NDCG@10=0.0000, n_test_items=3391
#   Left-out user e7aea83bd3881673b3997a3aae04246f: NDCG@10=0.0000, n_test_items=1283
#   Left-out user e95a3f90318b20cb34eb53b1661c6410: NDCG@10=0.2364, n_test_items=4174
#   Left-out user ea1f218dadb90c02a55e44fc1702c661: NDCG@10=0.0000, n_test_items=166
#   Left-out user eacaf8e8255da6a24858fcf0fd74119a: NDCG@10=0.0091, n_test_items=3455
#   Left-out user eb61cbb4b4d06c55abff1275d948c5c1: NDCG@10=0.0000, n_test_items=733
#   Left-out user eb8e38b302bcfbbfdf733053ea35ec0d: NDCG@10=0.0000, n_test_items=373
#   Left-out user eba9fa22681fa1464dbed7172d293429: NDCG@10=0.0000, n_test_items=179
#   Left-out user eefa81fd4a1e5ec72714527b20d5d064: NDCG@10=0.0000, n_test_items=973
#   Left-out user f00b1cc4098002bc33257ff3b6ad76a8: NDCG@10=0.0000, n_test_items=408
#   Left-out user f058da4cda7a047f1172c5f88a0a12de: NDCG@10=0.0000, n_test_items=70
#   Left-out user f0d8193888d5082bea4a9297a8fa1bc5: NDCG@10=0.3364, n_test_items=3848
#   Left-out user f13a2d26493632933a42f18040c1dafa: NDCG@10=0.0000, n_test_items=150
#   Left-out user f279dc20a57ca6e9c1e51fcebfd181d6: NDCG@10=0.0000, n_test_items=57
#   Left-out user f2cb35d7fde9d956b3de5dfa28d675af: NDCG@10=0.0952, n_test_items=1399
#   Left-out user f2df90328d03f94db7a421267dade931: NDCG@10=0.0000, n_test_items=113
#   Left-out user f353436d61cbda22cc7b7d4a8d2a734a: NDCG@10=0.0000, n_test_items=696
#   Left-out user f4625def3cd5f9b14b72af3d468a318c: NDCG@10=0.0000, n_test_items=1032
#   Left-out user f467382e1b52562ae15e151e0605c712: NDCG@10=0.0000, n_test_items=2438
#   Left-out user f49ecad2937f54ea688a95df503ff6a4: NDCG@10=0.0952, n_test_items=2442
#   Left-out user f4b983df51c8f36d9f277bf25e345a2e: NDCG@10=0.1520, n_test_items=3115
#   Left-out user f4e6d3e9954c8622e70a706e123d54f6: NDCG@10=0.0476, n_test_items=1003
#   Left-out user f6cefebbf6af74b3cb5564d274c73974: NDCG@10=0.0000, n_test_items=56
#   Left-out user f897d285b5939bce6b195002a7ccf7b1: NDCG@10=0.0000, n_test_items=206
#   Left-out user f8bde75134fadc750d7a6daeca685bdf: NDCG@10=0.0000, n_test_items=39
#   Left-out user f90fe34419be55e9007c820eb5772524: NDCG@10=0.0000, n_test_items=135
#   Left-out user f94fc655cf65e0187f96a833252ea923: NDCG@10=0.0000, n_test_items=446
#   Left-out user f9789c1bb9a0f71d11ee13fa2f31fbfc: NDCG@10=0.0952, n_test_items=2627
#   Left-out user f9f219a8ea089721d5fdfc91978d01d2: NDCG@10=0.0583, n_test_items=6206
#   Left-out user fa44ebc9638368e9f2e23e122e26ee9a: NDCG@10=0.0000, n_test_items=2619
#   Left-out user fac9b25bfb788251893522845b400bf1: NDCG@10=0.0000, n_test_items=358
#   Left-out user fbbfbcc25919d85047836acd18669270: NDCG@10=0.0000, n_test_items=1366
#   Left-out user fc5720a7d99321573c359757cba2e8fd: NDCG@10=0.0000, n_test_items=31
#   Left-out user fc94354770dd3adc7871c6d060d9c645: NDCG@10=0.1545, n_test_items=2906
#   Left-out user fcf2183bbbd7a733740436ec6ee26916: NDCG@10=0.0000, n_test_items=586
#   Left-out user fd10090105a23ab614edca1a7c7ef2d9: NDCG@10=0.0000, n_test_items=576
#   Left-out user fdff7032d1d9a7ff3aa665d4903536cf: NDCG@10=0.0000, n_test_items=2230
#   Left-out user fe47f68d9eb9487681126544cc1afee7: NDCG@10=0.0000, n_test_items=1462
#   Left-out user fe661b9169b4ec9a1e0fccf3179efe93: NDCG@10=0.0000, n_test_items=236
#   Left-out user fec1a8d5daa5bf4c02b18b8b7f1f53e5: NDCG@10=0.2182, n_test_items=6240
#   Left-out user ff12d43a6f260e06737dacb3a924b46d: NDCG@10=0.0000, n_test_items=217
#   Left-out user ff1e549fd5258a410b185f595f526f4e: NDCG@10=0.0476, n_test_items=964
#   Left-out user ff424c09231fe62240539c754e347972: NDCG@10=0.0000, n_test_items=303
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1} -> Avg NDCG@10: 0.0551, RMSE: 1.5484, RMSE_norm: 0.9504533296381085
# Users: 334, Videos: 21416
# Observed interactions: 598251
# Density: 0.0836
# Sparsity: 0.9164
# Time split: 11
# (133443, 3) (106622, 3) (26821, 3)
# 106622 26821 26688.600000000002
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1}
# ✅ Best RMSE on TEST: 1.4064, NDCG@3: 0.8328 (len:304), normalized RMSE: 1.4064
#
# 📈 Explained Variance (for best SVD only): 0.03543763517754376
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Short videos
# Test size: 25730
# Accuracy: 0.2670
# Precision (macro): 0.3009
# Recall (macro): 0.2013
# F1 Score (macro): 0.1466
# (133444, 3)
# (133443, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1} ===
#   Left-out user 052f9630e3db689123da58fc108031d9: NDCG@10=0.0000, n_test_items=51
#   Left-out user 05ab0303fcacd5a317b2ae09139d2f90: NDCG@10=0.1625, n_test_items=622
#   Left-out user 05e5cb7c62f3231151833fc2f9c14e26: NDCG@10=0.0000, n_test_items=25
#   Left-out user 076f72958232d0807c41c7e9f998f700: NDCG@10=0.0000, n_test_items=620
#   Left-out user 087b10f90b88c964f3753b2e96d692af: NDCG@10=0.0000, n_test_items=8
#   Left-out user 0b21e0687828ef44ea07681a70516403: NDCG@10=0.2667, n_test_items=532
#   Left-out user 0d3e5f43ebd0e0e1e7b6cd0dea2c834a: NDCG@10=0.0000, n_test_items=7
#   Left-out user 0d9cb0e2fc8cdcc2c14f9280e68d7675: NDCG@10=0.0000, n_test_items=72
#   Left-out user 0dbe1e9bc9b5fa04df02d7d41387200f: NDCG@10=0.0000, n_test_items=8
#   Left-out user 0e69a81894779495dc08cecca018fb58: NDCG@10=0.0000, n_test_items=146
#   Left-out user 0e95162c2b3c14828987a49621134ffd: NDCG@10=0.0000, n_test_items=132
#   Left-out user 0ea625614dacc2750aaf93ba9386f04b: NDCG@10=0.1625, n_test_items=274
#   Left-out user 0ef1b453b67410d98c1367403349ae33: NDCG@10=0.0000, n_test_items=27
#   Left-out user 0fd17efbacf85c58a77377d252e05a6c: NDCG@10=0.0000, n_test_items=76
#   Left-out user 102150a808c31e245734412261431d32: NDCG@10=0.0000, n_test_items=67
#   Left-out user 12abb37f503259b8a48c86077c27ba03: NDCG@10=0.0000, n_test_items=420
#   Left-out user 137804c0e789adde207f4cf0e524fc3a: NDCG@10=0.0000, n_test_items=24
#   Left-out user 13cbe3e4b325cd5b555a46f18c68fa59: NDCG@10=0.0000, n_test_items=8
#   Left-out user 15424295d7705106ef5e24ac9eea096d: NDCG@10=0.0000, n_test_items=266
#   Left-out user 15459844d914a9c74b876b5807168b82: NDCG@10=0.0000, n_test_items=43
#   Left-out user 17a9ea69fccd32487949dee7750c3295: NDCG@10=0.0000, n_test_items=160
#   Left-out user 1964bf8f4c07ecdf673761a7e2f9d0b8: NDCG@10=0.0000, n_test_items=223
#   Left-out user 1996515c9517c0cb01b93b7c5d765bd7: NDCG@10=0.0000, n_test_items=8
#   Left-out user 19ac140ea80427a6356e696615285c72: NDCG@10=0.0000, n_test_items=3
#   Left-out user 19c44519c804fed6d647029703d8a6fb: NDCG@10=0.0000, n_test_items=58
#   Left-out user 1bce27bbf94b95096a4066bd599313fa: NDCG@10=0.0000, n_test_items=22
#   Left-out user 1c0003f8e50eb4f4fb92fb9c0c46eaa7: NDCG@10=0.0000, n_test_items=263
#   Left-out user 1cce06370bb01af6a542cf896880600e: NDCG@10=0.0000, n_test_items=22
#   Left-out user 1ef2f6ff5d6d43d79afccfdd5cb36f2f: NDCG@10=0.0000, n_test_items=92
#   Left-out user 1fe00c9118a3274f914159331ee52f52: NDCG@10=0.0000, n_test_items=81
#   Left-out user 21102041d7ba33f8002f059b5d340bc7: NDCG@10=0.2000, n_test_items=683
#   Left-out user 2302b2facf7649c5a7fc99987c001344: NDCG@10=0.0000, n_test_items=169
#   Left-out user 23e4254f85d251e950894139fcaf49e2: NDCG@10=0.0667, n_test_items=138
#   Left-out user 255a985563ad1261d47e9208a7152e1b: NDCG@10=0.0000, n_test_items=54
#   Left-out user 25cb2512c9b12ed5d8f81daa57d5aae2: NDCG@10=0.0000, n_test_items=91
#   Left-out user 28a092120f0ed6d1b3c2d334e4af5568: NDCG@10=0.5333, n_test_items=1552
#   Left-out user 2917f6163e8e4ff90b9216b4c2809f38: NDCG@10=0.0667, n_test_items=579
#   Left-out user 2aa21a7b3f8e5f365ab7131e15ea5594: NDCG@10=0.1263, n_test_items=1284
#   Left-out user 2b5b34dd7e218c96a725b9fa436c2c92: NDCG@10=0.0125, n_test_items=397
#   Left-out user 2bc8b180f7cddc63c3aac9c3735dbd5f: NDCG@10=0.0000, n_test_items=352
#   Left-out user 2d5130067f092afdb354be9ed2bc08c0: NDCG@10=0.0000, n_test_items=160
#   Left-out user 2dfa08a38607d7b2defdfeb495640d51: NDCG@10=0.0000, n_test_items=50
#   Left-out user 2e529ee770042ddca25437929e74c4f8: NDCG@10=0.0875, n_test_items=375
#   Left-out user 2ecf17461d0902650f3b429d4bf9e635: NDCG@10=0.0000, n_test_items=166
#   Left-out user 30a9d7f9a643a5e737538e6704d9ac0a: NDCG@10=0.0000, n_test_items=76
#   Left-out user 30f492cc2f83d120cc717657264a493d: NDCG@10=0.0000, n_test_items=204
#   Left-out user 3317144fdcd77eeadeb0159766d9e101: NDCG@10=0.0000, n_test_items=35
#   Left-out user 332d80d28657ac16f3e8eb12789220e2: NDCG@10=0.0000, n_test_items=804
#   Left-out user 336827fdc3789e6bd2010eae5ab0f9c7: NDCG@10=0.3333, n_test_items=1663
#   Left-out user 343f92c0e1899b010c7c0edf0ebe7a7d: NDCG@10=0.0000, n_test_items=38
#   Left-out user 34e6785c087dd04f7017637fdaac6935: NDCG@10=0.1125, n_test_items=908
#   Left-out user 3547fb5186df001d444756e4ee5f2591: NDCG@10=0.0667, n_test_items=895
#   Left-out user 37fe1f2671505d68d1b0f8840dd8647d: NDCG@10=0.0000, n_test_items=88
#   Left-out user 3823d017a87751a777883f3ecf6bcd7b: NDCG@10=0.0000, n_test_items=102
#   Left-out user 38a0265b9fe0e0b72f5704e972bc2514: NDCG@10=0.0667, n_test_items=240
#   Left-out user 3974f7feab8685e2fab51493f3f9440e: NDCG@10=0.2889, n_test_items=1043
#   Left-out user 39aa010cf288ebb8eacf338ef044c10c: NDCG@10=0.0000, n_test_items=12
#   Left-out user 3a92a13fe50df44c206dbfa28657a970: NDCG@10=0.0000, n_test_items=435
#   Left-out user 3b1dd81b22ca85221075f2a0247e76b6: NDCG@10=0.0000, n_test_items=412
#   Left-out user 3e45119c86cf3833ee15e1713223f189: NDCG@10=0.0000, n_test_items=697
#   Left-out user 3e715fee944f2092a0eeb0ab8faa23d0: NDCG@10=0.0000, n_test_items=402
#   Left-out user 3f13460fee63f7e60264cdaadc02cb28: NDCG@10=0.0000, n_test_items=110
#   Left-out user 3fd079e17ad60c9c6aad2d047935a4fa: NDCG@10=0.0000, n_test_items=14
#   Left-out user 4068ad24fede755988ada6f2afced976: NDCG@10=0.0667, n_test_items=1235
#   Left-out user 406daeec631e809cc1bdfa76de6d52d9: NDCG@10=0.1125, n_test_items=846
#   Left-out user 40a03696dbdb0ee85336b9ca9e7a695f: NDCG@10=0.0000, n_test_items=60
#   Left-out user 40ba2c296a0ef074f0cbe157f125c77a: NDCG@10=0.0000, n_test_items=254
#   Left-out user 41ac64f0197420ef325649f39fd6c009: NDCG@10=0.0000, n_test_items=63
#   Left-out user 4297f216570039d1b3dd115cee43c8b5: NDCG@10=0.0000, n_test_items=163
#   Left-out user 42b55c91da8f2dfc8a3811e7560ba476: NDCG@10=0.1778, n_test_items=1081
#   Left-out user 42e4eeaf8f6aaaab2e26b3d9f7cdf6dc: NDCG@10=0.0000, n_test_items=202
#   Left-out user 43376387e78ea356a179511fd199aa84: NDCG@10=0.1333, n_test_items=827
#   Left-out user 44348b56c7a6629e3b06586cc5ccccde: NDCG@10=0.0353, n_test_items=654
#   Left-out user 46c4306fb1b6e7086ed289b3f79e36d1: NDCG@10=0.1333, n_test_items=912
#   Left-out user 4884fad8f1ef4c64e667fe35b59ae2d2: NDCG@10=0.0000, n_test_items=292
#   Left-out user 499140967d3c5a0471b82643791c385a: NDCG@10=0.0000, n_test_items=19
#   Left-out user 49afcdfeefb9d054c38692ea54f6cccc: NDCG@10=0.0667, n_test_items=111
#   Left-out user 49b7d10e7254ab76d59dfdda71585074: NDCG@10=0.0000, n_test_items=13
#   Left-out user 4a0af3921fb7aac0f78dbccde7b441fd: NDCG@10=0.0000, n_test_items=695
#   Left-out user 4a0de4b76c69664b16fed903626b1ed5: NDCG@10=0.0250, n_test_items=325
#   Left-out user 4b11a2f56b0d686648a07460df5c0b76: NDCG@10=0.0000, n_test_items=468
#   Left-out user 4c189c06d7ba7bbd012b9c145e25619b: NDCG@10=0.0000, n_test_items=4
#   Left-out user 4c71c19ac7b08c18a995f0a65333f71f: NDCG@10=0.0000, n_test_items=322
#   Left-out user 4dcf5beeb2ab6c55415663b0c5d9f95e: NDCG@10=0.0000, n_test_items=30
#   Left-out user 4de03bb326ea2d91bc18a1dff1f29e09: NDCG@10=0.0000, n_test_items=49
#   Left-out user 4e04810735ee047d9b9be48e136ab5d1: NDCG@10=0.0000, n_test_items=184
#   Left-out user 4f26e2367e813265511193120050a83a: NDCG@10=0.0125, n_test_items=985
#   Left-out user 507bb312519d0352acb3dc92a7bcfeb2: NDCG@10=0.3100, n_test_items=1090
#   Left-out user 5103a66de51fd6c79a902e5a533fd0d3: NDCG@10=0.0000, n_test_items=2
#   Left-out user 51c768b0847e5e3110cc1ee553cab5bb: NDCG@10=0.0375, n_test_items=250
#   Left-out user 520c7ca606f866cd05f96a99a5781857: NDCG@10=0.1333, n_test_items=1135
#   Left-out user 528805dfa4495d6e8ac97f881ba54a93: NDCG@10=0.0000, n_test_items=3
#   Left-out user 548da090423d7988b4cee214a6ee7d1c: NDCG@10=0.0667, n_test_items=328
#   Left-out user 5520bd4de4a77552c1d9094a0533bcde: NDCG@10=0.0000, n_test_items=9
#   Left-out user 570c9378801a8b7bcc508bf3888dacdd: NDCG@10=0.1333, n_test_items=850
#   Left-out user 5715af9f68d0bc5b9874d912439468a4: NDCG@10=0.0125, n_test_items=497
#   Left-out user 57323ce3500a7a866d69d7f104eb4890: NDCG@10=0.0000, n_test_items=121
#   Left-out user 57ae16c4ed0a5dca87925881413938d8: NDCG@10=0.1750, n_test_items=720
#   Left-out user 57af84aa4b30181d4d9d7c2a626dc06e: NDCG@10=0.0000, n_test_items=242
#   Left-out user 57c9cc2ac02b4894eb027323a0c50010: NDCG@10=0.0000, n_test_items=244
#   Left-out user 599ceff0a84dc8cf9178880acca5213f: NDCG@10=0.0000, n_test_items=7
#   Left-out user 5a22d0fc0842fd9194f1ea38712f66f6: NDCG@10=0.0824, n_test_items=609
#   Left-out user 5a86cf996f5da8513530d839aefec9a5: NDCG@10=0.0000, n_test_items=154
#   Left-out user 5b0e3171111759b19d32ed6b8f71dfbc: NDCG@10=0.4118, n_test_items=1136
#   Left-out user 5bac7fedbf1056f90292483c7bdaa3f7: NDCG@10=0.0000, n_test_items=110
#   Left-out user 5c71a22110f8799370bde7f45349ceed: NDCG@10=0.0000, n_test_items=38
#   Left-out user 5c94f3e0be7e65faf11d480a7fc76d88: NDCG@10=0.0000, n_test_items=42
#   Left-out user 5ddaf79effbe3d0b9b8a7f41e8eee944: NDCG@10=0.0000, n_test_items=26
#   Left-out user 5e4e748682843750177dedd54abc6817: NDCG@10=0.0000, n_test_items=74
#   Left-out user 5edc7fac7178f39672b9387bde6b45c3: NDCG@10=0.0000, n_test_items=4
#   Left-out user 5ef7eb7ed57c696c5ae8602ee22706b3: NDCG@10=0.4222, n_test_items=1154
#   Left-out user 60196aa0ec61d5fc79ccd2d4c02c46af: NDCG@10=0.0000, n_test_items=120
#   Left-out user 604f7333f04114b863497d0159e65e78: NDCG@10=0.0000, n_test_items=131
#   Left-out user 6061ee13eef22979c9b019bbb5526069: NDCG@10=0.3176, n_test_items=632
#   Left-out user 607cb1a5d022cd92eae9932c3191a732: NDCG@10=0.1500, n_test_items=363
#   Left-out user 60d2994860f1d12b76f594e3543e6e71: NDCG@10=0.0667, n_test_items=543
#   Left-out user 629287b369ac062b5aabf335b57be814: NDCG@10=0.5333, n_test_items=1027
#   Left-out user 630c54bf5947f4518d41c758d55f3620: NDCG@10=0.0000, n_test_items=36
#   Left-out user 6338c66185bed178e2842c313e91bd16: NDCG@10=0.2000, n_test_items=626
#   Left-out user 6400c1f18085936e736b4f9da4fcac54: NDCG@10=0.0000, n_test_items=27
#   Left-out user 67491ceff046cc7972f4502a6491e652: NDCG@10=0.4500, n_test_items=1166
#   Left-out user 67eda3f0faec6c8db4d3aaf0bfb8cd89: NDCG@10=0.2000, n_test_items=585
#   Left-out user 691be87b9359f1a523d662b30aebaeaa: NDCG@10=0.0000, n_test_items=36
#   Left-out user 6aa5523048f6d068d395da3491e50aec: NDCG@10=0.0667, n_test_items=161
#   Left-out user 6aabc825deeac290f05b481a4c3b4b2f: NDCG@10=0.1412, n_test_items=1192
#   Left-out user 6dc440420258c0dc658eeb7087175447: NDCG@10=0.0000, n_test_items=118
#   Left-out user 6e12e1dfb66974cb5b7926c1a93370e6: NDCG@10=0.0000, n_test_items=25
#   Left-out user 6e2a5a480c1b3794db9ef93704bf7911: NDCG@10=0.0000, n_test_items=10
#   Left-out user 6f030cca3695043fbd1ab28a80fa1642: NDCG@10=0.0000, n_test_items=8
#   Left-out user 6f3ee61714f01a03a1f336016a971c98: NDCG@10=0.0000, n_test_items=74
#   Left-out user 6ffdc203c4100200dc86e79a4627a4a2: NDCG@10=0.0000, n_test_items=97
#   Left-out user 7091415866d5d0b9cb0f9be9cca3dbe9: NDCG@10=0.0000, n_test_items=20
#   Left-out user 736f55466e60cc5b89efff729c6aead1: NDCG@10=0.0000, n_test_items=10
#   Left-out user 75beba3a959306b160d8e550de5d0828: NDCG@10=0.0667, n_test_items=1129
#   Left-out user 75d0a99bbe07bd245b3e0bf14dde4a7a: NDCG@10=0.0000, n_test_items=18
#   Left-out user 75f74ef71a30ea288a1080cfc003270b: NDCG@10=0.0000, n_test_items=335
#   Left-out user 760876a30551767cb8dbfd9540033fc0: NDCG@10=0.0667, n_test_items=166
#   Left-out user 76b19aa2995ca4b75d0a00ea8697a952: NDCG@10=0.0000, n_test_items=25
#   Left-out user 78bd94ee2fb6e1d7689192c52d0ce784: NDCG@10=0.0000, n_test_items=83
#   Left-out user 7937913e1b3414ed466bd7468c537681: NDCG@10=0.0667, n_test_items=433
#   Left-out user 7997e04a523b022071b7946830bfec9a: NDCG@10=0.0667, n_test_items=185
#   Left-out user 7bebee95d3a8f58bd668f9b3a9a37ac9: NDCG@10=0.0000, n_test_items=112
#   Left-out user 7cd41b5e73b3a86f2301b66d207c9db6: NDCG@10=0.0000, n_test_items=95
#   Left-out user 7d25c880b7427084b5a0001abd6cef21: NDCG@10=0.1375, n_test_items=807
#   Left-out user 7d3b625c9e1756e7eccadb5e7507d785: NDCG@10=0.0000, n_test_items=33
#   Left-out user 7e5d5c610d39a23bf469a4cf86a68159: NDCG@10=0.0000, n_test_items=3
#   Left-out user 7e7f3042796772b9720f875648e1e390: NDCG@10=0.0667, n_test_items=74
#   Left-out user 7ed4dec827db3ef02d0c3260704f72b2: NDCG@10=0.2125, n_test_items=932
#   Left-out user 7eef5f8cf623fa53cd76144928bbd075: NDCG@10=0.0000, n_test_items=74
#   Left-out user 7f4248d5d43dce6c96972008b627a58f: NDCG@10=0.0000, n_test_items=8
#   Left-out user 7f7d5323d00cda473c6cccf3cd1dd350: NDCG@10=0.0250, n_test_items=1218
#   Left-out user 8029fea2643a45f6c3346aae9ab56596: NDCG@10=0.0000, n_test_items=112
#   Left-out user 806fc581a43ba60b0f46c4e4717692e6: NDCG@10=0.0000, n_test_items=4
#   Left-out user 80abd77077bdc11308178d830d50966b: NDCG@10=0.0000, n_test_items=278
#   Left-out user 8272c4f28e6b137c4b3139118e5a493f: NDCG@10=0.0471, n_test_items=554
#   Left-out user 82fa387d8dffd9832ee488542a068d15: NDCG@10=0.0000, n_test_items=46
#   Left-out user 8322389ae010fbd858d7fd1981159292: NDCG@10=0.0000, n_test_items=577
#   Left-out user 841831a1f2fb0209030ac0426cb430c8: NDCG@10=0.0000, n_test_items=258
#   Left-out user 8471a959fed8614e8dd5a62c97530fe8: NDCG@10=0.0000, n_test_items=34
#   Left-out user 84e4d48000f53b053bb6e713fd9f0ff6: NDCG@10=0.0000, n_test_items=22
#   Left-out user 8579f5442d69fef62c14ef0089b53120: NDCG@10=0.0000, n_test_items=23
#   Left-out user 85991072f65697d7ae7cc35ff4ff6421: NDCG@10=0.0000, n_test_items=113
#   Left-out user 85cfa0f9e44950c26f5b5d65cb2f3d2e: NDCG@10=0.0667, n_test_items=1035
#   Left-out user 85f3fa94f6d5cfc6d2b3ea0f944ccb7b: NDCG@10=0.0000, n_test_items=68
#   Left-out user 863c4b751397e49e5d335f84a99e041f: NDCG@10=0.0000, n_test_items=157
#   Left-out user 88f430db28e75019041a51776cd759f9: NDCG@10=0.0000, n_test_items=49
#   Left-out user 8a614460361b54fc395b8bd133f3d53a: NDCG@10=0.4000, n_test_items=987
#   Left-out user 8afff0bd59b3e9e2915c56d848503189: NDCG@10=0.0000, n_test_items=545
#   Left-out user 8b5874fb0a1f2aac47ca477a2f8810f5: NDCG@10=0.0000, n_test_items=82
#   Left-out user 8c8b78d09aabfeb56e0cff6bdadf9932: NDCG@10=0.0000, n_test_items=302
#   Left-out user 8d125ec3ed4e911cc40fc2c7feca4665: NDCG@10=0.0000, n_test_items=10
#   Left-out user 8d3fb00a64dd788221f3aecbfbfee218: NDCG@10=0.0000, n_test_items=151
#   Left-out user 8e8570de6673c5c33386a25fcc76c249: NDCG@10=0.2000, n_test_items=1371
#   Left-out user 8f73da1e8ae660c7513641d9d59e8f6b: NDCG@10=0.0000, n_test_items=282
#   Left-out user 90d64ce67a462da5e3e72e9a6ed6cf72: NDCG@10=0.0000, n_test_items=33
#   Left-out user 918e2de571fe5d21a5cb03df0972106d: NDCG@10=0.6000, n_test_items=1227
#   Left-out user 92120756a22d7133085b14eec1bbd96b: NDCG@10=0.1000, n_test_items=546
#   Left-out user 9275cf3a9831f938667626eeec7b7c74: NDCG@10=0.5053, n_test_items=1482
#   Left-out user 92ec19edd2ed135056691b13cb35ff63: NDCG@10=0.2000, n_test_items=760
#   Left-out user 935adc97adb465b94b07a241069425cc: NDCG@10=0.1222, n_test_items=388
#   Left-out user 936afe4c6c620965afea35c37b44f833: NDCG@10=0.0000, n_test_items=406
#   Left-out user 9466223293e5ddf532ce93b87dd04fad: NDCG@10=0.0000, n_test_items=13
#   Left-out user 94bd6242868ab1d3f43f085ad757ff7b: NDCG@10=0.0000, n_test_items=353
#   Left-out user 95dfc7e4ac06738557fad16ee021644b: NDCG@10=0.0000, n_test_items=163
#   Left-out user 95fea58479822e5942a339b817d92b6b: NDCG@10=0.0000, n_test_items=108
#   Left-out user 9610f77463aa1dc2bda5f923337a21d7: NDCG@10=0.0000, n_test_items=22
#   Left-out user 98e5244f8bb68b5740850ab24573c017: NDCG@10=0.0000, n_test_items=11
#   Left-out user 9913d7d4c4014e75f4d71c1fb709f7b9: NDCG@10=0.0000, n_test_items=114
#   Left-out user 99959ca3dfe40d82568db050596948b4: NDCG@10=0.0000, n_test_items=53
#   Left-out user 99cd9e6aeccdec9e6bf744e292171c18: NDCG@10=0.0000, n_test_items=34
#   Left-out user 99d56dfa2bf934a4a48435271c9015a3: NDCG@10=0.0000, n_test_items=42
#   Left-out user 9a31ea87f222c2ed002d81cf237fcc9d: NDCG@10=0.0000, n_test_items=499
#   Left-out user 9a3390e99fa2f377e6a91a586f89af0e: NDCG@10=0.0000, n_test_items=46
#   Left-out user 9b763981424074df93c6b9aa101c4485: NDCG@10=0.0000, n_test_items=226
#   Left-out user 9bc296bebd5a88045279fac4abde279e: NDCG@10=0.3765, n_test_items=408
#   Left-out user 9d30bf7bc95f0ce348ff947cbf5b1dca: NDCG@10=0.0000, n_test_items=65
#   Left-out user 9e29c60e447028e52d9b52c3059ecbe7: NDCG@10=0.1333, n_test_items=183
#   Left-out user 9ea7daabbdc3c56d9e54235bddb889d7: NDCG@10=0.0000, n_test_items=152
#   Left-out user 9fb20ba713b179f24495f6d969bf42fd: NDCG@10=0.0000, n_test_items=57
#   Left-out user 9fcef0961596a361e45178cbe7664b76: NDCG@10=0.0667, n_test_items=46
#   Left-out user 9fe384d5aae32897fb237f0bc1fa735f: NDCG@10=0.0667, n_test_items=343
#   Left-out user 9fe9468f2714c2f43acff287fd785985: NDCG@10=0.0000, n_test_items=29
#   Left-out user a0283278a2762f9f893c172ce2ae28ae: NDCG@10=0.0667, n_test_items=266
#   Left-out user a21805b93948e07b3ca19399aaa26a1b: NDCG@10=0.0000, n_test_items=23
#   Left-out user a25995ac5c430a097fe42c5b80cbca93: NDCG@10=0.0000, n_test_items=10
#   Left-out user a2dc9281b961eef6e29d66335a20b7bf: NDCG@10=0.0000, n_test_items=104
#   Left-out user a3c9df5b15b0a6b1926a929f745f6355: NDCG@10=0.4353, n_test_items=745
#   Left-out user a60f9da2acfcd81a1722df5938f1e1a7: NDCG@10=0.1333, n_test_items=852
#   Left-out user a670f905b78ce21ec5ae78fb1e514d88: NDCG@10=0.0000, n_test_items=138
#   Left-out user a6c0cda9061b82a0951cc1de293af62e: NDCG@10=0.0000, n_test_items=390
#   Left-out user aa4a6fa20ef0be3b9e8f8ceb3f075858: NDCG@10=0.5176, n_test_items=1177
#   Left-out user aa4c1abbf29d76cf70f7740bfc85a35f: NDCG@10=0.1333, n_test_items=1736
#   Left-out user aa98334a880507fb150021be7b2a37e0: NDCG@10=0.0667, n_test_items=122
#   Left-out user aace0606f25529cb645f28c6c0586577: NDCG@10=0.0000, n_test_items=50
#   Left-out user add03e608bef35f1c5bc13d990b9f317: NDCG@10=0.0000, n_test_items=37
#   Left-out user add247ff11a1cdd16f3117878d70b7f2: NDCG@10=0.0000, n_test_items=1424
#   Left-out user aeb4a7d549713081c22fac75981733fb: NDCG@10=0.2125, n_test_items=661
#   Left-out user af225c460d5c2574c30c1233e040437c: NDCG@10=0.0125, n_test_items=313
#   Left-out user b0a136d836a3dc742bd514ac3c6f4b92: NDCG@10=0.2588, n_test_items=1757
#   Left-out user b12e08675d640e90df6dfa3923574286: NDCG@10=0.0000, n_test_items=361
#   Left-out user b30192f8313c378cc0a158f0563ae1d9: NDCG@10=0.0000, n_test_items=217
#   Left-out user b3740aaa07240ffa5201a93b09899e77: NDCG@10=0.0000, n_test_items=252
#   Left-out user b4e1d8d3fe1381c841c9c8a87ca6753f: NDCG@10=0.0000, n_test_items=41
#   Left-out user b7053409ecb49ac940b9c43f1cd43de8: NDCG@10=0.0000, n_test_items=143
# ...
#   Left-out user 7bebee95d3a8f58bd668f9b3a9a37ac9: NDCG@10=0.0000, n_test_items=212
#   Left-out user 7cd41b5e73b3a86f2301b66d207c9db6: NDCG@10=0.0000, n_test_items=105
#   Left-out user 7d25c880b7427084b5a0001abd6cef21: NDCG@10=0.0851, n_test_items=559
#   Left-out user 7d3b625c9e1756e7eccadb5e7507d785: NDCG@10=0.0021, n_test_items=43
#   Left-out user 7e5d5c610d39a23bf469a4cf86a68159: NDCG@10=0.0000, n_test_items=23
#   Left-out user 7e7f3042796772b9720f875648e1e390: NDCG@10=0.3264, n_test_items=254
#   Left-out user 7ed4dec827db3ef02d0c3260704f72b2: NDCG@10=0.0424, n_test_items=357
#   Left-out user 7eef5f8cf623fa53cd76144928bbd075: NDCG@10=0.0000, n_test_items=83
#   Left-out user 7f4248d5d43dce6c96972008b627a58f: NDCG@10=0.0000, n_test_items=7
#   Left-out user 7f7d5323d00cda473c6cccf3cd1dd350: NDCG@10=0.0000, n_test_items=616
#   Left-out user 8029fea2643a45f6c3346aae9ab56596: NDCG@10=0.0000, n_test_items=50
#   Left-out user 806fc581a43ba60b0f46c4e4717692e6: NDCG@10=0.0000, n_test_items=4
#   Left-out user 80abd77077bdc11308178d830d50966b: NDCG@10=0.0000, n_test_items=342
#   Left-out user 8272c4f28e6b137c4b3139118e5a493f: NDCG@10=0.0000, n_test_items=568
#   Left-out user 82fa387d8dffd9832ee488542a068d15: NDCG@10=0.0000, n_test_items=256
#   Left-out user 8322389ae010fbd858d7fd1981159292: NDCG@10=0.0000, n_test_items=721
#   Left-out user 841831a1f2fb0209030ac0426cb430c8: NDCG@10=0.0000, n_test_items=258
#   Left-out user 8471a959fed8614e8dd5a62c97530fe8: NDCG@10=0.0000, n_test_items=22
#   Left-out user 84e4d48000f53b053bb6e713fd9f0ff6: NDCG@10=0.0000, n_test_items=15
#   Left-out user 8579f5442d69fef62c14ef0089b53120: NDCG@10=0.0000, n_test_items=21
#   Left-out user 85991072f65697d7ae7cc35ff4ff6421: NDCG@10=0.0000, n_test_items=283
#   Left-out user 85cfa0f9e44950c26f5b5d65cb2f3d2e: NDCG@10=0.0000, n_test_items=603
#   Left-out user 85f3fa94f6d5cfc6d2b3ea0f944ccb7b: NDCG@10=0.0000, n_test_items=16
#   Left-out user 863c4b751397e49e5d335f84a99e041f: NDCG@10=0.0000, n_test_items=273
#   Left-out user 88f430db28e75019041a51776cd759f9: NDCG@10=0.0000, n_test_items=21
#   Left-out user 8a614460361b54fc395b8bd133f3d53a: NDCG@10=0.3723, n_test_items=820
#   Left-out user 8afff0bd59b3e9e2915c56d848503189: NDCG@10=0.0000, n_test_items=418
#   Left-out user 8b5874fb0a1f2aac47ca477a2f8810f5: NDCG@10=0.0000, n_test_items=110
#   Left-out user 8c8b78d09aabfeb56e0cff6bdadf9932: NDCG@10=0.0000, n_test_items=514
#   Left-out user 8d125ec3ed4e911cc40fc2c7feca4665: NDCG@10=0.0000, n_test_items=21
#   Left-out user 8d3fb00a64dd788221f3aecbfbfee218: NDCG@10=0.0000, n_test_items=211
#   Left-out user 8e8570de6673c5c33386a25fcc76c249: NDCG@10=0.1697, n_test_items=1048
#   Left-out user 8f73da1e8ae660c7513641d9d59e8f6b: NDCG@10=0.0000, n_test_items=325
#   Left-out user 90d64ce67a462da5e3e72e9a6ed6cf72: NDCG@10=0.0000, n_test_items=46
#   Left-out user 918e2de571fe5d21a5cb03df0972106d: NDCG@10=0.2421, n_test_items=842
#   Left-out user 92120756a22d7133085b14eec1bbd96b: NDCG@10=0.0627, n_test_items=616
#   Left-out user 9275cf3a9831f938667626eeec7b7c74: NDCG@10=0.2940, n_test_items=1099
#   Left-out user 92ec19edd2ed135056691b13cb35ff63: NDCG@10=0.0000, n_test_items=548
#   Left-out user 935adc97adb465b94b07a241069425cc: NDCG@10=0.0000, n_test_items=241
#   Left-out user 936afe4c6c620965afea35c37b44f833: NDCG@10=0.0000, n_test_items=332
#   Left-out user 9466223293e5ddf532ce93b87dd04fad: NDCG@10=0.0000, n_test_items=13
#   Left-out user 94bd6242868ab1d3f43f085ad757ff7b: NDCG@10=0.0000, n_test_items=534
#   Left-out user 95dfc7e4ac06738557fad16ee021644b: NDCG@10=0.0000, n_test_items=150
#   Left-out user 95fea58479822e5942a339b817d92b6b: NDCG@10=0.0000, n_test_items=72
#   Left-out user 9610f77463aa1dc2bda5f923337a21d7: NDCG@10=0.0851, n_test_items=76
#   Left-out user 98e5244f8bb68b5740850ab24573c017: NDCG@10=0.0000, n_test_items=10
#   Left-out user 9913d7d4c4014e75f4d71c1fb709f7b9: NDCG@10=0.0000, n_test_items=67
#   Left-out user 99959ca3dfe40d82568db050596948b4: NDCG@10=0.0851, n_test_items=249
#   Left-out user 99cd9e6aeccdec9e6bf744e292171c18: NDCG@10=0.0000, n_test_items=16
#   Left-out user 99d56dfa2bf934a4a48435271c9015a3: NDCG@10=0.0000, n_test_items=134
#   Left-out user 9a31ea87f222c2ed002d81cf237fcc9d: NDCG@10=0.0000, n_test_items=385
#   Left-out user 9a3390e99fa2f377e6a91a586f89af0e: NDCG@10=0.0000, n_test_items=288
#   Left-out user 9b763981424074df93c6b9aa101c4485: NDCG@10=0.0000, n_test_items=148
#   Left-out user 9bc296bebd5a88045279fac4abde279e: NDCG@10=0.0000, n_test_items=344
#   Left-out user 9d30bf7bc95f0ce348ff947cbf5b1dca: NDCG@10=0.0000, n_test_items=143
#   Left-out user 9e29c60e447028e52d9b52c3059ecbe7: NDCG@10=0.2201, n_test_items=353
#   Left-out user 9ea7daabbdc3c56d9e54235bddb889d7: NDCG@10=0.0000, n_test_items=69
#   Left-out user 9fb20ba713b179f24495f6d969bf42fd: NDCG@10=0.0190, n_test_items=111
#   Left-out user 9fcef0961596a361e45178cbe7664b76: NDCG@10=0.2135, n_test_items=94
#   Left-out user 9fe384d5aae32897fb237f0bc1fa735f: NDCG@10=0.0000, n_test_items=164
#   Left-out user 9fe9468f2714c2f43acff287fd785985: NDCG@10=0.0000, n_test_items=91
#   Left-out user a0283278a2762f9f893c172ce2ae28ae: NDCG@10=0.1378, n_test_items=394
#   Left-out user a21805b93948e07b3ca19399aaa26a1b: NDCG@10=0.0000, n_test_items=33
#   Left-out user a25995ac5c430a097fe42c5b80cbca93: NDCG@10=0.0000, n_test_items=10
#   Left-out user a2dc9281b961eef6e29d66335a20b7bf: NDCG@10=0.0000, n_test_items=110
#   Left-out user a3c9df5b15b0a6b1926a929f745f6355: NDCG@10=0.3158, n_test_items=549
#   Left-out user a60f9da2acfcd81a1722df5938f1e1a7: NDCG@10=0.0043, n_test_items=802
#   Left-out user a670f905b78ce21ec5ae78fb1e514d88: NDCG@10=0.0000, n_test_items=97
#   Left-out user a6c0cda9061b82a0951cc1de293af62e: NDCG@10=0.0000, n_test_items=214
#   Left-out user aa4a6fa20ef0be3b9e8f8ceb3f075858: NDCG@10=0.0877, n_test_items=485
#   Left-out user aa4c1abbf29d76cf70f7740bfc85a35f: NDCG@10=0.1378, n_test_items=1169
#   Left-out user aa98334a880507fb150021be7b2a37e0: NDCG@10=0.0000, n_test_items=86
#   Left-out user aace0606f25529cb645f28c6c0586577: NDCG@10=0.0000, n_test_items=178
#   Left-out user add03e608bef35f1c5bc13d990b9f317: NDCG@10=0.0000, n_test_items=16
#   Left-out user add247ff11a1cdd16f3117878d70b7f2: NDCG@10=0.1389, n_test_items=1258
#   Left-out user aeb4a7d549713081c22fac75981733fb: NDCG@10=0.0000, n_test_items=606
#   Left-out user af225c460d5c2574c30c1233e040437c: NDCG@10=0.0000, n_test_items=277
#   Left-out user b0a136d836a3dc742bd514ac3c6f4b92: NDCG@10=0.0770, n_test_items=1035
#   Left-out user b12e08675d640e90df6dfa3923574286: NDCG@10=0.0000, n_test_items=171
#   Left-out user b30192f8313c378cc0a158f0563ae1d9: NDCG@10=0.0278, n_test_items=254
#   Left-out user b3740aaa07240ffa5201a93b09899e77: NDCG@10=0.0000, n_test_items=106
#   Left-out user b4e1d8d3fe1381c841c9c8a87ca6753f: NDCG@10=0.0000, n_test_items=183
#   Left-out user b7053409ecb49ac940b9c43f1cd43de8: NDCG@10=0.0000, n_test_items=208
#   Left-out user b719e3f0e9502a6955333f344a864d0c: NDCG@10=0.0136, n_test_items=394
#   Left-out user b78c646642bdefa4358dbe41c7fd8519: NDCG@10=0.2659, n_test_items=339
#   Left-out user b81c3bab6d9c61ba9833434717095b6c: NDCG@10=0.0851, n_test_items=102
#   Left-out user b91d595b94b0dbf77368c65d799a51fc: NDCG@10=0.0000, n_test_items=124
#   Left-out user ba17211868c4341e8beb1e05d15ee35a: NDCG@10=0.0000, n_test_items=987
#   Left-out user ba1c26c63f66b311541d7f7d4f330a99: NDCG@10=0.1876, n_test_items=123
#   Left-out user ba2d5114cfba51db92fb1076f543998c: NDCG@10=0.0000, n_test_items=410
#   Left-out user ba3aead3e7d97af7c8447f68db6926d0: NDCG@10=0.0000, n_test_items=6
#   Left-out user bb953b3f720c17ef70b54b1433edf042: NDCG@10=0.2201, n_test_items=433
#   Left-out user bc4b888d497b89951ecccb7bbf6116d4: NDCG@10=0.2756, n_test_items=432
#   Left-out user bc7584dd10c17c7ab7b13e6ac9523a4d: NDCG@10=0.0000, n_test_items=11
#   Left-out user bc7dbd351ed5e2bc359ac6a36247590d: NDCG@10=0.0000, n_test_items=421
#   Left-out user bdb3c7577a14fd1cd125290c197504fb: NDCG@10=0.1980, n_test_items=851
#   Left-out user bdf87a5f07383649d749765e8db6f3a7: NDCG@10=0.0000, n_test_items=192
#   Left-out user be95d2d16b9220ea3906643d54b59a90: NDCG@10=0.0000, n_test_items=53
#   Left-out user c055083da103f98b8c75d24e933a73d5: NDCG@10=0.0000, n_test_items=79
#   Left-out user c11b38b53d8d318d4321d31922de1852: NDCG@10=0.0000, n_test_items=14
#   Left-out user c2f4f8d9c3d4836c783fb25db228bdcc: NDCG@10=0.0000, n_test_items=82
#   Left-out user c3fed64b100f211f4fa106b65dfde8d2: NDCG@10=0.0278, n_test_items=268
#   Left-out user c4360c1edb8b4195581ae0f0ca366449: NDCG@10=0.0000, n_test_items=390
#   Left-out user c4b5ed8e35f0a55a4bfbdcbbcacfe131: NDCG@10=0.0000, n_test_items=838
#   Left-out user c4cbbbf32176fcc196795d56eb21d0e5: NDCG@10=0.0278, n_test_items=89
#   Left-out user c55eb3a5c4871e90cf83519d30b8f9c9: NDCG@10=0.0000, n_test_items=144
#   Left-out user c625e60059faad10f733ab395917506b: NDCG@10=0.0000, n_test_items=616
#   Left-out user c78859a8b046c9e6ee28094abe874e83: NDCG@10=0.0000, n_test_items=417
#   Left-out user c87b7cc0f0baae94203da80370f4990b: NDCG@10=0.0000, n_test_items=79
#   Left-out user c8de92d9ad2a1b6e90b8ab7eedb6ebeb: NDCG@10=0.0615, n_test_items=365
#   Left-out user c9a7b8be73ebd53a4fe482cb1ff05e52: NDCG@10=0.3495, n_test_items=500
#   Left-out user caf6b231df17d862a8afb50fedd7497d: NDCG@10=0.0000, n_test_items=123
#   Left-out user cb4d02891b7388a483d4d62f08b0b898: NDCG@10=0.0000, n_test_items=115
#   Left-out user cb6370414c535a767a05f4fb8584e4e0: NDCG@10=0.0627, n_test_items=1054
#   Left-out user ccbdf84a9f25aba01e8eed1b6e402cfc: NDCG@10=0.0440, n_test_items=426
#   Left-out user cde5c36cf21a04c93c5d638a47d93a14: NDCG@10=0.0000, n_test_items=8
#   Left-out user cdeb1f2e7d41de1a12dd891dd0da9b7a: NDCG@10=0.0000, n_test_items=24
#   Left-out user ce619e04a6c578502eb47d2e8fa0734d: NDCG@10=0.0000, n_test_items=113
#   Left-out user ceb9a212ab4d8fb0be9828beb020a848: NDCG@10=0.0555, n_test_items=1034
#   Left-out user cf780f4ddcb8c00c6ac23afb37d52dae: NDCG@10=0.0000, n_test_items=7
#   Left-out user cfa4293588943a18e329ec9450fe4f58: NDCG@10=0.0000, n_test_items=70
#   Left-out user d0b81b79c5da3ee544a0b549ab11bf36: NDCG@10=0.0000, n_test_items=991
#   Left-out user d117b1fa4816274bad3b124f9bc9b836: NDCG@10=0.0000, n_test_items=82
#   Left-out user d13d54bc573490213cee7196c2d99198: NDCG@10=0.0000, n_test_items=255
#   Left-out user d17757f195bed106b840b05c31620d90: NDCG@10=0.0000, n_test_items=59
#   Left-out user d3da2778eaf14237dde32b08093ba865: NDCG@10=0.0000, n_test_items=176
#   Left-out user d4cdb2e4a1175556acdd10284391ce30: NDCG@10=0.0000, n_test_items=399
#   Left-out user d6b6d8a6c6346626c8d673519ae16c5d: NDCG@10=0.0000, n_test_items=1531
#   Left-out user d91f62b3addd8857dfd7f15f5dc19144: NDCG@10=0.3052, n_test_items=575
#   Left-out user d94f12386537c7bb53c64c7f95c72dae: NDCG@10=0.0000, n_test_items=202
#   Left-out user db22c3330010b7395e482bfd30499d5d: NDCG@10=0.0000, n_test_items=95
#   Left-out user db528c1228870a562aabb4e85f81636d: NDCG@10=0.0555, n_test_items=1369
#   Left-out user db7b75dd3496d2f16b3dc8c789128389: NDCG@10=0.0180, n_test_items=958
#   Left-out user dc503db1918adfdb82e50018075e4e86: NDCG@10=0.0000, n_test_items=54
#   Left-out user dca8dee49b5b5498e153a81baa6ffb83: NDCG@10=0.0000, n_test_items=495
#   Left-out user dcb9bd758192391033375e09b35c4f86: NDCG@10=0.0220, n_test_items=162
#   Left-out user e1b8d11473458133ac34f21f84e68cc2: NDCG@10=0.0000, n_test_items=103
#   Left-out user e327f9b0d0253e05a2eb27da88a5978e: NDCG@10=0.2201, n_test_items=251
#   Left-out user e4973ba7fb519cb1ae2712fe22336fc5: NDCG@10=0.0000, n_test_items=31
#   Left-out user e498ee8ef660429ee298d3b03851f633: NDCG@10=0.0000, n_test_items=46
#   Left-out user e4e65ae9328f589369fe193b4615fb47: NDCG@10=0.0660, n_test_items=429
#   Left-out user e5274c8192b0f0baed7503da938ec7c6: NDCG@10=0.1389, n_test_items=484
#   Left-out user e53917e067246f32375050cf300cb4b1: NDCG@10=0.0615, n_test_items=377
#   Left-out user e5638817a49654844029877d07dde483: NDCG@10=0.1829, n_test_items=467
#   Left-out user e583814caefc5c78f3fd2dc01571e862: NDCG@10=0.0000, n_test_items=988
#   Left-out user e607194702fd4205848d2c3b5b164a51: NDCG@10=0.0000, n_test_items=121
#   Left-out user e628020db39ca283d83a6e5a5beb6289: NDCG@10=0.0000, n_test_items=70
#   Left-out user e63b5aaaf83943bfdc003af680d991f6: NDCG@10=0.0000, n_test_items=302
#   Left-out user e6633a23f7ba8b1c231fbb5a7afd210b: NDCG@10=0.1160, n_test_items=709
#   Left-out user e7aea83bd3881673b3997a3aae04246f: NDCG@10=0.0000, n_test_items=325
#   Left-out user e95a3f90318b20cb34eb53b1661c6410: NDCG@10=0.0000, n_test_items=758
#   Left-out user ea1f218dadb90c02a55e44fc1702c661: NDCG@10=0.0000, n_test_items=41
#   Left-out user eacaf8e8255da6a24858fcf0fd74119a: NDCG@10=0.0851, n_test_items=1172
#   Left-out user eb61cbb4b4d06c55abff1275d948c5c1: NDCG@10=0.0000, n_test_items=155
#   Left-out user eb8e38b302bcfbbfdf733053ea35ec0d: NDCG@10=0.0000, n_test_items=97
#   Left-out user eba9fa22681fa1464dbed7172d293429: NDCG@10=0.0000, n_test_items=28
#   Left-out user eefa81fd4a1e5ec72714527b20d5d064: NDCG@10=0.1160, n_test_items=303
#   Left-out user f00b1cc4098002bc33257ff3b6ad76a8: NDCG@10=0.0000, n_test_items=80
#   Left-out user f058da4cda7a047f1172c5f88a0a12de: NDCG@10=0.0000, n_test_items=2
#   Left-out user f0d8193888d5082bea4a9297a8fa1bc5: NDCG@10=0.1389, n_test_items=835
#   Left-out user f13a2d26493632933a42f18040c1dafa: NDCG@10=0.0000, n_test_items=38
#   Left-out user f279dc20a57ca6e9c1e51fcebfd181d6: NDCG@10=0.0000, n_test_items=13
#   Left-out user f2cb35d7fde9d956b3de5dfa28d675af: NDCG@10=0.0851, n_test_items=230
#   Left-out user f2df90328d03f94db7a421267dade931: NDCG@10=0.0000, n_test_items=12
#   Left-out user f353436d61cbda22cc7b7d4a8d2a734a: NDCG@10=0.0000, n_test_items=127
#   Left-out user f4625def3cd5f9b14b72af3d468a318c: NDCG@10=0.0000, n_test_items=179
#   Left-out user f467382e1b52562ae15e151e0605c712: NDCG@10=0.0000, n_test_items=326
#   Left-out user f49ecad2937f54ea688a95df503ff6a4: NDCG@10=0.0000, n_test_items=558
#   Left-out user f4b983df51c8f36d9f277bf25e345a2e: NDCG@10=0.0278, n_test_items=462
#   Left-out user f4e6d3e9954c8622e70a706e123d54f6: NDCG@10=0.0000, n_test_items=300
#   Left-out user f6cefebbf6af74b3cb5564d274c73974: NDCG@10=0.0000, n_test_items=18
#   Left-out user f897d285b5939bce6b195002a7ccf7b1: NDCG@10=0.0000, n_test_items=45
#   Left-out user f8bde75134fadc750d7a6daeca685bdf: NDCG@10=0.0000, n_test_items=11
#   Left-out user f90fe34419be55e9007c820eb5772524: NDCG@10=0.0000, n_test_items=21
#   Left-out user f94fc655cf65e0187f96a833252ea923: NDCG@10=0.0000, n_test_items=100
#   Left-out user f9789c1bb9a0f71d11ee13fa2f31fbfc: NDCG@10=0.0440, n_test_items=598
#   Left-out user f9f219a8ea089721d5fdfc91978d01d2: NDCG@10=0.0000, n_test_items=1292
#   Left-out user fa44ebc9638368e9f2e23e122e26ee9a: NDCG@10=0.0000, n_test_items=610
#   Left-out user fac9b25bfb788251893522845b400bf1: NDCG@10=0.0615, n_test_items=73
#   Left-out user fbbfbcc25919d85047836acd18669270: NDCG@10=0.0000, n_test_items=331
#   Left-out user fc5720a7d99321573c359757cba2e8fd: NDCG@10=0.0000, n_test_items=2
#   Left-out user fc94354770dd3adc7871c6d060d9c645: NDCG@10=0.0000, n_test_items=515
#   Left-out user fcf2183bbbd7a733740436ec6ee26916: NDCG@10=0.0353, n_test_items=126
#   Left-out user fd10090105a23ab614edca1a7c7ef2d9: NDCG@10=0.0000, n_test_items=153
#   Left-out user fdff7032d1d9a7ff3aa665d4903536cf: NDCG@10=0.0000, n_test_items=311
#   Left-out user fe47f68d9eb9487681126544cc1afee7: NDCG@10=0.0000, n_test_items=240
#   Left-out user fe661b9169b4ec9a1e0fccf3179efe93: NDCG@10=0.0000, n_test_items=52
#   Left-out user fec1a8d5daa5bf4c02b18b8b7f1f53e5: NDCG@10=0.2297, n_test_items=1103
#   Left-out user ff12d43a6f260e06737dacb3a924b46d: NDCG@10=0.0000, n_test_items=16
#   Left-out user ff1e549fd5258a410b185f595f526f4e: NDCG@10=0.0000, n_test_items=214
#   Left-out user ff424c09231fe62240539c754e347972: NDCG@10=0.0278, n_test_items=102
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1} -> Avg NDCG@10: 0.0381, RMSE: 1.7224, RMSE_norm: 0.9839023682883558

# %%
df_results_real = pd.DataFrame(results_real)

# %%
df_results_real
# Out:
#                  Data  Quantile  Duration   Type  Accuracy  Precision  \
# 0   TikTok Real-World      1.00       NaN    all  0.373092   0.347676
# 1   TikTok Real-World      0.20      11.0  short  0.267003   0.300913
# 2   TikTok Real-World      0.20      11.0   long  0.166622   0.292307
# 3   TikTok Real-World      0.25      12.0  short  0.264250   0.291024
# 4   TikTok Real-World      0.25      12.0   long  0.161621   0.294143
# 5   TikTok Real-World      0.50      17.0  short  0.235862   0.312268
# 6   TikTok Real-World      0.50      17.0   long  0.140232   0.284868
# 7   TikTok Real-World      0.75      33.0  short  0.208292   0.307819
# 8   TikTok Real-World      0.75      33.0   long  0.130513   0.279107
# 9   TikTok Real-World      0.80      41.0  short  0.204202   0.307485
# 10  TikTok Real-World      0.80      41.0   long  0.120886   0.266988
#
#       Recall  F1 score      ndcg  k_ndcg      rmse  rmse_norm  avg_ndcg_loo  \
# 0   0.301097  0.287353  0.803080       3  1.546608   0.934442      0.055099
# 1   0.201256  0.146581  0.832809       3  1.406352   0.966811      0.055528
# 2   0.208601  0.137703  0.775050       3  1.586345   0.944788      0.051383
# 3   0.208752  0.146834  0.837152       3  1.416223   0.969889      0.055733
# 4   0.205649  0.135123  0.761250       3  1.590302   0.942622      0.053829
# 5   0.216285  0.161006  0.827596       3  1.441783   0.948169      0.056083
# 6   0.198070  0.119661  0.740472       3  1.639664   0.949582      0.051045
# 7   0.213900  0.152377  0.818924       3  1.490892   0.945087      0.055470
# 8   0.190505  0.109350  0.702213       3  1.696518   0.969212      0.044545
# 9   0.211669  0.152363  0.808195       3  1.498499   0.942723      0.055125
# 10  0.185632  0.100768  0.696350       3  1.707289   0.970435      0.038094
#
#     k_ndcg_loo  rmse_loo  rmse_normalized_loo  num_users_loo
# 0           10  1.548382             0.950453            334
# 1           10  1.401853             0.991252            333
# 2           10  1.589052             0.956743            334
# 3           10  1.408694             0.990514            333
# 4           10  1.595609             0.957485            334
# 5           10  1.437371             0.970440            334
# 6           10  1.658574             0.967649            334
# 7           10  1.490662             0.964555            334
# 8           10  1.711314             0.979499            334
# 9           10  1.501346             0.962807            334
# 10          10  1.722380             0.983902            333

# %%
plot_mf_summary(df_results_real, note="tiktok-real")

# %%
df_results_real.to_csv("data/results_mf_real.csv")

# %% [markdown]
# ## MovieLens data

# %%
df_mf_ml = pd.read_csv('data/movielens-100k/u.data', sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])
df_mf_ml.drop(columns=['timestamp'], inplace=True)
df_mf_ml.rename(columns={"item_id": "video_id"}, inplace=True)
df_mf_ml.head(5)
# Out:
#    user_id  video_id  rating
# 0      196       242       3
# 1      186       302       3
# 2       22       377       1
# 3      244        51       2
# 4      166       346       1

# %%
df_mf_ml[["rating"]].hist(figsize=(5,2))
plt.title("Distribution of video percentage watched \"rating\"")
# Out:
# Text(0.5, 1.0, 'Distribution of video percentage watched "rating"')

# %%
_ = calculate_density(df_mf_ml)
# Out:
# Users: 943, Videos: 1682
# Observed interactions: 100000
# Density: 0.0630
# Sparsity: 0.9370

# %%
summary_plot_ratings(df_mf_ml)
# Out:
# Most active user: 405 (737 ratings)
# Most rated video: 50 (583 ratings)

# %%
param_grid = {
    'n_components': [2, 5, 10, 20, 50, 100, 124],
    'max_iter': [1000, 2000, 3000],
    'init': ['random'],
    'model_type': ['svd'],
    'n_iter': [1, 3, 5, 10, 15]
}

R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_normalized, best_param = grid_search_mf_bias(df_mf_ml, param_grid)
# Out:
# (99859, 3) (79499, 3) (20360, 3)
# cold items [1365 1371 1398]
# 79502 20357 19971.800000000003
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1}
# svd 2 1000 random 1
# Explained variance: 0.03725716727248565
# Number of users used for NDCG: 943
# RMSE: 0.9502, Normalized: 0.8454, NDCG@3: 0.8684
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 3}
# svd 2 1000 random 3
# Explained variance: 0.04093235268294894
# Number of users used for NDCG: 943
# RMSE: 0.9477, Normalized: 0.8432, NDCG@3: 0.8697
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 5}
# svd 2 1000 random 5
# Explained variance: 0.04097635057109182
# Number of users used for NDCG: 943
# RMSE: 0.9476, Normalized: 0.8432, NDCG@3: 0.8697
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 10}
# svd 2 1000 random 10
# Explained variance: 0.040976711448988776
# Number of users used for NDCG: 943
# RMSE: 0.9476, Normalized: 0.8432, NDCG@3: 0.8698
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 15}
# svd 2 1000 random 15
# Explained variance: 0.04097670398686692
# Number of users used for NDCG: 943
# RMSE: 0.9476, Normalized: 0.8432, NDCG@3: 0.8698
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 1}
# svd 5 1000 random 1
# Explained variance: 0.06636710931884629
# Number of users used for NDCG: 943
# RMSE: 0.9467, Normalized: 0.8424, NDCG@3: 0.8704
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 3}
# svd 5 1000 random 3
# Explained variance: 0.07704338260072173
# Number of users used for NDCG: 943
# RMSE: 0.9416, Normalized: 0.8378, NDCG@3: 0.8696
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 5}
# svd 5 1000 random 5
# Explained variance: 0.07796271331476005
# Number of users used for NDCG: 943
# RMSE: 0.9415, Normalized: 0.8377, NDCG@3: 0.8700
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 10}
# svd 5 1000 random 10
# Explained variance: 0.07807202351302335
# Number of users used for NDCG: 943
# RMSE: 0.9416, Normalized: 0.8378, NDCG@3: 0.8702
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 15}
# svd 5 1000 random 15
# Explained variance: 0.0780728707120582
# Number of users used for NDCG: 943
# RMSE: 0.9416, Normalized: 0.8378, NDCG@3: 0.8701
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 1}
# svd 10 1000 random 1
# Explained variance: 0.10666159316732077
# Number of users used for NDCG: 943
# RMSE: 0.9481, Normalized: 0.8436, NDCG@3: 0.8678
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 3}
# svd 10 1000 random 3
# Explained variance: 0.12126824923987768
# Number of users used for NDCG: 943
# RMSE: 0.9408, Normalized: 0.8370, NDCG@3: 0.8740
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 5}
# svd 10 1000 random 5
# Explained variance: 0.12307247436998664
# Number of users used for NDCG: 943
# RMSE: 0.9396, Normalized: 0.8360, NDCG@3: 0.8744
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 10}
# svd 10 1000 random 10
# Explained variance: 0.12401492978673109
# Number of users used for NDCG: 943
# RMSE: 0.9389, Normalized: 0.8354, NDCG@3: 0.8730
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 15}
# svd 10 1000 random 15
# Explained variance: 0.12407299675725517
# Number of users used for NDCG: 943
# RMSE: 0.9388, Normalized: 0.8353, NDCG@3: 0.8730
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 1}
# svd 20 1000 random 1
# Explained variance: 0.1709063026228192
# Number of users used for NDCG: 943
# RMSE: 0.9474, Normalized: 0.8430, NDCG@3: 0.8717
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 3}
# svd 20 1000 random 3
# Explained variance: 0.19341485481269668
# Number of users used for NDCG: 943
# RMSE: 0.9424, Normalized: 0.8385, NDCG@3: 0.8719
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 5}
# svd 20 1000 random 5
# Explained variance: 0.1962950481055234
# Number of users used for NDCG: 943
# RMSE: 0.9415, Normalized: 0.8377, NDCG@3: 0.8719
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 10}
# svd 20 1000 random 10
# Explained variance: 0.19735701631874508
# Number of users used for NDCG: 943
# RMSE: 0.9409, Normalized: 0.8372, NDCG@3: 0.8724
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 15}
# svd 20 1000 random 15
# Explained variance: 0.19748826786082718
# Number of users used for NDCG: 943
# RMSE: 0.9407, Normalized: 0.8370, NDCG@3: 0.8727
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 1}
# svd 50 1000 random 1
# Explained variance: 0.32075390280730487
# Number of users used for NDCG: 943
# RMSE: 0.9534, Normalized: 0.8483, NDCG@3: 0.8707
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 3}
# svd 50 1000 random 3
# Explained variance: 0.3544103797230811
# Number of users used for NDCG: 943
# RMSE: 0.9487, Normalized: 0.8441, NDCG@3: 0.8747
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 5}
# svd 50 1000 random 5
# Explained variance: 0.35976834854551915
# Number of users used for NDCG: 943
# RMSE: 0.9475, Normalized: 0.8430, NDCG@3: 0.8739
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 10}
# svd 50 1000 random 10
# Explained variance: 0.3620278569501712
# Number of users used for NDCG: 943
# RMSE: 0.9472, Normalized: 0.8428, NDCG@3: 0.8742
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 15}
# svd 50 1000 random 15
# Explained variance: 0.36244412220407746
# Number of users used for NDCG: 943
# RMSE: 0.9472, Normalized: 0.8427, NDCG@3: 0.8732
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 1}
# svd 100 1000 random 1
# Explained variance: 0.5036379434628313
# Number of users used for NDCG: 943
# RMSE: 0.9570, Normalized: 0.8515, NDCG@3: 0.8675
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 3}
# svd 100 1000 random 3
# Explained variance: 0.5423499051599858
# Number of users used for NDCG: 943
# RMSE: 0.9549, Normalized: 0.8496, NDCG@3: 0.8708
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 5}
# svd 100 1000 random 5
# Explained variance: 0.5484254114647285
# Number of users used for NDCG: 943
# RMSE: 0.9547, Normalized: 0.8494, NDCG@3: 0.8707
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 10}
# svd 100 1000 random 10
# Explained variance: 0.550874648128984
# Number of users used for NDCG: 943
# RMSE: 0.9546, Normalized: 0.8493, NDCG@3: 0.8710
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 15}
# svd 100 1000 random 15
# Explained variance: 0.5512066517437593
# Number of users used for NDCG: 943
# RMSE: 0.9544, Normalized: 0.8492, NDCG@3: 0.8707
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 1}
# svd 124 1000 random 1
# Explained variance: 0.5742802749105441
# Number of users used for NDCG: 943
# RMSE: 0.9585, Normalized: 0.8528, NDCG@3: 0.8669
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 3}
# svd 124 1000 random 3
# Explained variance: 0.6107636682715949
# Number of users used for NDCG: 943
# RMSE: 0.9576, Normalized: 0.8520, NDCG@3: 0.8697
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 5}
# svd 124 1000 random 5
# Explained variance: 0.6159805508001871
# Number of users used for NDCG: 943
# RMSE: 0.9572, Normalized: 0.8517, NDCG@3: 0.8694
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 10}
# svd 124 1000 random 10
# Explained variance: 0.6181962543719399
# Number of users used for NDCG: 943
# RMSE: 0.9569, Normalized: 0.8514, NDCG@3: 0.8686
# Testing parameters: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 15}
# svd 124 1000 random 15
# Explained variance: 0.6184945401498525
# Number of users used for NDCG: 943
# RMSE: 0.9568, Normalized: 0.8513, NDCG@3: 0.8679
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1}
# svd 2 2000 random 1
# Explained variance: 0.03725716727248565
# Number of users used for NDCG: 943
# RMSE: 0.9502, Normalized: 0.8454, NDCG@3: 0.8684
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 3}
# svd 2 2000 random 3
# Explained variance: 0.04093235268294894
# Number of users used for NDCG: 943
# RMSE: 0.9477, Normalized: 0.8432, NDCG@3: 0.8697
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 5}
# svd 2 2000 random 5
# Explained variance: 0.04097635057109182
# Number of users used for NDCG: 943
# RMSE: 0.9476, Normalized: 0.8432, NDCG@3: 0.8697
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 10}
# svd 2 2000 random 10
# Explained variance: 0.040976711448988776
# Number of users used for NDCG: 943
# RMSE: 0.9476, Normalized: 0.8432, NDCG@3: 0.8698
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 15}
# svd 2 2000 random 15
# Explained variance: 0.04097670398686692
# Number of users used for NDCG: 943
# RMSE: 0.9476, Normalized: 0.8432, NDCG@3: 0.8698
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 1}
# svd 5 2000 random 1
# Explained variance: 0.06636710931884629
# Number of users used for NDCG: 943
# RMSE: 0.9467, Normalized: 0.8424, NDCG@3: 0.8704
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 3}
# svd 5 2000 random 3
# Explained variance: 0.07704338260072173
# Number of users used for NDCG: 943
# RMSE: 0.9416, Normalized: 0.8378, NDCG@3: 0.8696
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 5}
# svd 5 2000 random 5
# Explained variance: 0.07796271331476005
# Number of users used for NDCG: 943
# RMSE: 0.9415, Normalized: 0.8377, NDCG@3: 0.8700
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 10}
# svd 5 2000 random 10
# Explained variance: 0.07807202351302335
# Number of users used for NDCG: 943
# RMSE: 0.9416, Normalized: 0.8378, NDCG@3: 0.8702
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 15}
# svd 5 2000 random 15
# Explained variance: 0.0780728707120582
# Number of users used for NDCG: 943
# RMSE: 0.9416, Normalized: 0.8378, NDCG@3: 0.8701
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 1}
# svd 10 2000 random 1
# Explained variance: 0.10666159316732077
# Number of users used for NDCG: 943
# RMSE: 0.9481, Normalized: 0.8436, NDCG@3: 0.8678
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 3}
# svd 10 2000 random 3
# Explained variance: 0.12126824923987768
# Number of users used for NDCG: 943
# RMSE: 0.9408, Normalized: 0.8370, NDCG@3: 0.8740
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 5}
# svd 10 2000 random 5
# Explained variance: 0.12307247436998664
# Number of users used for NDCG: 943
# RMSE: 0.9396, Normalized: 0.8360, NDCG@3: 0.8744
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 10}
# svd 10 2000 random 10
# Explained variance: 0.12401492978673109
# Number of users used for NDCG: 943
# RMSE: 0.9389, Normalized: 0.8354, NDCG@3: 0.8730
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 15}
# svd 10 2000 random 15
# Explained variance: 0.12407299675725517
# Number of users used for NDCG: 943
# RMSE: 0.9388, Normalized: 0.8353, NDCG@3: 0.8730
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 1}
# svd 20 2000 random 1
# Explained variance: 0.1709063026228192
# Number of users used for NDCG: 943
# RMSE: 0.9474, Normalized: 0.8430, NDCG@3: 0.8717
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 3}
# svd 20 2000 random 3
# Explained variance: 0.19341485481269668
# Number of users used for NDCG: 943
# RMSE: 0.9424, Normalized: 0.8385, NDCG@3: 0.8719
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 5}
# svd 20 2000 random 5
# Explained variance: 0.1962950481055234
# Number of users used for NDCG: 943
# RMSE: 0.9415, Normalized: 0.8377, NDCG@3: 0.8719
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 10}
# svd 20 2000 random 10
# Explained variance: 0.19735701631874508
# Number of users used for NDCG: 943
# RMSE: 0.9409, Normalized: 0.8372, NDCG@3: 0.8724
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 15}
# svd 20 2000 random 15
# Explained variance: 0.19748826786082718
# Number of users used for NDCG: 943
# RMSE: 0.9407, Normalized: 0.8370, NDCG@3: 0.8727
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 1}
# svd 50 2000 random 1
# Explained variance: 0.32075390280730487
# Number of users used for NDCG: 943
# RMSE: 0.9534, Normalized: 0.8483, NDCG@3: 0.8707
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 3}
# svd 50 2000 random 3
# Explained variance: 0.3544103797230811
# Number of users used for NDCG: 943
# RMSE: 0.9487, Normalized: 0.8441, NDCG@3: 0.8747
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 5}
# svd 50 2000 random 5
# Explained variance: 0.35976834854551915
# Number of users used for NDCG: 943
# RMSE: 0.9475, Normalized: 0.8430, NDCG@3: 0.8739
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 10}
# svd 50 2000 random 10
# Explained variance: 0.3620278569501712
# Number of users used for NDCG: 943
# RMSE: 0.9472, Normalized: 0.8428, NDCG@3: 0.8742
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 15}
# svd 50 2000 random 15
# Explained variance: 0.36244412220407746
# Number of users used for NDCG: 943
# RMSE: 0.9472, Normalized: 0.8427, NDCG@3: 0.8732
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 1}
# svd 100 2000 random 1
# Explained variance: 0.5036379434628313
# Number of users used for NDCG: 943
# RMSE: 0.9570, Normalized: 0.8515, NDCG@3: 0.8675
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 3}
# svd 100 2000 random 3
# Explained variance: 0.5423499051599858
# Number of users used for NDCG: 943
# RMSE: 0.9549, Normalized: 0.8496, NDCG@3: 0.8708
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 5}
# svd 100 2000 random 5
# Explained variance: 0.5484254114647285
# Number of users used for NDCG: 943
# RMSE: 0.9547, Normalized: 0.8494, NDCG@3: 0.8707
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 10}
# svd 100 2000 random 10
# Explained variance: 0.550874648128984
# Number of users used for NDCG: 943
# RMSE: 0.9546, Normalized: 0.8493, NDCG@3: 0.8710
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 15}
# svd 100 2000 random 15
# Explained variance: 0.5512066517437593
# Number of users used for NDCG: 943
# RMSE: 0.9544, Normalized: 0.8492, NDCG@3: 0.8707
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 1}
# svd 124 2000 random 1
# Explained variance: 0.5742802749105441
# Number of users used for NDCG: 943
# RMSE: 0.9585, Normalized: 0.8528, NDCG@3: 0.8669
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 3}
# svd 124 2000 random 3
# Explained variance: 0.6107636682715949
# Number of users used for NDCG: 943
# RMSE: 0.9576, Normalized: 0.8520, NDCG@3: 0.8697
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 5}
# svd 124 2000 random 5
# Explained variance: 0.6159805508001871
# Number of users used for NDCG: 943
# RMSE: 0.9572, Normalized: 0.8517, NDCG@3: 0.8694
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 10}
# svd 124 2000 random 10
# Explained variance: 0.6181962543719399
# Number of users used for NDCG: 943
# RMSE: 0.9569, Normalized: 0.8514, NDCG@3: 0.8686
# Testing parameters: {'init': 'random', 'max_iter': 2000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 15}
# svd 124 2000 random 15
# Explained variance: 0.6184945401498525
# Number of users used for NDCG: 943
# RMSE: 0.9568, Normalized: 0.8513, NDCG@3: 0.8679
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 1}
# svd 2 3000 random 1
# Explained variance: 0.03725716727248565
# Number of users used for NDCG: 943
# RMSE: 0.9502, Normalized: 0.8454, NDCG@3: 0.8684
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 3}
# svd 2 3000 random 3
# Explained variance: 0.04093235268294894
# Number of users used for NDCG: 943
# RMSE: 0.9477, Normalized: 0.8432, NDCG@3: 0.8697
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 5}
# svd 2 3000 random 5
# Explained variance: 0.04097635057109182
# Number of users used for NDCG: 943
# RMSE: 0.9476, Normalized: 0.8432, NDCG@3: 0.8697
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 10}
# svd 2 3000 random 10
# Explained variance: 0.040976711448988776
# Number of users used for NDCG: 943
# RMSE: 0.9476, Normalized: 0.8432, NDCG@3: 0.8698
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 15}
# svd 2 3000 random 15
# Explained variance: 0.04097670398686692
# Number of users used for NDCG: 943
# RMSE: 0.9476, Normalized: 0.8432, NDCG@3: 0.8698
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 1}
# svd 5 3000 random 1
# Explained variance: 0.06636710931884629
# Number of users used for NDCG: 943
# RMSE: 0.9467, Normalized: 0.8424, NDCG@3: 0.8704
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 3}
# svd 5 3000 random 3
# Explained variance: 0.07704338260072173
# Number of users used for NDCG: 943
# RMSE: 0.9416, Normalized: 0.8378, NDCG@3: 0.8696
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 5}
# svd 5 3000 random 5
# Explained variance: 0.07796271331476005
# Number of users used for NDCG: 943
# RMSE: 0.9415, Normalized: 0.8377, NDCG@3: 0.8700
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 10}
# svd 5 3000 random 10
# Explained variance: 0.07807202351302335
# Number of users used for NDCG: 943
# RMSE: 0.9416, Normalized: 0.8378, NDCG@3: 0.8702
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 5, 'n_iter': 15}
# svd 5 3000 random 15
# Explained variance: 0.0780728707120582
# Number of users used for NDCG: 943
# RMSE: 0.9416, Normalized: 0.8378, NDCG@3: 0.8701
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 1}
# svd 10 3000 random 1
# Explained variance: 0.10666159316732077
# Number of users used for NDCG: 943
# RMSE: 0.9481, Normalized: 0.8436, NDCG@3: 0.8678
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 3}
# svd 10 3000 random 3
# Explained variance: 0.12126824923987768
# Number of users used for NDCG: 943
# RMSE: 0.9408, Normalized: 0.8370, NDCG@3: 0.8740
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 5}
# svd 10 3000 random 5
# Explained variance: 0.12307247436998664
# Number of users used for NDCG: 943
# RMSE: 0.9396, Normalized: 0.8360, NDCG@3: 0.8744
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 10}
# svd 10 3000 random 10
# Explained variance: 0.12401492978673109
# Number of users used for NDCG: 943
# RMSE: 0.9389, Normalized: 0.8354, NDCG@3: 0.8730
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 15}
# svd 10 3000 random 15
# Explained variance: 0.12407299675725517
# Number of users used for NDCG: 943
# RMSE: 0.9388, Normalized: 0.8353, NDCG@3: 0.8730
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 1}
# svd 20 3000 random 1
# Explained variance: 0.1709063026228192
# Number of users used for NDCG: 943
# RMSE: 0.9474, Normalized: 0.8430, NDCG@3: 0.8717
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 3}
# svd 20 3000 random 3
# Explained variance: 0.19341485481269668
# Number of users used for NDCG: 943
# RMSE: 0.9424, Normalized: 0.8385, NDCG@3: 0.8719
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 5}
# svd 20 3000 random 5
# Explained variance: 0.1962950481055234
# Number of users used for NDCG: 943
# RMSE: 0.9415, Normalized: 0.8377, NDCG@3: 0.8719
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 10}
# svd 20 3000 random 10
# Explained variance: 0.19735701631874508
# Number of users used for NDCG: 943
# RMSE: 0.9409, Normalized: 0.8372, NDCG@3: 0.8724
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 20, 'n_iter': 15}
# svd 20 3000 random 15
# Explained variance: 0.19748826786082718
# Number of users used for NDCG: 943
# RMSE: 0.9407, Normalized: 0.8370, NDCG@3: 0.8727
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 1}
# svd 50 3000 random 1
# Explained variance: 0.32075390280730487
# Number of users used for NDCG: 943
# RMSE: 0.9534, Normalized: 0.8483, NDCG@3: 0.8707
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 3}
# svd 50 3000 random 3
# Explained variance: 0.3544103797230811
# Number of users used for NDCG: 943
# RMSE: 0.9487, Normalized: 0.8441, NDCG@3: 0.8747
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 5}
# svd 50 3000 random 5
# Explained variance: 0.35976834854551915
# Number of users used for NDCG: 943
# RMSE: 0.9475, Normalized: 0.8430, NDCG@3: 0.8739
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 10}
# svd 50 3000 random 10
# Explained variance: 0.3620278569501712
# Number of users used for NDCG: 943
# RMSE: 0.9472, Normalized: 0.8428, NDCG@3: 0.8742
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 50, 'n_iter': 15}
# svd 50 3000 random 15
# Explained variance: 0.36244412220407746
# Number of users used for NDCG: 943
# RMSE: 0.9472, Normalized: 0.8427, NDCG@3: 0.8732
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 1}
# svd 100 3000 random 1
# Explained variance: 0.5036379434628313
# Number of users used for NDCG: 943
# RMSE: 0.9570, Normalized: 0.8515, NDCG@3: 0.8675
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 3}
# svd 100 3000 random 3
# Explained variance: 0.5423499051599858
# Number of users used for NDCG: 943
# RMSE: 0.9549, Normalized: 0.8496, NDCG@3: 0.8708
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 5}
# svd 100 3000 random 5
# Explained variance: 0.5484254114647285
# Number of users used for NDCG: 943
# RMSE: 0.9547, Normalized: 0.8494, NDCG@3: 0.8707
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 10}
# svd 100 3000 random 10
# Explained variance: 0.550874648128984
# Number of users used for NDCG: 943
# RMSE: 0.9546, Normalized: 0.8493, NDCG@3: 0.8710
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 100, 'n_iter': 15}
# svd 100 3000 random 15
# Explained variance: 0.5512066517437593
# Number of users used for NDCG: 943
# RMSE: 0.9544, Normalized: 0.8492, NDCG@3: 0.8707
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 1}
# svd 124 3000 random 1
# Explained variance: 0.5742802749105441
# Number of users used for NDCG: 943
# RMSE: 0.9585, Normalized: 0.8528, NDCG@3: 0.8669
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 3}
# svd 124 3000 random 3
# Explained variance: 0.6107636682715949
# Number of users used for NDCG: 943
# RMSE: 0.9576, Normalized: 0.8520, NDCG@3: 0.8697
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 5}
# svd 124 3000 random 5
# Explained variance: 0.6159805508001871
# Number of users used for NDCG: 943
# RMSE: 0.9572, Normalized: 0.8517, NDCG@3: 0.8694
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 10}
# svd 124 3000 random 10
# Explained variance: 0.6181962543719399
# Number of users used for NDCG: 943
# RMSE: 0.9569, Normalized: 0.8514, NDCG@3: 0.8686
# Testing parameters: {'init': 'random', 'max_iter': 3000, 'model_type': 'svd', 'n_components': 124, 'n_iter': 15}
# svd 124 3000 random 15
# Explained variance: 0.6184945401498525
# Number of users used for NDCG: 943
# RMSE: 0.9568, Normalized: 0.8513, NDCG@3: 0.8679
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 15}
# ✅ Best RMSE on TEST: 0.9388, NDCG@3: 0.8730 (len:943), normalized RMSE: 0.9388
#
# 📈 Explained Variance (for best SVD only): 0.12407299675725517
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None

# %%
cm, acc, pre, rec, f1s = plot_confusion_matrix_ratings(R_test, R_estimated)
# Out:
# Test size: 20357
# Accuracy: 0.4224
# Precision (macro): 0.3855
# Recall (macro): 0.2713
# F1 Score (macro): 0.2783

# %%
best_metrics = grid_search_mf_bias_loou_ndcg(df_mf_ml, best_param)
# Out:
# (100000, 3)
# (100000, 3)
#
# === Testing params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 15} ===
#   Left-out user 1: NDCG@10=0.0000, n_test_items=272
#   Left-out user 2: NDCG@10=0.0000, n_test_items=62
#   Left-out user 3: NDCG@10=0.0000, n_test_items=54
#   Left-out user 4: NDCG@10=0.0000, n_test_items=24
#   Left-out user 5: NDCG@10=0.0000, n_test_items=175
#   Left-out user 6: NDCG@10=0.0000, n_test_items=211
#   Left-out user 7: NDCG@10=0.0000, n_test_items=403
#   Left-out user 8: NDCG@10=0.0000, n_test_items=59
#   Left-out user 9: NDCG@10=0.0000, n_test_items=22
#   Left-out user 10: NDCG@10=0.0000, n_test_items=184
#   Left-out user 11: NDCG@10=0.0000, n_test_items=181
#   Left-out user 12: NDCG@10=0.0000, n_test_items=51
#   Left-out user 13: NDCG@10=0.0000, n_test_items=636
#   Left-out user 14: NDCG@10=0.0000, n_test_items=98
#   Left-out user 15: NDCG@10=0.0000, n_test_items=104
#   Left-out user 16: NDCG@10=0.0000, n_test_items=140
#   Left-out user 17: NDCG@10=0.0000, n_test_items=28
#   Left-out user 18: NDCG@10=0.0000, n_test_items=277
#   Left-out user 19: NDCG@10=0.0000, n_test_items=20
#   Left-out user 20: NDCG@10=0.0000, n_test_items=48
#   Left-out user 21: NDCG@10=0.0000, n_test_items=179
#   Left-out user 22: NDCG@10=0.0000, n_test_items=128
#   Left-out user 23: NDCG@10=0.0000, n_test_items=151
#   Left-out user 24: NDCG@10=0.0000, n_test_items=68
#   Left-out user 25: NDCG@10=0.0000, n_test_items=78
#   Left-out user 26: NDCG@10=0.0000, n_test_items=107
#   Left-out user 27: NDCG@10=0.0000, n_test_items=25
#   Left-out user 28: NDCG@10=0.0000, n_test_items=79
#   Left-out user 29: NDCG@10=0.0000, n_test_items=34
#   Left-out user 30: NDCG@10=0.0000, n_test_items=43
#   Left-out user 31: NDCG@10=0.0000, n_test_items=36
#   Left-out user 32: NDCG@10=0.0000, n_test_items=41
#   Left-out user 33: NDCG@10=0.0000, n_test_items=24
#   Left-out user 34: NDCG@10=0.0000, n_test_items=20
#   Left-out user 35: NDCG@10=0.0000, n_test_items=25
#   Left-out user 36: NDCG@10=0.0000, n_test_items=20
#   Left-out user 37: NDCG@10=0.0000, n_test_items=57
#   Left-out user 38: NDCG@10=0.0000, n_test_items=121
#   Left-out user 39: NDCG@10=0.0000, n_test_items=22
#   Left-out user 40: NDCG@10=0.0000, n_test_items=35
#   Left-out user 41: NDCG@10=0.0000, n_test_items=52
#   Left-out user 42: NDCG@10=0.0000, n_test_items=183
#   Left-out user 43: NDCG@10=0.0000, n_test_items=221
#   Left-out user 44: NDCG@10=0.0000, n_test_items=151
#   Left-out user 45: NDCG@10=0.0000, n_test_items=48
#   Left-out user 46: NDCG@10=0.0000, n_test_items=27
#   Left-out user 47: NDCG@10=0.0000, n_test_items=25
#   Left-out user 48: NDCG@10=0.0000, n_test_items=66
#   Left-out user 49: NDCG@10=0.0000, n_test_items=215
#   Left-out user 50: NDCG@10=0.0000, n_test_items=24
#   Left-out user 51: NDCG@10=0.0000, n_test_items=23
#   Left-out user 52: NDCG@10=0.0000, n_test_items=56
#   Left-out user 53: NDCG@10=0.0000, n_test_items=28
#   Left-out user 54: NDCG@10=0.0000, n_test_items=65
#   Left-out user 55: NDCG@10=0.0000, n_test_items=21
#   Left-out user 56: NDCG@10=0.0000, n_test_items=187
#   Left-out user 57: NDCG@10=0.0000, n_test_items=106
#   Left-out user 58: NDCG@10=0.0000, n_test_items=154
#   Left-out user 59: NDCG@10=0.0000, n_test_items=382
#   Left-out user 60: NDCG@10=0.0000, n_test_items=208
#   Left-out user 61: NDCG@10=0.0000, n_test_items=21
#   Left-out user 62: NDCG@10=0.0000, n_test_items=232
#   Left-out user 63: NDCG@10=0.0000, n_test_items=93
#   Left-out user 64: NDCG@10=0.0000, n_test_items=200
#   Left-out user 65: NDCG@10=0.0000, n_test_items=80
#   Left-out user 66: NDCG@10=0.0000, n_test_items=38
#   Left-out user 67: NDCG@10=0.0000, n_test_items=30
#   Left-out user 68: NDCG@10=0.0000, n_test_items=34
#   Left-out user 69: NDCG@10=0.0000, n_test_items=65
#   Left-out user 70: NDCG@10=0.0000, n_test_items=131
#   Left-out user 71: NDCG@10=0.0000, n_test_items=38
#   Left-out user 72: NDCG@10=0.0000, n_test_items=137
#   Left-out user 73: NDCG@10=0.0000, n_test_items=66
#   Left-out user 74: NDCG@10=0.0000, n_test_items=39
#   Left-out user 75: NDCG@10=0.0000, n_test_items=79
#   Left-out user 76: NDCG@10=0.0000, n_test_items=82
#   Left-out user 77: NDCG@10=0.0000, n_test_items=72
#   Left-out user 78: NDCG@10=0.0000, n_test_items=21
#   Left-out user 79: NDCG@10=0.0000, n_test_items=55
#   Left-out user 80: NDCG@10=0.0000, n_test_items=29
#   Left-out user 81: NDCG@10=0.0000, n_test_items=58
#   Left-out user 82: NDCG@10=0.0000, n_test_items=168
#   Left-out user 83: NDCG@10=0.0000, n_test_items=155
#   Left-out user 84: NDCG@10=0.0000, n_test_items=68
#   Left-out user 85: NDCG@10=0.0000, n_test_items=288
#   Left-out user 86: NDCG@10=0.0000, n_test_items=23
#   Left-out user 87: NDCG@10=0.1000, n_test_items=211
#   Left-out user 88: NDCG@10=0.0000, n_test_items=21
#   Left-out user 89: NDCG@10=0.0000, n_test_items=76
#   Left-out user 90: NDCG@10=0.0000, n_test_items=300
#   Left-out user 91: NDCG@10=0.0000, n_test_items=98
#   Left-out user 92: NDCG@10=0.0000, n_test_items=388
#   Left-out user 93: NDCG@10=0.0000, n_test_items=20
#   Left-out user 94: NDCG@10=0.0000, n_test_items=400
#   Left-out user 95: NDCG@10=0.0000, n_test_items=278
#   Left-out user 96: NDCG@10=0.0000, n_test_items=56
#   Left-out user 97: NDCG@10=0.0000, n_test_items=63
#   Left-out user 98: NDCG@10=0.0000, n_test_items=27
#   Left-out user 99: NDCG@10=0.0000, n_test_items=136
#   Left-out user 100: NDCG@10=0.0000, n_test_items=59
#   Left-out user 101: NDCG@10=0.0000, n_test_items=67
#   Left-out user 102: NDCG@10=0.0000, n_test_items=216
#   Left-out user 103: NDCG@10=0.0000, n_test_items=29
#   Left-out user 104: NDCG@10=0.0000, n_test_items=111
#   Left-out user 105: NDCG@10=0.0000, n_test_items=23
#   Left-out user 106: NDCG@10=0.0000, n_test_items=64
#   Left-out user 107: NDCG@10=0.0000, n_test_items=22
#   Left-out user 108: NDCG@10=0.0000, n_test_items=33
#   Left-out user 109: NDCG@10=0.0000, n_test_items=234
#   Left-out user 110: NDCG@10=0.0000, n_test_items=133
#   Left-out user 111: NDCG@10=0.0000, n_test_items=24
#   Left-out user 112: NDCG@10=0.0000, n_test_items=46
#   Left-out user 113: NDCG@10=0.0000, n_test_items=51
#   Left-out user 114: NDCG@10=0.0000, n_test_items=48
#   Left-out user 115: NDCG@10=0.0000, n_test_items=92
#   Left-out user 116: NDCG@10=0.0000, n_test_items=143
#   Left-out user 117: NDCG@10=0.0000, n_test_items=86
#   Left-out user 118: NDCG@10=0.0000, n_test_items=71
#   Left-out user 119: NDCG@10=0.0000, n_test_items=181
#   Left-out user 120: NDCG@10=0.0000, n_test_items=26
#   Left-out user 121: NDCG@10=0.0000, n_test_items=74
#   Left-out user 122: NDCG@10=0.0000, n_test_items=61
#   Left-out user 123: NDCG@10=0.0000, n_test_items=54
#   Left-out user 124: NDCG@10=0.0000, n_test_items=24
#   Left-out user 125: NDCG@10=0.0000, n_test_items=182
#   Left-out user 126: NDCG@10=0.0000, n_test_items=45
#   Left-out user 127: NDCG@10=0.0000, n_test_items=23
#   Left-out user 128: NDCG@10=0.0000, n_test_items=184
#   Left-out user 129: NDCG@10=0.0000, n_test_items=30
#   Left-out user 130: NDCG@10=0.0000, n_test_items=353
#   Left-out user 131: NDCG@10=0.0000, n_test_items=30
#   Left-out user 132: NDCG@10=0.0000, n_test_items=22
#   Left-out user 133: NDCG@10=0.0000, n_test_items=26
#   Left-out user 134: NDCG@10=0.0000, n_test_items=25
#   Left-out user 135: NDCG@10=0.0000, n_test_items=55
#   Left-out user 136: NDCG@10=0.0000, n_test_items=35
#   Left-out user 137: NDCG@10=0.0000, n_test_items=47
#   Left-out user 138: NDCG@10=0.0000, n_test_items=51
#   Left-out user 139: NDCG@10=0.0000, n_test_items=24
#   Left-out user 140: NDCG@10=0.0000, n_test_items=21
#   Left-out user 141: NDCG@10=0.0000, n_test_items=107
#   Left-out user 142: NDCG@10=0.0000, n_test_items=33
#   Left-out user 143: NDCG@10=0.0000, n_test_items=20
#   Left-out user 144: NDCG@10=0.0000, n_test_items=206
#   Left-out user 145: NDCG@10=0.0000, n_test_items=316
#   Left-out user 146: NDCG@10=0.1042, n_test_items=29
#   Left-out user 147: NDCG@10=0.0000, n_test_items=20
#   Left-out user 148: NDCG@10=0.0000, n_test_items=65
#   Left-out user 149: NDCG@10=0.0000, n_test_items=36
#   Left-out user 150: NDCG@10=0.0000, n_test_items=32
#   Left-out user 151: NDCG@10=0.0000, n_test_items=307
#   Left-out user 152: NDCG@10=0.0000, n_test_items=106
#   Left-out user 153: NDCG@10=0.0000, n_test_items=23
#   Left-out user 154: NDCG@10=0.0000, n_test_items=51
#   Left-out user 155: NDCG@10=0.0000, n_test_items=22
#   Left-out user 156: NDCG@10=0.0000, n_test_items=37
#   Left-out user 157: NDCG@10=0.0000, n_test_items=51
#   Left-out user 158: NDCG@10=0.0000, n_test_items=173
#   Left-out user 159: NDCG@10=0.0000, n_test_items=107
#   Left-out user 160: NDCG@10=0.0000, n_test_items=120
#   Left-out user 161: NDCG@10=0.0000, n_test_items=58
#   Left-out user 162: NDCG@10=0.0000, n_test_items=42
#   Left-out user 163: NDCG@10=0.0000, n_test_items=23
#   Left-out user 164: NDCG@10=0.0000, n_test_items=63
#   Left-out user 165: NDCG@10=0.0000, n_test_items=30
#   Left-out user 166: NDCG@10=0.0000, n_test_items=20
#   Left-out user 167: NDCG@10=0.0000, n_test_items=69
#   Left-out user 168: NDCG@10=0.0000, n_test_items=69
#   Left-out user 169: NDCG@10=0.0000, n_test_items=37
#   Left-out user 170: NDCG@10=0.0000, n_test_items=22
#   Left-out user 171: NDCG@10=0.0000, n_test_items=28
#   Left-out user 172: NDCG@10=0.0000, n_test_items=27
#   Left-out user 173: NDCG@10=0.0000, n_test_items=43
#   Left-out user 174: NDCG@10=0.0000, n_test_items=177
#   Left-out user 175: NDCG@10=0.0000, n_test_items=38
#   Left-out user 176: NDCG@10=0.0000, n_test_items=63
#   Left-out user 177: NDCG@10=0.0000, n_test_items=115
#   Left-out user 178: NDCG@10=0.0000, n_test_items=273
#   Left-out user 179: NDCG@10=0.0000, n_test_items=42
#   Left-out user 180: NDCG@10=0.0000, n_test_items=63
#   Left-out user 181: NDCG@10=0.0209, n_test_items=435
#   Left-out user 182: NDCG@10=0.0000, n_test_items=28
#   Left-out user 183: NDCG@10=0.0000, n_test_items=53
#   Left-out user 184: NDCG@10=0.0000, n_test_items=251
#   Left-out user 185: NDCG@10=0.0000, n_test_items=48
#   Left-out user 186: NDCG@10=0.0000, n_test_items=92
#   Left-out user 187: NDCG@10=0.0000, n_test_items=56
#   Left-out user 188: NDCG@10=0.0000, n_test_items=112
#   Left-out user 189: NDCG@10=0.0000, n_test_items=187
#   Left-out user 190: NDCG@10=0.0000, n_test_items=59
#   Left-out user 191: NDCG@10=0.0000, n_test_items=27
#   Left-out user 192: NDCG@10=0.0000, n_test_items=35
#   Left-out user 193: NDCG@10=0.0000, n_test_items=121
#   Left-out user 194: NDCG@10=0.0000, n_test_items=305
#   Left-out user 195: NDCG@10=0.0000, n_test_items=96
#   Left-out user 196: NDCG@10=0.0000, n_test_items=39
#   Left-out user 197: NDCG@10=0.0000, n_test_items=118
#   Left-out user 198: NDCG@10=0.0000, n_test_items=181
#   Left-out user 199: NDCG@10=0.0000, n_test_items=40
#   Left-out user 200: NDCG@10=0.0000, n_test_items=216
#   Left-out user 201: NDCG@10=0.0727, n_test_items=386
#   Left-out user 202: NDCG@10=0.0000, n_test_items=20
#   Left-out user 203: NDCG@10=0.0000, n_test_items=43
#   Left-out user 204: NDCG@10=0.0000, n_test_items=42
#   Left-out user 205: NDCG@10=0.0000, n_test_items=22
#   Left-out user 206: NDCG@10=0.0000, n_test_items=64
#   Left-out user 207: NDCG@10=0.0000, n_test_items=230
#   Left-out user 208: NDCG@10=0.0000, n_test_items=33
#   Left-out user 209: NDCG@10=0.0000, n_test_items=33
#   Left-out user 210: NDCG@10=0.0000, n_test_items=132
#   Left-out user 211: NDCG@10=0.0000, n_test_items=37
#   Left-out user 212: NDCG@10=0.0000, n_test_items=25
#   Left-out user 213: NDCG@10=0.0000, n_test_items=126
#   Left-out user 214: NDCG@10=0.0000, n_test_items=128
#   Left-out user 215: NDCG@10=0.0000, n_test_items=93
#   Left-out user 216: NDCG@10=0.0000, n_test_items=131
#   Left-out user 217: NDCG@10=0.0000, n_test_items=76
#   Left-out user 218: NDCG@10=0.0000, n_test_items=53
#   Left-out user 219: NDCG@10=0.0000, n_test_items=28
#   Left-out user 220: NDCG@10=0.0000, n_test_items=22
#   Left-out user 221: NDCG@10=0.0000, n_test_items=146
#   Left-out user 222: NDCG@10=0.0000, n_test_items=387
#   Left-out user 223: NDCG@10=0.0000, n_test_items=105
#   Left-out user 224: NDCG@10=0.0000, n_test_items=141
#   Left-out user 225: NDCG@10=0.0000, n_test_items=27
#   Left-out user 226: NDCG@10=0.0000, n_test_items=50
#   Left-out user 227: NDCG@10=0.0000, n_test_items=58
#   Left-out user 228: NDCG@10=0.0000, n_test_items=21
#   Left-out user 229: NDCG@10=0.0000, n_test_items=30
#   Left-out user 230: NDCG@10=0.0000, n_test_items=133
#   Left-out user 231: NDCG@10=0.0000, n_test_items=21
#   Left-out user 232: NDCG@10=0.0000, n_test_items=93
#   Left-out user 233: NDCG@10=0.0000, n_test_items=110
#   Left-out user 234: NDCG@10=0.1000, n_test_items=480
#   Left-out user 235: NDCG@10=0.0000, n_test_items=94
#   Left-out user 236: NDCG@10=0.0000, n_test_items=124
#   Left-out user 237: NDCG@10=0.0000, n_test_items=48
#   Left-out user 238: NDCG@10=0.0000, n_test_items=29
#   Left-out user 239: NDCG@10=0.0000, n_test_items=159
#   Left-out user 240: NDCG@10=0.0000, n_test_items=24
#   Left-out user 241: NDCG@10=0.0000, n_test_items=23
#   Left-out user 242: NDCG@10=0.0000, n_test_items=20
#   Left-out user 243: NDCG@10=0.0000, n_test_items=81
#   Left-out user 244: NDCG@10=0.1000, n_test_items=238
#   Left-out user 245: NDCG@10=0.0000, n_test_items=22
#   Left-out user 246: NDCG@10=0.0000, n_test_items=195
#   Left-out user 247: NDCG@10=0.0000, n_test_items=26
#   Left-out user 248: NDCG@10=0.0000, n_test_items=56
#   Left-out user 249: NDCG@10=0.0000, n_test_items=161
#   Left-out user 250: NDCG@10=0.0000, n_test_items=122
#   Left-out user 251: NDCG@10=0.0000, n_test_items=77
#   Left-out user 252: NDCG@10=0.0000, n_test_items=21
#   Left-out user 253: NDCG@10=0.0000, n_test_items=97
#   Left-out user 254: NDCG@10=0.0000, n_test_items=159
#   Left-out user 255: NDCG@10=0.0000, n_test_items=83
#   Left-out user 256: NDCG@10=0.0000, n_test_items=207
#   Left-out user 257: NDCG@10=0.0364, n_test_items=57
#   Left-out user 258: NDCG@10=0.0000, n_test_items=23
#   Left-out user 259: NDCG@10=0.0000, n_test_items=46
#   Left-out user 260: NDCG@10=0.0000, n_test_items=24
#   Left-out user 261: NDCG@10=0.0000, n_test_items=27
#   Left-out user 262: NDCG@10=0.0000, n_test_items=160
#   Left-out user 263: NDCG@10=0.0000, n_test_items=123
#   Left-out user 264: NDCG@10=0.0000, n_test_items=120
#   Left-out user 265: NDCG@10=0.0000, n_test_items=46
#   Left-out user 266: NDCG@10=0.0000, n_test_items=23
#   Left-out user 267: NDCG@10=0.0000, n_test_items=185
#   Left-out user 268: NDCG@10=0.0000, n_test_items=328
#   Left-out user 269: NDCG@10=0.0000, n_test_items=323
#   Left-out user 270: NDCG@10=0.0000, n_test_items=138
#   Left-out user 271: NDCG@10=0.0000, n_test_items=278
#   Left-out user 272: NDCG@10=0.0000, n_test_items=51
#   Left-out user 273: NDCG@10=0.0000, n_test_items=22
#   Left-out user 274: NDCG@10=0.0000, n_test_items=71
#   Left-out user 275: NDCG@10=0.0000, n_test_items=95
#   Left-out user 276: NDCG@10=0.0000, n_test_items=518
#   Left-out user 277: NDCG@10=0.0000, n_test_items=54
#   Left-out user 278: NDCG@10=0.0000, n_test_items=23
#   Left-out user 279: NDCG@10=0.1000, n_test_items=434
#   Left-out user 280: NDCG@10=0.0000, n_test_items=258
#   Left-out user 281: NDCG@10=0.0000, n_test_items=26
#   Left-out user 282: NDCG@10=0.0000, n_test_items=22
#   Left-out user 283: NDCG@10=0.0000, n_test_items=53
#   Left-out user 284: NDCG@10=0.0000, n_test_items=47
#   Left-out user 285: NDCG@10=0.0000, n_test_items=32
#   Left-out user 286: NDCG@10=0.0000, n_test_items=288
#   Left-out user 287: NDCG@10=0.0000, n_test_items=62
#   Left-out user 288: NDCG@10=0.0000, n_test_items=75
#   Left-out user 289: NDCG@10=0.0000, n_test_items=27
#   Left-out user 290: NDCG@10=0.0000, n_test_items=150
#   Left-out user 291: NDCG@10=0.0000, n_test_items=296
#   Left-out user 292: NDCG@10=0.0000, n_test_items=124
#   Left-out user 293: NDCG@10=0.0000, n_test_items=388
#   Left-out user 294: NDCG@10=0.0000, n_test_items=150
#   Left-out user 295: NDCG@10=0.0000, n_test_items=196
#   Left-out user 296: NDCG@10=0.0000, n_test_items=147
#   Left-out user 297: NDCG@10=0.0000, n_test_items=192
#   Left-out user 298: NDCG@10=0.0000, n_test_items=127
#   Left-out user 299: NDCG@10=0.0000, n_test_items=280
#   Left-out user 300: NDCG@10=0.0000, n_test_items=20
#   Left-out user 301: NDCG@10=0.0000, n_test_items=275
#   Left-out user 302: NDCG@10=0.0000, n_test_items=21
#   Left-out user 303: NDCG@10=0.0000, n_test_items=484
#   Left-out user 304: NDCG@10=0.0000, n_test_items=26
#   Left-out user 305: NDCG@10=0.0000, n_test_items=222
#   Left-out user 306: NDCG@10=0.0000, n_test_items=32
#   Left-out user 307: NDCG@10=0.0000, n_test_items=112
#   Left-out user 308: NDCG@10=0.0000, n_test_items=397
#   Left-out user 309: NDCG@10=0.0000, n_test_items=20
#   Left-out user 310: NDCG@10=0.0000, n_test_items=21
#   Left-out user 311: NDCG@10=0.0000, n_test_items=294
#   Left-out user 312: NDCG@10=0.0000, n_test_items=223
#   Left-out user 313: NDCG@10=0.0000, n_test_items=262
#   Left-out user 314: NDCG@10=0.0000, n_test_items=245
#   Left-out user 315: NDCG@10=0.0000, n_test_items=87
#   Left-out user 316: NDCG@10=0.0000, n_test_items=75
#   Left-out user 317: NDCG@10=0.0000, n_test_items=22
#   Left-out user 318: NDCG@10=0.0000, n_test_items=174
#   Left-out user 319: NDCG@10=0.0000, n_test_items=23
#   Left-out user 320: NDCG@10=0.0000, n_test_items=154
#   Left-out user 321: NDCG@10=0.0000, n_test_items=125
#   Left-out user 322: NDCG@10=0.0000, n_test_items=51
#   Left-out user 323: NDCG@10=0.0000, n_test_items=89
#   Left-out user 324: NDCG@10=0.0000, n_test_items=66
#   Left-out user 325: NDCG@10=0.0000, n_test_items=142
#   Left-out user 326: NDCG@10=0.0000, n_test_items=187
#   Left-out user 327: NDCG@10=0.0000, n_test_items=284
#   Left-out user 328: NDCG@10=0.0000, n_test_items=283
#   Left-out user 329: NDCG@10=0.0000, n_test_items=65
#   Left-out user 330: NDCG@10=0.0000, n_test_items=147
#   Left-out user 331: NDCG@10=0.0000, n_test_items=70
#   Left-out user 332: NDCG@10=0.0000, n_test_items=183
#   Left-out user 333: NDCG@10=0.0000, n_test_items=26
#   Left-out user 334: NDCG@10=0.0000, n_test_items=333
#   Left-out user 335: NDCG@10=0.0000, n_test_items=22
#   Left-out user 336: NDCG@10=0.0000, n_test_items=130
#   Left-out user 337: NDCG@10=0.0000, n_test_items=34
#   Left-out user 338: NDCG@10=0.0000, n_test_items=75
#   Left-out user 339: NDCG@10=0.0000, n_test_items=254
#   Left-out user 340: NDCG@10=0.0000, n_test_items=44
#   Left-out user 341: NDCG@10=0.0000, n_test_items=21
#   Left-out user 342: NDCG@10=0.0000, n_test_items=201
#   Left-out user 343: NDCG@10=0.0000, n_test_items=237
#   Left-out user 344: NDCG@10=0.0000, n_test_items=190
#   Left-out user 345: NDCG@10=0.0000, n_test_items=232
#   Left-out user 346: NDCG@10=0.0000, n_test_items=193
#   Left-out user 347: NDCG@10=0.0000, n_test_items=199
#   Left-out user 348: NDCG@10=0.0000, n_test_items=58
#   Left-out user 349: NDCG@10=0.0000, n_test_items=41
#   Left-out user 350: NDCG@10=0.0000, n_test_items=50
#   Left-out user 351: NDCG@10=0.0000, n_test_items=44
#   Left-out user 352: NDCG@10=0.0000, n_test_items=42
#   Left-out user 353: NDCG@10=0.0000, n_test_items=25
#   Left-out user 354: NDCG@10=0.0000, n_test_items=233
#   Left-out user 355: NDCG@10=0.0000, n_test_items=26
#   Left-out user 356: NDCG@10=0.0000, n_test_items=24
#   Left-out user 357: NDCG@10=0.0000, n_test_items=76
#   Left-out user 358: NDCG@10=0.0000, n_test_items=43
#   Left-out user 359: NDCG@10=0.0000, n_test_items=27
#   Left-out user 360: NDCG@10=0.0000, n_test_items=102
#   Left-out user 361: NDCG@10=0.0000, n_test_items=121
#   Left-out user 362: NDCG@10=0.0000, n_test_items=25
#   Left-out user 363: NDCG@10=0.0000, n_test_items=311
#   Left-out user 364: NDCG@10=0.0000, n_test_items=20
#   Left-out user 365: NDCG@10=0.0000, n_test_items=58
#   Left-out user 366: NDCG@10=0.0000, n_test_items=33
#   Left-out user 367: NDCG@10=0.0000, n_test_items=58
#   Left-out user 368: NDCG@10=0.0000, n_test_items=45
#   Left-out user 369: NDCG@10=0.0000, n_test_items=22
#   Left-out user 370: NDCG@10=0.0000, n_test_items=75
#   Left-out user 371: NDCG@10=0.0000, n_test_items=51
#   Left-out user 372: NDCG@10=0.0000, n_test_items=66
#   Left-out user 373: NDCG@10=0.0000, n_test_items=233
#   Left-out user 374: NDCG@10=0.0000, n_test_items=274
#   Left-out user 375: NDCG@10=0.0000, n_test_items=28
#   Left-out user 376: NDCG@10=0.0000, n_test_items=30
#   Left-out user 377: NDCG@10=0.0000, n_test_items=33
#   Left-out user 378: NDCG@10=0.0000, n_test_items=375
#   Left-out user 379: NDCG@10=0.0000, n_test_items=196
#   Left-out user 380: NDCG@10=0.0000, n_test_items=162
#   Left-out user 381: NDCG@10=0.0000, n_test_items=127
#   Left-out user 382: NDCG@10=0.0000, n_test_items=53
#   Left-out user 383: NDCG@10=0.0000, n_test_items=71
#   Left-out user 384: NDCG@10=0.0000, n_test_items=22
#   Left-out user 385: NDCG@10=0.0509, n_test_items=281
#   Left-out user 386: NDCG@10=0.0000, n_test_items=23
#   Left-out user 387: NDCG@10=0.0000, n_test_items=304
#   Left-out user 388: NDCG@10=0.0000, n_test_items=52
#   Left-out user 389: NDCG@10=0.0000, n_test_items=271
#   Left-out user 390: NDCG@10=0.0000, n_test_items=31
#   Left-out user 391: NDCG@10=0.0000, n_test_items=121
#   Left-out user 392: NDCG@10=0.0000, n_test_items=111
#   Left-out user 393: NDCG@10=0.0000, n_test_items=448
#   Left-out user 394: NDCG@10=0.0000, n_test_items=149
#   Left-out user 395: NDCG@10=0.0000, n_test_items=57
#   Left-out user 396: NDCG@10=0.0000, n_test_items=54
#   Left-out user 397: NDCG@10=0.0000, n_test_items=102
#   Left-out user 398: NDCG@10=0.0000, n_test_items=172
#   Left-out user 399: NDCG@10=0.0000, n_test_items=319
#   Left-out user 400: NDCG@10=0.0000, n_test_items=22
#   Left-out user 401: NDCG@10=0.0000, n_test_items=153
#   Left-out user 402: NDCG@10=0.0000, n_test_items=68
#   Left-out user 403: NDCG@10=0.0000, n_test_items=50
#   Left-out user 404: NDCG@10=0.0000, n_test_items=44
#   Left-out user 405: NDCG@10=0.0182, n_test_items=737
#   Left-out user 406: NDCG@10=0.0000, n_test_items=342
#   Left-out user 407: NDCG@10=0.0000, n_test_items=226
#   Left-out user 408: NDCG@10=0.0000, n_test_items=27
#   Left-out user 409: NDCG@10=0.0000, n_test_items=203
#   Left-out user 410: NDCG@10=0.0000, n_test_items=28
#   Left-out user 411: NDCG@10=0.0000, n_test_items=58
#   Left-out user 412: NDCG@10=0.0000, n_test_items=51
#   Left-out user 413: NDCG@10=0.0000, n_test_items=50
#   Left-out user 414: NDCG@10=0.0000, n_test_items=25
#   Left-out user 415: NDCG@10=0.0000, n_test_items=24
#   Left-out user 416: NDCG@10=0.1000, n_test_items=493
#   Left-out user 417: NDCG@10=0.0000, n_test_items=365
#   Left-out user 418: NDCG@10=0.0000, n_test_items=20
#   Left-out user 419: NDCG@10=0.0000, n_test_items=32
#   Left-out user 420: NDCG@10=0.0000, n_test_items=36
#   Left-out user 421: NDCG@10=0.0000, n_test_items=62
#   Left-out user 422: NDCG@10=0.0000, n_test_items=97
#   Left-out user 423: NDCG@10=0.0000, n_test_items=64
#   Left-out user 424: NDCG@10=0.0000, n_test_items=44
#   Left-out user 425: NDCG@10=0.0000, n_test_items=204
#   Left-out user 426: NDCG@10=0.0000, n_test_items=101
#   Left-out user 427: NDCG@10=0.0000, n_test_items=31
#   Left-out user 428: NDCG@10=0.0000, n_test_items=55
#   Left-out user 429: NDCG@10=0.0000, n_test_items=414
#   Left-out user 430: NDCG@10=0.0000, n_test_items=65
#   Left-out user 431: NDCG@10=0.0000, n_test_items=21
#   Left-out user 432: NDCG@10=0.0000, n_test_items=62
#   Left-out user 433: NDCG@10=0.0000, n_test_items=41
#   Left-out user 434: NDCG@10=0.0000, n_test_items=44
#   Left-out user 435: NDCG@10=0.0000, n_test_items=379
#   Left-out user 436: NDCG@10=0.0000, n_test_items=145
#   Left-out user 437: NDCG@10=0.0000, n_test_items=263
#   Left-out user 438: NDCG@10=0.0000, n_test_items=33
#   Left-out user 439: NDCG@10=0.0000, n_test_items=31
#   Left-out user 440: NDCG@10=0.0000, n_test_items=51
#   Left-out user 441: NDCG@10=0.0000, n_test_items=20
#   Left-out user 442: NDCG@10=0.0000, n_test_items=143
#   Left-out user 443: NDCG@10=0.0000, n_test_items=24
#   Left-out user 444: NDCG@10=0.0000, n_test_items=24
#   Left-out user 445: NDCG@10=0.0000, n_test_items=135
#   Left-out user 446: NDCG@10=0.0000, n_test_items=36
#   Left-out user 447: NDCG@10=0.0000, n_test_items=139
#   Left-out user 448: NDCG@10=0.0000, n_test_items=38
#   Left-out user 449: NDCG@10=0.0000, n_test_items=75
#   Left-out user 450: NDCG@10=0.0000, n_test_items=540
#   Left-out user 451: NDCG@10=0.0000, n_test_items=98
#   Left-out user 452: NDCG@10=0.0000, n_test_items=206
#   Left-out user 453: NDCG@10=0.0000, n_test_items=156
#   Left-out user 454: NDCG@10=0.0000, n_test_items=236
#   Left-out user 455: NDCG@10=0.0000, n_test_items=189
#   Left-out user 456: NDCG@10=0.0000, n_test_items=217
#   Left-out user 457: NDCG@10=0.0000, n_test_items=277
#   Left-out user 458: NDCG@10=0.0000, n_test_items=183
#   Left-out user 459: NDCG@10=0.0000, n_test_items=118
#   Left-out user 460: NDCG@10=0.0000, n_test_items=68
#   Left-out user 461: NDCG@10=0.0000, n_test_items=23
#   Left-out user 462: NDCG@10=0.0000, n_test_items=33
#   Left-out user 463: NDCG@10=0.0000, n_test_items=133
#   Left-out user 464: NDCG@10=0.0000, n_test_items=53
#   Left-out user 465: NDCG@10=0.0000, n_test_items=80
#   Left-out user 466: NDCG@10=0.0000, n_test_items=101
#   Left-out user 467: NDCG@10=0.0000, n_test_items=44
#   Left-out user 468: NDCG@10=0.0000, n_test_items=143
#   Left-out user 469: NDCG@10=0.0000, n_test_items=43
#   Left-out user 470: NDCG@10=0.0000, n_test_items=57
#   Left-out user 471: NDCG@10=0.0000, n_test_items=31
#   Left-out user 472: NDCG@10=0.0000, n_test_items=263
#   Left-out user 473: NDCG@10=0.0000, n_test_items=35
#   Left-out user 474: NDCG@10=0.0000, n_test_items=327
#   Left-out user 475: NDCG@10=0.0000, n_test_items=20
#   Left-out user 476: NDCG@10=0.0000, n_test_items=83
#   Left-out user 477: NDCG@10=0.0000, n_test_items=35
#   Left-out user 478: NDCG@10=0.0000, n_test_items=113
#   Left-out user 479: NDCG@10=0.0000, n_test_items=202
#   Left-out user 480: NDCG@10=0.0000, n_test_items=60
#   Left-out user 481: NDCG@10=0.0000, n_test_items=56
#   Left-out user 482: NDCG@10=0.0000, n_test_items=26
#   Left-out user 483: NDCG@10=0.0000, n_test_items=59
#   Left-out user 484: NDCG@10=0.0000, n_test_items=139
#   Left-out user 485: NDCG@10=0.0000, n_test_items=26
#   Left-out user 486: NDCG@10=0.0000, n_test_items=189
#   Left-out user 487: NDCG@10=0.0000, n_test_items=231
#   Left-out user 488: NDCG@10=0.0000, n_test_items=154
#   Left-out user 489: NDCG@10=0.1000, n_test_items=109
#   Left-out user 490: NDCG@10=0.0000, n_test_items=57
#   Left-out user 491: NDCG@10=0.0000, n_test_items=33
#   Left-out user 492: NDCG@10=0.0000, n_test_items=55
#   Left-out user 493: NDCG@10=0.0000, n_test_items=135
#   Left-out user 494: NDCG@10=0.0000, n_test_items=47
#   Left-out user 495: NDCG@10=0.0000, n_test_items=213
#   Left-out user 496: NDCG@10=0.0000, n_test_items=129
#   Left-out user 497: NDCG@10=0.0000, n_test_items=279
#   Left-out user 498: NDCG@10=0.0000, n_test_items=149
#   Left-out user 499: NDCG@10=0.0000, n_test_items=102
#   Left-out user 500: NDCG@10=0.0000, n_test_items=225
#   Left-out user 501: NDCG@10=0.0000, n_test_items=73
#   Left-out user 502: NDCG@10=0.0000, n_test_items=37
#   Left-out user 503: NDCG@10=0.0000, n_test_items=160
#   Left-out user 504: NDCG@10=0.0000, n_test_items=251
#   Left-out user 505: NDCG@10=0.0000, n_test_items=112
#   Left-out user 506: NDCG@10=0.0000, n_test_items=242
#   Left-out user 507: NDCG@10=0.0000, n_test_items=58
#   Left-out user 508: NDCG@10=0.0000, n_test_items=87
#   Left-out user 509: NDCG@10=0.0000, n_test_items=33
#   Left-out user 510: NDCG@10=0.0000, n_test_items=30
#   Left-out user 511: NDCG@10=0.0000, n_test_items=24
#   Left-out user 512: NDCG@10=0.0000, n_test_items=21
#   Left-out user 513: NDCG@10=0.0000, n_test_items=22
#   Left-out user 514: NDCG@10=0.0000, n_test_items=194
#   Left-out user 515: NDCG@10=0.0000, n_test_items=40
#   Left-out user 516: NDCG@10=0.0000, n_test_items=21
#   Left-out user 517: NDCG@10=0.0000, n_test_items=37
#   Left-out user 518: NDCG@10=0.0000, n_test_items=73
#   Left-out user 519: NDCG@10=0.1000, n_test_items=49
#   Left-out user 520: NDCG@10=0.0000, n_test_items=23
#   Left-out user 521: NDCG@10=0.0000, n_test_items=150
#   Left-out user 522: NDCG@10=0.0000, n_test_items=30
#   Left-out user 523: NDCG@10=0.0000, n_test_items=100
#   Left-out user 524: NDCG@10=0.0000, n_test_items=306
#   Left-out user 525: NDCG@10=0.0000, n_test_items=54
#   Left-out user 526: NDCG@10=0.0000, n_test_items=68
#   Left-out user 527: NDCG@10=0.0000, n_test_items=137
#   Left-out user 528: NDCG@10=0.0000, n_test_items=53
#   Left-out user 529: NDCG@10=0.0000, n_test_items=43
#   Left-out user 530: NDCG@10=0.0000, n_test_items=45
#   Left-out user 531: NDCG@10=0.0000, n_test_items=30
#   Left-out user 532: NDCG@10=0.1636, n_test_items=274
#   Left-out user 533: NDCG@10=0.0000, n_test_items=260
#   Left-out user 534: NDCG@10=0.0000, n_test_items=80
#   Left-out user 535: NDCG@10=0.0000, n_test_items=218
#   Left-out user 536: NDCG@10=0.0000, n_test_items=163
#   Left-out user 537: NDCG@10=0.0000, n_test_items=490
#   Left-out user 538: NDCG@10=0.0000, n_test_items=81
#   Left-out user 539: NDCG@10=0.0000, n_test_items=56
#   Left-out user 540: NDCG@10=0.0000, n_test_items=63
#   Left-out user 541: NDCG@10=0.0000, n_test_items=133
#   Left-out user 542: NDCG@10=0.0000, n_test_items=135
#   Left-out user 543: NDCG@10=0.0000, n_test_items=197
#   Left-out user 544: NDCG@10=0.0000, n_test_items=31
#   Left-out user 545: NDCG@10=0.0000, n_test_items=162
#   Left-out user 546: NDCG@10=0.0000, n_test_items=59
#   Left-out user 547: NDCG@10=0.0000, n_test_items=23
#   Left-out user 548: NDCG@10=0.0000, n_test_items=155
#   Left-out user 549: NDCG@10=0.0000, n_test_items=25
#   Left-out user 550: NDCG@10=0.0000, n_test_items=40
#   Left-out user 551: NDCG@10=0.0000, n_test_items=334
#   Left-out user 552: NDCG@10=0.0000, n_test_items=84
#   Left-out user 553: NDCG@10=0.0000, n_test_items=100
#   Left-out user 554: NDCG@10=0.0000, n_test_items=114
#   Left-out user 555: NDCG@10=0.0000, n_test_items=52
#   Left-out user 556: NDCG@10=0.0000, n_test_items=44
#   Left-out user 557: NDCG@10=0.0000, n_test_items=53
#   Left-out user 558: NDCG@10=0.0000, n_test_items=20
#   Left-out user 559: NDCG@10=0.0000, n_test_items=76
#   Left-out user 560: NDCG@10=0.0000, n_test_items=101
#   Left-out user 561: NDCG@10=0.0000, n_test_items=357
#   Left-out user 562: NDCG@10=0.0000, n_test_items=72
#   Left-out user 563: NDCG@10=0.0000, n_test_items=30
#   Left-out user 564: NDCG@10=0.0000, n_test_items=34
#   Left-out user 565: NDCG@10=0.0000, n_test_items=35
#   Left-out user 566: NDCG@10=0.0000, n_test_items=149
#   Left-out user 567: NDCG@10=0.0000, n_test_items=155
#   Left-out user 568: NDCG@10=0.0000, n_test_items=81
#   Left-out user 569: NDCG@10=0.0000, n_test_items=70
#   Left-out user 570: NDCG@10=0.0000, n_test_items=22
#   Left-out user 571: NDCG@10=0.0000, n_test_items=20
#   Left-out user 572: NDCG@10=0.0000, n_test_items=20
#   Left-out user 573: NDCG@10=0.0000, n_test_items=51
#   Left-out user 574: NDCG@10=0.0000, n_test_items=46
#   Left-out user 575: NDCG@10=0.0000, n_test_items=26
#   Left-out user 576: NDCG@10=0.0000, n_test_items=36
#   Left-out user 577: NDCG@10=0.0000, n_test_items=188
#   Left-out user 578: NDCG@10=0.0000, n_test_items=24
#   Left-out user 579: NDCG@10=0.0000, n_test_items=74
#   Left-out user 580: NDCG@10=0.0000, n_test_items=47
#   Left-out user 581: NDCG@10=0.0000, n_test_items=28
#   Left-out user 582: NDCG@10=0.0000, n_test_items=62
#   Left-out user 583: NDCG@10=0.0000, n_test_items=27
#   Left-out user 584: NDCG@10=0.0000, n_test_items=24
#   Left-out user 585: NDCG@10=0.0000, n_test_items=80
#   Left-out user 586: NDCG@10=0.0000, n_test_items=166
#   Left-out user 587: NDCG@10=0.0000, n_test_items=98
#   Left-out user 588: NDCG@10=0.0000, n_test_items=225
#   Left-out user 589: NDCG@10=0.0000, n_test_items=43
#   Left-out user 590: NDCG@10=0.0000, n_test_items=48
#   Left-out user 591: NDCG@10=0.0000, n_test_items=84
#   Left-out user 592: NDCG@10=0.0000, n_test_items=360
#   Left-out user 593: NDCG@10=0.0000, n_test_items=156
#   Left-out user 594: NDCG@10=0.0000, n_test_items=25
#   Left-out user 595: NDCG@10=0.0000, n_test_items=96
#   Left-out user 596: NDCG@10=0.0000, n_test_items=20
#   Left-out user 597: NDCG@10=0.0000, n_test_items=41
#   Left-out user 598: NDCG@10=0.0000, n_test_items=25
#   Left-out user 599: NDCG@10=0.0000, n_test_items=47
#   Left-out user 600: NDCG@10=0.0000, n_test_items=89
#   Left-out user 601: NDCG@10=0.0000, n_test_items=148
#   Left-out user 602: NDCG@10=0.0000, n_test_items=29
#   Left-out user 603: NDCG@10=0.0000, n_test_items=47
#   Left-out user 604: NDCG@10=0.0000, n_test_items=27
#   Left-out user 605: NDCG@10=0.0000, n_test_items=90
#   Left-out user 606: NDCG@10=0.0000, n_test_items=236
#   Left-out user 607: NDCG@10=0.0000, n_test_items=37
#   Left-out user 608: NDCG@10=0.0000, n_test_items=163
#   Left-out user 609: NDCG@10=0.0000, n_test_items=28
#   Left-out user 610: NDCG@10=0.0000, n_test_items=75
#   Left-out user 611: NDCG@10=0.0000, n_test_items=42
#   Left-out user 612: NDCG@10=0.0000, n_test_items=27
#   Left-out user 613: NDCG@10=0.0000, n_test_items=28
#   Left-out user 614: NDCG@10=0.0000, n_test_items=39
#   Left-out user 615: NDCG@10=0.0000, n_test_items=103
#   Left-out user 616: NDCG@10=0.0000, n_test_items=43
#   Left-out user 617: NDCG@10=0.0000, n_test_items=108
#   Left-out user 618: NDCG@10=0.0000, n_test_items=216
#   Left-out user 619: NDCG@10=0.0000, n_test_items=89
#   Left-out user 620: NDCG@10=0.0000, n_test_items=110
#   Left-out user 621: NDCG@10=0.0000, n_test_items=171
#   Left-out user 622: NDCG@10=0.0000, n_test_items=228
#   Left-out user 623: NDCG@10=0.0000, n_test_items=45
#   Left-out user 624: NDCG@10=0.0000, n_test_items=141
#   Left-out user 625: NDCG@10=0.0000, n_test_items=106
#   Left-out user 626: NDCG@10=0.0000, n_test_items=32
#   Left-out user 627: NDCG@10=0.0000, n_test_items=181
#   Left-out user 628: NDCG@10=0.0000, n_test_items=27
#   Left-out user 629: NDCG@10=0.0000, n_test_items=121
#   Left-out user 630: NDCG@10=0.0000, n_test_items=108
#   Left-out user 631: NDCG@10=0.0000, n_test_items=20
#   Left-out user 632: NDCG@10=0.0000, n_test_items=118
#   Left-out user 633: NDCG@10=0.0000, n_test_items=58
#   Left-out user 634: NDCG@10=0.0000, n_test_items=135
#   Left-out user 635: NDCG@10=0.0000, n_test_items=34
#   Left-out user 636: NDCG@10=0.0000, n_test_items=20
#   Left-out user 637: NDCG@10=0.0000, n_test_items=104
#   Left-out user 638: NDCG@10=0.0000, n_test_items=67
#   Left-out user 639: NDCG@10=0.0000, n_test_items=148
#   Left-out user 640: NDCG@10=0.0000, n_test_items=109
#   Left-out user 641: NDCG@10=0.0000, n_test_items=40
#   Left-out user 642: NDCG@10=0.0000, n_test_items=318
#   Left-out user 643: NDCG@10=0.0000, n_test_items=206
#   Left-out user 644: NDCG@10=0.0000, n_test_items=42
#   Left-out user 645: NDCG@10=0.0000, n_test_items=122
#   Left-out user 646: NDCG@10=0.0000, n_test_items=38
#   Left-out user 647: NDCG@10=0.0000, n_test_items=58
#   Left-out user 648: NDCG@10=0.0000, n_test_items=297
#   Left-out user 649: NDCG@10=0.0000, n_test_items=24
#   Left-out user 650: NDCG@10=0.0000, n_test_items=311
#   Left-out user 651: NDCG@10=0.0000, n_test_items=21
#   Left-out user 652: NDCG@10=0.0000, n_test_items=22
#   Left-out user 653: NDCG@10=0.0000, n_test_items=283
#   Left-out user 654: NDCG@10=0.0000, n_test_items=147
#   Left-out user 655: NDCG@10=0.1167, n_test_items=685
#   Left-out user 656: NDCG@10=0.0000, n_test_items=24
#   Left-out user 657: NDCG@10=0.0000, n_test_items=29
#   Left-out user 658: NDCG@10=0.0000, n_test_items=71
#   Left-out user 659: NDCG@10=0.0000, n_test_items=191
#   Left-out user 660: NDCG@10=0.0000, n_test_items=224
#   Left-out user 661: NDCG@10=0.0000, n_test_items=121
#   Left-out user 662: NDCG@10=0.0000, n_test_items=23
#   Left-out user 663: NDCG@10=0.0000, n_test_items=158
#   Left-out user 664: NDCG@10=0.0000, n_test_items=166
#   Left-out user 665: NDCG@10=0.0000, n_test_items=142
#   Left-out user 666: NDCG@10=0.0000, n_test_items=245
#   Left-out user 667: NDCG@10=0.0000, n_test_items=47
#   Left-out user 668: NDCG@10=0.0000, n_test_items=46
#   Left-out user 669: NDCG@10=0.0000, n_test_items=100
#   Left-out user 670: NDCG@10=0.0000, n_test_items=46
#   Left-out user 671: NDCG@10=0.0182, n_test_items=124
#   Left-out user 672: NDCG@10=0.0000, n_test_items=29
#   Left-out user 673: NDCG@10=0.0000, n_test_items=35
#   Left-out user 674: NDCG@10=0.0000, n_test_items=41
#   Left-out user 675: NDCG@10=0.0000, n_test_items=34
#   Left-out user 676: NDCG@10=0.0000, n_test_items=77
#   Left-out user 677: NDCG@10=0.0000, n_test_items=49
#   Left-out user 678: NDCG@10=0.0000, n_test_items=28
#   Left-out user 679: NDCG@10=0.0000, n_test_items=62
#   Left-out user 680: NDCG@10=0.0000, n_test_items=38
#   Left-out user 681: NDCG@10=0.0000, n_test_items=22
#   Left-out user 682: NDCG@10=0.0000, n_test_items=399
#   Left-out user 683: NDCG@10=0.0000, n_test_items=75
#   Left-out user 684: NDCG@10=0.0000, n_test_items=86
#   Left-out user 685: NDCG@10=0.0000, n_test_items=20
#   Left-out user 686: NDCG@10=0.0000, n_test_items=71
#   Left-out user 687: NDCG@10=0.0000, n_test_items=21
#   Left-out user 688: NDCG@10=0.0000, n_test_items=24
#   Left-out user 689: NDCG@10=0.0000, n_test_items=36
#   Left-out user 690: NDCG@10=0.0000, n_test_items=115
#   Left-out user 691: NDCG@10=0.0000, n_test_items=32
#   Left-out user 692: NDCG@10=0.0000, n_test_items=40
#   Left-out user 693: NDCG@10=0.0000, n_test_items=154
#   Left-out user 694: NDCG@10=0.0000, n_test_items=157
#   Left-out user 695: NDCG@10=0.0000, n_test_items=38
#   Left-out user 696: NDCG@10=0.0000, n_test_items=29
#   Left-out user 697: NDCG@10=0.0000, n_test_items=105
#   Left-out user 698: NDCG@10=0.0000, n_test_items=127
#   Left-out user 699: NDCG@10=0.0000, n_test_items=149
#   Left-out user 700: NDCG@10=0.0000, n_test_items=21
#   Left-out user 701: NDCG@10=0.0000, n_test_items=33
#   Left-out user 702: NDCG@10=0.0000, n_test_items=31
#   Left-out user 703: NDCG@10=0.0000, n_test_items=47
#   Left-out user 704: NDCG@10=0.0000, n_test_items=90
#   Left-out user 705: NDCG@10=0.0000, n_test_items=114
#   Left-out user 706: NDCG@10=0.0000, n_test_items=29
#   Left-out user 707: NDCG@10=0.0000, n_test_items=236
#   Left-out user 708: NDCG@10=0.0000, n_test_items=105
#   Left-out user 709: NDCG@10=0.0000, n_test_items=138
#   Left-out user 710: NDCG@10=0.0000, n_test_items=86
#   Left-out user 711: NDCG@10=0.0000, n_test_items=221
#   Left-out user 712: NDCG@10=0.0000, n_test_items=162
#   Left-out user 713: NDCG@10=0.0452, n_test_items=30
#   Left-out user 714: NDCG@10=0.0000, n_test_items=44
#   Left-out user 715: NDCG@10=0.0000, n_test_items=167
#   Left-out user 716: NDCG@10=0.0000, n_test_items=269
#   Left-out user 717: NDCG@10=0.0000, n_test_items=93
#   Left-out user 718: NDCG@10=0.0000, n_test_items=39
#   Left-out user 719: NDCG@10=0.0000, n_test_items=67
#   Left-out user 720: NDCG@10=0.0000, n_test_items=30
#   Left-out user 721: NDCG@10=0.0000, n_test_items=168
#   Left-out user 722: NDCG@10=0.0000, n_test_items=42
#   Left-out user 723: NDCG@10=0.0000, n_test_items=22
#   Left-out user 724: NDCG@10=0.0203, n_test_items=85
#   Left-out user 725: NDCG@10=0.0000, n_test_items=25
#   Left-out user 726: NDCG@10=0.0000, n_test_items=24
#   Left-out user 727: NDCG@10=0.0000, n_test_items=322
#   Left-out user 728: NDCG@10=0.0000, n_test_items=26
#   Left-out user 729: NDCG@10=0.0000, n_test_items=21
#   Left-out user 730: NDCG@10=0.0000, n_test_items=38
#   Left-out user 731: NDCG@10=0.0000, n_test_items=83
#   Left-out user 732: NDCG@10=0.0000, n_test_items=20
#   Left-out user 733: NDCG@10=0.0000, n_test_items=107
#   Left-out user 734: NDCG@10=0.0000, n_test_items=64
#   Left-out user 735: NDCG@10=0.0000, n_test_items=53
#   Left-out user 736: NDCG@10=0.0000, n_test_items=24
#   Left-out user 737: NDCG@10=0.0000, n_test_items=33
#   Left-out user 738: NDCG@10=0.0000, n_test_items=148
#   Left-out user 739: NDCG@10=0.0000, n_test_items=35
#   Left-out user 740: NDCG@10=0.0000, n_test_items=20
#   Left-out user 741: NDCG@10=0.0000, n_test_items=104
#   Left-out user 742: NDCG@10=0.0000, n_test_items=26
#   Left-out user 743: NDCG@10=0.0000, n_test_items=35
#   Left-out user 744: NDCG@10=0.0000, n_test_items=27
#   Left-out user 745: NDCG@10=0.0000, n_test_items=60
#   Left-out user 746: NDCG@10=0.0000, n_test_items=67
#   Left-out user 747: NDCG@10=0.0000, n_test_items=293
#   Left-out user 748: NDCG@10=0.0000, n_test_items=108
#   Left-out user 749: NDCG@10=0.0000, n_test_items=305
#   Left-out user 750: NDCG@10=0.0000, n_test_items=33
#   Left-out user 751: NDCG@10=0.0000, n_test_items=168
#   Left-out user 752: NDCG@10=0.0000, n_test_items=73
#   Left-out user 753: NDCG@10=0.0000, n_test_items=57
#   Left-out user 754: NDCG@10=0.0000, n_test_items=34
#   Left-out user 755: NDCG@10=0.0000, n_test_items=38
#   Left-out user 756: NDCG@10=0.0000, n_test_items=109
#   Left-out user 757: NDCG@10=0.0000, n_test_items=166
#   Left-out user 758: NDCG@10=0.0000, n_test_items=357
#   Left-out user 759: NDCG@10=0.0000, n_test_items=32
#   Left-out user 760: NDCG@10=0.0000, n_test_items=41
#   Left-out user 761: NDCG@10=0.0000, n_test_items=66
#   Left-out user 762: NDCG@10=0.0000, n_test_items=21
#   Left-out user 763: NDCG@10=0.0000, n_test_items=129
#   Left-out user 764: NDCG@10=0.0000, n_test_items=109
#   Left-out user 765: NDCG@10=0.0000, n_test_items=23
#   Left-out user 766: NDCG@10=0.0000, n_test_items=175
#   Left-out user 767: NDCG@10=0.0000, n_test_items=37
#   Left-out user 768: NDCG@10=0.0000, n_test_items=64
#   Left-out user 769: NDCG@10=0.0000, n_test_items=29
#   Left-out user 770: NDCG@10=0.0000, n_test_items=64
#   Left-out user 771: NDCG@10=0.0000, n_test_items=70
#   Left-out user 772: NDCG@10=0.0000, n_test_items=33
#   Left-out user 773: NDCG@10=0.0000, n_test_items=161
#   Left-out user 774: NDCG@10=0.0000, n_test_items=224
#   Left-out user 775: NDCG@10=0.0000, n_test_items=28
#   Left-out user 776: NDCG@10=0.0000, n_test_items=105
#   Left-out user 777: NDCG@10=0.0000, n_test_items=36
#   Left-out user 778: NDCG@10=0.0000, n_test_items=65
#   Left-out user 779: NDCG@10=0.0000, n_test_items=37
#   Left-out user 780: NDCG@10=0.0000, n_test_items=55
#   Left-out user 781: NDCG@10=0.1000, n_test_items=42
#   Left-out user 782: NDCG@10=0.0598, n_test_items=232
#   Left-out user 783: NDCG@10=0.0000, n_test_items=30
#   Left-out user 784: NDCG@10=0.0000, n_test_items=39
#   Left-out user 785: NDCG@10=0.0000, n_test_items=27
#   Left-out user 786: NDCG@10=0.0000, n_test_items=117
#   Left-out user 787: NDCG@10=0.0000, n_test_items=57
#   Left-out user 788: NDCG@10=0.0000, n_test_items=249
#   Left-out user 789: NDCG@10=0.0000, n_test_items=33
#   Left-out user 790: NDCG@10=0.0000, n_test_items=231
#   Left-out user 791: NDCG@10=0.0000, n_test_items=25
#   Left-out user 792: NDCG@10=0.0000, n_test_items=47
#   Left-out user 793: NDCG@10=0.0000, n_test_items=55
#   Left-out user 794: NDCG@10=0.0000, n_test_items=39
#   Left-out user 795: NDCG@10=0.0000, n_test_items=159
#   Left-out user 796: NDCG@10=0.0000, n_test_items=358
#   Left-out user 797: NDCG@10=0.0000, n_test_items=26
#   Left-out user 798: NDCG@10=0.0000, n_test_items=239
#   Left-out user 799: NDCG@10=0.0000, n_test_items=24
#   Left-out user 800: NDCG@10=0.0000, n_test_items=28
#   Left-out user 801: NDCG@10=0.0000, n_test_items=26
#   Left-out user 802: NDCG@10=0.0000, n_test_items=75
#   Left-out user 803: NDCG@10=0.0000, n_test_items=33
#   Left-out user 804: NDCG@10=0.0000, n_test_items=332
#   Left-out user 805: NDCG@10=0.0000, n_test_items=273
#   Left-out user 806: NDCG@10=0.0000, n_test_items=140
#   Left-out user 807: NDCG@10=0.0000, n_test_items=204
#   Left-out user 808: NDCG@10=0.0000, n_test_items=23
#   Left-out user 809: NDCG@10=0.0000, n_test_items=20
#   Left-out user 810: NDCG@10=0.0000, n_test_items=26
#   Left-out user 811: NDCG@10=0.0000, n_test_items=21
#   Left-out user 812: NDCG@10=0.0000, n_test_items=20
#   Left-out user 813: NDCG@10=0.0000, n_test_items=29
#   Left-out user 814: NDCG@10=0.0000, n_test_items=35
#   Left-out user 815: NDCG@10=0.0000, n_test_items=183
#   Left-out user 816: NDCG@10=0.0000, n_test_items=25
#   Left-out user 817: NDCG@10=0.0000, n_test_items=36
#   Left-out user 818: NDCG@10=0.0000, n_test_items=21
#   Left-out user 819: NDCG@10=0.0000, n_test_items=28
#   Left-out user 820: NDCG@10=0.0000, n_test_items=21
#   Left-out user 821: NDCG@10=0.0000, n_test_items=62
#   Left-out user 822: NDCG@10=0.0000, n_test_items=25
#   Left-out user 823: NDCG@10=0.0000, n_test_items=185
#   Left-out user 824: NDCG@10=0.0000, n_test_items=20
#   Left-out user 825: NDCG@10=0.0000, n_test_items=145
#   Left-out user 826: NDCG@10=0.0000, n_test_items=115
#   Left-out user 827: NDCG@10=0.0000, n_test_items=28
#   Left-out user 828: NDCG@10=0.0000, n_test_items=104
#   Left-out user 829: NDCG@10=0.0000, n_test_items=64
#   Left-out user 830: NDCG@10=0.0000, n_test_items=106
#   Left-out user 831: NDCG@10=0.0000, n_test_items=73
#   Left-out user 832: NDCG@10=0.0000, n_test_items=25
#   Left-out user 833: NDCG@10=0.0000, n_test_items=267
#   Left-out user 834: NDCG@10=0.0000, n_test_items=54
#   Left-out user 835: NDCG@10=0.0000, n_test_items=102
#   Left-out user 836: NDCG@10=0.0000, n_test_items=50
#   Left-out user 837: NDCG@10=0.0000, n_test_items=46
#   Left-out user 838: NDCG@10=0.0000, n_test_items=93
#   Left-out user 839: NDCG@10=0.0000, n_test_items=57
#   Left-out user 840: NDCG@10=0.0000, n_test_items=197
#   Left-out user 841: NDCG@10=0.0000, n_test_items=31
#   Left-out user 842: NDCG@10=0.0000, n_test_items=27
#   Left-out user 843: NDCG@10=0.0000, n_test_items=204
#   Left-out user 844: NDCG@10=0.0000, n_test_items=81
#   Left-out user 845: NDCG@10=0.0000, n_test_items=31
#   Left-out user 846: NDCG@10=0.0000, n_test_items=405
#   Left-out user 847: NDCG@10=0.0000, n_test_items=146
#   Left-out user 848: NDCG@10=0.0000, n_test_items=150
#   Left-out user 849: NDCG@10=0.0000, n_test_items=23
#   Left-out user 850: NDCG@10=0.0000, n_test_items=51
#   Left-out user 851: NDCG@10=0.0000, n_test_items=209
#   Left-out user 852: NDCG@10=0.0000, n_test_items=49
#   Left-out user 853: NDCG@10=0.0000, n_test_items=41
#   Left-out user 854: NDCG@10=0.0000, n_test_items=217
#   Left-out user 855: NDCG@10=0.0000, n_test_items=23
#   Left-out user 856: NDCG@10=0.0000, n_test_items=26
#   Left-out user 857: NDCG@10=0.0000, n_test_items=22
#   Left-out user 858: NDCG@10=0.0000, n_test_items=21
#   Left-out user 859: NDCG@10=0.0000, n_test_items=39
#   Left-out user 860: NDCG@10=0.0000, n_test_items=71
#   Left-out user 861: NDCG@10=0.0000, n_test_items=43
#   Left-out user 862: NDCG@10=0.0000, n_test_items=165
#   Left-out user 863: NDCG@10=0.0000, n_test_items=107
#   Left-out user 864: NDCG@10=0.0000, n_test_items=294
#   Left-out user 865: NDCG@10=0.0000, n_test_items=66
#   Left-out user 866: NDCG@10=0.0000, n_test_items=20
#   Left-out user 867: NDCG@10=0.0000, n_test_items=95
#   Left-out user 868: NDCG@10=0.0000, n_test_items=208
#   Left-out user 869: NDCG@10=0.0000, n_test_items=47
#   Left-out user 870: NDCG@10=0.0000, n_test_items=269
#   Left-out user 871: NDCG@10=0.0000, n_test_items=115
#   Left-out user 872: NDCG@10=0.0000, n_test_items=71
#   Left-out user 873: NDCG@10=0.0000, n_test_items=20
#   Left-out user 874: NDCG@10=0.0000, n_test_items=34
#   Left-out user 875: NDCG@10=0.0000, n_test_items=89
#   Left-out user 876: NDCG@10=0.0000, n_test_items=21
#   Left-out user 877: NDCG@10=0.0000, n_test_items=81
#   Left-out user 878: NDCG@10=0.0000, n_test_items=134
#   Left-out user 879: NDCG@10=0.0000, n_test_items=29
#   Left-out user 880: NDCG@10=0.0000, n_test_items=368
#   Left-out user 881: NDCG@10=0.0000, n_test_items=259
#   Left-out user 882: NDCG@10=0.0000, n_test_items=137
#   Left-out user 883: NDCG@10=0.0000, n_test_items=268
#   Left-out user 884: NDCG@10=0.0000, n_test_items=43
#   Left-out user 885: NDCG@10=0.0000, n_test_items=102
#   Left-out user 886: NDCG@10=0.1000, n_test_items=240
#   Left-out user 887: NDCG@10=0.0000, n_test_items=171
#   Left-out user 888: NDCG@10=0.0000, n_test_items=20
#   Left-out user 889: NDCG@10=0.0000, n_test_items=326
#   Left-out user 890: NDCG@10=0.0000, n_test_items=119
#   Left-out user 891: NDCG@10=0.0000, n_test_items=47
#   Left-out user 892: NDCG@10=0.0000, n_test_items=226
#   Left-out user 893: NDCG@10=0.0000, n_test_items=59
#   Left-out user 894: NDCG@10=0.0000, n_test_items=245
#   Left-out user 895: NDCG@10=0.0000, n_test_items=20
#   Left-out user 896: NDCG@10=0.0000, n_test_items=362
#   Left-out user 897: NDCG@10=0.0000, n_test_items=185
#   Left-out user 898: NDCG@10=0.0000, n_test_items=30
#   Left-out user 899: NDCG@10=0.0000, n_test_items=135
#   Left-out user 900: NDCG@10=0.0000, n_test_items=45
#   Left-out user 901: NDCG@10=0.0000, n_test_items=124
#   Left-out user 902: NDCG@10=0.0000, n_test_items=49
#   Left-out user 903: NDCG@10=0.0000, n_test_items=136
#   Left-out user 904: NDCG@10=0.0000, n_test_items=47
#   Left-out user 905: NDCG@10=0.0000, n_test_items=40
#   Left-out user 906: NDCG@10=0.0000, n_test_items=41
#   Left-out user 907: NDCG@10=0.0000, n_test_items=147
#   Left-out user 908: NDCG@10=0.0000, n_test_items=74
#   Left-out user 909: NDCG@10=0.0000, n_test_items=26
#   Left-out user 910: NDCG@10=0.0000, n_test_items=60
#   Left-out user 911: NDCG@10=0.0000, n_test_items=98
#   Left-out user 912: NDCG@10=0.0000, n_test_items=53
#   Left-out user 913: NDCG@10=0.0000, n_test_items=132
#   Left-out user 914: NDCG@10=0.0000, n_test_items=23
#   Left-out user 915: NDCG@10=0.0000, n_test_items=26
#   Left-out user 916: NDCG@10=0.0000, n_test_items=317
#   Left-out user 917: NDCG@10=0.0000, n_test_items=35
#   Left-out user 918: NDCG@10=0.0000, n_test_items=103
#   Left-out user 919: NDCG@10=0.0000, n_test_items=217
#   Left-out user 920: NDCG@10=0.0000, n_test_items=26
#   Left-out user 921: NDCG@10=0.0000, n_test_items=110
#   Left-out user 922: NDCG@10=0.0000, n_test_items=127
#   Left-out user 923: NDCG@10=0.0000, n_test_items=74
#   Left-out user 924: NDCG@10=0.0000, n_test_items=82
#   Left-out user 925: NDCG@10=0.0000, n_test_items=32
#   Left-out user 926: NDCG@10=0.0000, n_test_items=20
#   Left-out user 927: NDCG@10=0.0000, n_test_items=120
#   Left-out user 928: NDCG@10=0.0000, n_test_items=32
#   Left-out user 929: NDCG@10=0.0000, n_test_items=49
#   Left-out user 930: NDCG@10=0.0000, n_test_items=63
#   Left-out user 931: NDCG@10=0.0000, n_test_items=61
#   Left-out user 932: NDCG@10=0.0000, n_test_items=241
#   Left-out user 933: NDCG@10=0.0000, n_test_items=184
#   Left-out user 934: NDCG@10=0.0000, n_test_items=174
#   Left-out user 935: NDCG@10=0.0000, n_test_items=39
#   Left-out user 936: NDCG@10=0.0000, n_test_items=142
#   Left-out user 937: NDCG@10=0.0000, n_test_items=40
#   Left-out user 938: NDCG@10=0.0000, n_test_items=108
#   Left-out user 939: NDCG@10=0.0000, n_test_items=49
#   Left-out user 940: NDCG@10=0.0000, n_test_items=107
#   Left-out user 941: NDCG@10=0.0000, n_test_items=22
#   Left-out user 942: NDCG@10=0.0000, n_test_items=79
#   Left-out user 943: NDCG@10=0.0000, n_test_items=168
# Params {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 10, 'n_iter': 15} -> Avg NDCG@10: 0.0017, RMSE: 1.0220, RMSE_norm: 0.9079477577837008

# %%
d = {"Data": "MovieLens 100k", 
    "Accuracy": acc, 
    "Precision": pre, 
    "Recall": rec, 
    "F1 score": f1s,
    "ndcg": ndcg,
    "k_ndcg": k_ndcg,
    "rmse": rmse,
    "rmse_norm": rmse_normalized,
    "density": calculate_density(df_mf_ml)
    }
d.update(best_metrics)
results_combine.append(d)
# Out:
# Users: 943, Videos: 1682
# Observed interactions: 100000
# Density: 0.0630
# Sparsity: 0.9370

# %%
df_results_combine = pd.DataFrame(results_combine) 
df_results_combine
# Out:
#                 Data  Accuracy  Precision    Recall  F1 score      ndcg  \
# 0  TikTok Experiment  0.373092   0.347676  0.301097  0.287353  0.887181
# 1  TikTok Real-World  0.185445   0.305384  0.211289  0.144749  0.803080
# 2     MovieLens 100k  0.422361   0.385454  0.271317  0.278305  0.873018
#
#    k_ndcg      rmse  rmse_norm   density  avg_ndcg_loo  k_ndcg_loo  rmse_loo  \
# 0       3  1.332465   0.809023  0.611310      0.807134          10  1.320171
# 1       3  1.546608   0.934442  0.083637      0.055099          10  1.548382
# 2       3  0.938817   0.835307  0.063047      0.001725          10  1.022048
#
#    rmse_normalized_loo  num_users_loo
# 0             0.787932             80
# 1             0.950453            334
# 2             0.907948            943

# %%
# Create bar plot
plt.figure(figsize=(8, 5))
plt.barh(df_results_combine["Data"], df_results_combine["F1 score"])
plt.xlabel("F1 Score")
plt.title("F1 Score by Dataset")
plt.xticks(rotation=15)
plt.tight_layout()

# Show plot
plt.show()

# %%
# Create bar plot
plt.figure(figsize=(8, 5))
plt.barh(df_results_combine["Data"], df_results_combine["rmse_norm"])
plt.xlabel("RMSE norm")
plt.title("RMSE norm by Dataset")
plt.xticks(rotation=15)
plt.tight_layout()

# Show plot
plt.show()

# %%
# Example column to annotate with – replace "model" with your desired column name
annotation_column = "Data"  # change this to your actual column name in df_results_combine

plt.figure(figsize=(8, 5))
plt.scatter(df_results_combine["density"], df_results_combine["F1 score"])

# Add annotations
for i, txt in enumerate(df_results_combine[annotation_column]):
    plt.annotate(txt,
                 (df_results_combine["density"].iloc[i], df_results_combine["F1 score"].iloc[i]),
                 textcoords="offset points",  # how to position the text
                 xytext=(5, 5),              # distance from the data point
                 fontsize=8)

plt.xlabel("Density")
plt.xlim(0,1)
plt.ylabel("F1 Score")
plt.ylim(0,0.5)
plt.title("Scatter Plot of Dataset Density vs F1 Score")
plt.tight_layout()
plt.show()

# %%
df_results_combine.to_csv("data/results_mf_combined.csv")

# %% [markdown]
# # Reduzing the size of ML data for comparison with TikTok Experiment data

# %%
def density(m):
    total_possible = m.shape[0] * m.shape[1]
    non_zero = (m != 0).sum().sum()
    return non_zero / total_possible
        
def extract_dense_subset_random(matrix, target_density=0.6, n_users_sample=1000, min_users=80, min_videos=100, random_state=42):
    
    np.random.seed(random_state)

    # Step 1: Randomly sample users
    sampled_users = np.random.choice(matrix.index, size=min(n_users_sample, matrix.shape[0]), replace=False)
    dense_matrix = matrix.loc[sampled_users]

    current_density = density(dense_matrix)
    changed = True

    while current_density < target_density and changed:
        changed = False
        # Shuffle users and videos before filtering (tie-breaking)
        dense_matrix = dense_matrix.sample(frac=1, random_state=random_state)
        dense_matrix = dense_matrix.sample(frac=1, axis=1, random_state=random_state)

        # Filter users with <= median interactions
        user_activity = (dense_matrix != 0).sum(axis=1)
        median_activity = user_activity.quantile(0.5)
        active_users = user_activity[user_activity > median_activity].index
        dense_matrix = dense_matrix.loc[active_users]

        # Filter videos with <= median interactions
        video_popularity = (dense_matrix != 0).sum(axis=0)
        median_popularity = video_popularity.quantile(0.5)
        popular_videos = video_popularity[video_popularity > median_popularity].index
        dense_matrix = dense_matrix[popular_videos]

        # Recompute density
        new_density = density(dense_matrix)
        if new_density > current_density:
            current_density = new_density
            changed = True

        # Check if the number of remaining users or videos falls below a minimum threshold
        if dense_matrix.shape[0] < min_users or dense_matrix.shape[1] < min_videos:
            break

    return dense_matrix

# %%
user_video_matrix = df_mf_ml.pivot_table(index='user_id', columns='video_id', values='rating', aggfunc='mean', fill_value=0)

dense_matrices = []
for i in range(5):
    dense_subset = extract_dense_subset_random(
        user_video_matrix,
        target_density=0.6,
        n_users_sample=650,  # larger than final dense block
        min_users=80,
        min_videos=100,
        random_state=42 + i
    )
    dense_matrices.append(dense_subset)
    print(f"Submatrix {i+1}: users={dense_subset.shape[0]}, videos={dense_subset.shape[1]}, density={(dense_subset!=0).sum().sum()/(dense_subset.shape[0]*dense_subset.shape[1]):.4f}")
# Out:
# Submatrix 1: users=80, videos=200, density=0.6663
# Submatrix 2: users=80, videos=195, density=0.6780
# Submatrix 3: users=80, videos=197, density=0.6754
# Submatrix 4: users=80, videos=202, density=0.6601
# Submatrix 5: users=79, videos=206, density=0.6722

# %%
dense_dfs = []  # to store the long-format versions

for i, dense_subset in enumerate(dense_matrices, start=1):
    # Convert the matrix back into long format
    dense_long = (
        dense_subset
        .stack()  # converts from wide to long
        .reset_index()
        .rename(columns={0: 'rating'})
    )
    
    # Keep only non-zero ratings (i.e., actual interactions)
    dense_long = dense_long[dense_long['rating'] != 0]
    
    # Optionally, add a sample ID column
    dense_long['sample_id'] = i
    
    dense_dfs.append(dense_long)
    
    print(f"Sample {i}: {len(dense_long)} interactions, users={dense_subset.shape[0]}, videos={dense_subset.shape[1]}")

# Combine all samples into one DataFrame (optional)
all_dense_samples = pd.concat(dense_dfs, ignore_index=True)
# Out:
# Sample 1: 10661 interactions, users=80, videos=200
# Sample 2: 10577 interactions, users=80, videos=195
# Sample 3: 10645 interactions, users=80, videos=197
# Sample 4: 10667 interactions, users=80, videos=202
# Sample 5: 10939 interactions, users=79, videos=206

# %%
# Prepare lists of user and video sets
user_sets = [set(df['user_id']) for df in dense_dfs]
video_sets = [set(df['video_id']) for df in dense_dfs]

user_overlap_results = []
video_overlap_results = []

# Pairwise combinations of samples
for (i, j) in itertools.combinations(range(len(dense_dfs)), 2):
    u_overlap = len(user_sets[i].intersection(user_sets[j]))
    v_overlap = len(video_sets[i].intersection(video_sets[j]))
    
    user_overlap_results.append({
        'sample_i': i+1,
        'sample_j': j+1,
        'shared_users': u_overlap,
        'prop_users_i': u_overlap / len(user_sets[i]),
        'prop_users_j': u_overlap / len(user_sets[j]),
    })
    
    video_overlap_results.append({
        'sample_i': i+1,
        'sample_j': j+1,
        'shared_videos': v_overlap,
        'prop_videos_i': v_overlap / len(video_sets[i]),
        'prop_videos_j': v_overlap / len(video_sets[j]),
    })

# Convert to DataFrames for easy viewing
user_overlap_df = pd.DataFrame(user_overlap_results)
video_overlap_df = pd.DataFrame(video_overlap_results)

print("=== User Overlap ===")
print(user_overlap_df.round(3))

print("\n=== Video Overlap ===")
print(video_overlap_df.round(3))
# Out:
# === User Overlap ===
#    sample_i  sample_j  shared_users  prop_users_i  prop_users_j
# 0         1         2            52         0.650         0.650
# 1         1         3            48         0.600         0.600
# 2         1         4            50         0.625         0.625
# 3         1         5            53         0.662         0.671
# 4         2         3            58         0.725         0.725
# 5         2         4            50         0.625         0.625
# 6         2         5            56         0.700         0.709
# 7         3         4            53         0.662         0.662
# 8         3         5            58         0.725         0.734
# 9         4         5            52         0.650         0.658
#
# === Video Overlap ===
#    sample_i  sample_j  shared_videos  prop_videos_i  prop_videos_j
# 0         1         2            180          0.900          0.923
# 1         1         3            184          0.920          0.934
# 2         1         4            181          0.905          0.896
# 3         1         5            181          0.905          0.879
# 4         2         3            184          0.944          0.934
# 5         2         4            181          0.928          0.896
# 6         2         5            182          0.933          0.883
# 7         3         4            185          0.939          0.916
# 8         3         5            189          0.959          0.917
# 9         4         5            187          0.926          0.908

# %% [markdown]
# ## MF TikTok Experiment data & MF ML 5 toy datasets

# %%
param_grid = {
    'n_components': [2, 5, 10, 20, 50, 100, 124],
    'max_iter': [1000, 2000, 3000],
    'init': ['random'],
    'model_type': ['svd'],
    'n_iter': [1, 3, 5, 10, 15]
}

results_ml = []

for i, df_ml_subset in enumerate(dense_dfs):
    d = calculate_density(df_ml_subset)
    R_test, R_estimated, ndcg, k_ndcg, rmse, rmse_norm, best_model = grid_search_mf_bias(df_ml_subset, param_grid, print_info=False)
    results_ml.append({"ML toy": i, "density": d, "ndcg": ndcg, "k_ndcg": k_ndcg, "rmse": rmse, "rmse_norm": rmse_norm})
# Out:
# Users: 80, Videos: 200
# Observed interactions: 10661
# Density: 0.6663
# Sparsity: 0.3337
# (10661, 4) (8500, 4) (2161, 4)
# 8500 2161 2132.2000000000003
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 15}
# ✅ Best RMSE on TEST: 0.8743, NDCG@3: 0.8924 (len:80), normalized RMSE: 0.8743
#
# 📈 Explained Variance (for best SVD only): 0.12178879067688897
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Users: 80, Videos: 195
# Observed interactions: 10577
# Density: 0.6780
# Sparsity: 0.3220
# (10577, 4) (8431, 4) (2146, 4)
# 8431 2146 2115.4
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 3}
# ✅ Best RMSE on TEST: 0.8696, NDCG@3: 0.8888 (len:80), normalized RMSE: 0.8696
#
# 📈 Explained Variance (for best SVD only): 0.12470632075417712
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Users: 80, Videos: 197
# Observed interactions: 10645
# Density: 0.6754
# Sparsity: 0.3246
# (10645, 4) (8484, 4) (2161, 4)
# 8484 2161 2129.0
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 15}
# ✅ Best RMSE on TEST: 0.8629, NDCG@3: 0.8834 (len:80), normalized RMSE: 0.8629
#
# 📈 Explained Variance (for best SVD only): 0.12090028666685648
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Users: 80, Videos: 202
# Observed interactions: 10667
# Density: 0.6601
# Sparsity: 0.3399
# (10667, 4) (8501, 4) (2166, 4)
# 8501 2166 2133.4
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 3}
# ✅ Best RMSE on TEST: 0.9061, NDCG@3: 0.8606 (len:80), normalized RMSE: 0.9061
#
# 📈 Explained Variance (for best SVD only): 0.11992448660622207
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None
# Users: 79, Videos: 206
# Observed interactions: 10939
# Density: 0.6722
# Sparsity: 0.3278
# (10939, 4) (8717, 4) (2222, 4)
# 8717 2222 2187.8
#
# ✅ Best params: {'init': 'random', 'max_iter': 1000, 'model_type': 'svd', 'n_components': 2, 'n_iter': 5}
# ✅ Best RMSE on TEST: 0.9175, NDCG@3: 0.8681 (len:79), normalized RMSE: 0.9175
#
# 📈 Explained Variance (for best SVD only): 0.11431508589904993
#
# 📈 Reconstruction Error (for best NMF only): None
#
# 📈 Reconstruction Error Normalized(for best NMF only): None

# %%
results_ml_df = pd.DataFrame(results_ml)
results_ml_df
# Out:
#    ML toy   density      ndcg  k_ndcg      rmse  rmse_norm
# 0       0  0.666312  0.892361       3  0.874271   0.849928
# 1       1  0.678013  0.888840       3  0.869631   0.836298
# 2       2  0.675444  0.883374       3  0.862877   0.847761
# 3       3  0.660087  0.860602       3  0.906127   0.834280
# 4       4  0.672176  0.868050       3  0.917469   0.860553
